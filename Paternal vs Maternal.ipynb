# %% [markdown]
# # **Aim of the notebook:**
# To check if the bias exsists in the Training dataset of IndicTrans2. Bias here means if the translation of ambiguos words is done more for paternal than maternal.
# To check the ratio of sentences in paternal vs maternal in both training and dataset.

# %%
import pandas as pd

# %% [markdown]
# # Languages Involved:

# %%
# languages = [ 'or', 'hi', 'ta', 'te','bn', 'gu',  'kn', 'ml', 'mr',  'pa'  ]

# %% [markdown]
# # Datasets involved:

# %%
# path = 'https://indictrans2-public.objectstore.e2enetworks.net/BPCC.zip'
# zip_path = path.split('/')[-1]

# # Download the dataset using above link
# !wget $path -O $zip_path

# %%
# !unzip $zip_path

# %% [markdown]
# ## Langs and scripts

# %%
# create a list with data (just include within bracket): Assamese (asm_Beng)	Kashmiri (Arabic) (kas_Arab)	Punjabi (pan_Guru)
# Bengali (ben_Beng)	Kashmiri (Devanagari) (kas_Deva)	Sanskrit (san_Deva)
# Bodo (brx_Deva)	Maithili (mai_Deva)	Santali (sat_Olck)
# Dogri (doi_Deva)	Malayalam (mal_Mlym)	Sindhi (Arabic) (snd_Arab)
# English (eng_Latn)	Marathi (mar_Deva)	Sindhi (Devanagari) (snd_Deva)
# Konkani (gom_Deva)	Manipuri (Bengali) (mni_Beng)	Tamil (tam_Taml)
# Gujarati (guj_Gujr)	Manipuri (Meitei) (mni_Mtei)	Telugu (tel_Telu)
# Hindi (hin_Deva)	Nepali (npi_Deva)	Urdu (urd_Arab)
# Kannada (kan_Knda)	Odia (ory_Orya)	

lang_script_list = [
    # 'asm_Beng', 'kas_Arab',
                     'pan_Guru', 'ben_Beng', 
                    #  'kas_Deva', 'san_Deva', 'brx_Deva', 'mai_Deva', 'sat_Olck', 'doi_Deva',
                       'mal_Mlym',
                     #    #  'snd_Arab',
                     #    #    'eng_Latn', 
                           'mar_Deva', 
                     #    #    'snd_Deva', 'gom_Deva', 'mni_Beng', 
                           'tam_Taml', 'guj_Gujr', 
                     #    #    'mni_Mtei', 
                           'tel_Telu', 'hin_Deva', 
                     #    #    'npi_Deva', 'urd_Arab', 
                           'kan_Knda', 
                           'ory_Orya'
                           ]

# %%
# Traverse through each folder of XXXU and print the folder names
import os
import pandas as pd
import tqdm

# Create a list to store the folder names
# folders = []
 # create a list of 10 items of dataframes in an array
df_list = {
    i : pd.DataFrame() for i in (lang_script_list)
}

df_list
# Out:
# {'pan_Guru': Empty DataFrame
#  Columns: []
#  Index: [],
#  'ben_Beng': Empty DataFrame
#  Columns: []
#  Index: [],
#  'mal_Mlym': Empty DataFrame
#  Columns: []
#  Index: [],
#  'mar_Deva': Empty DataFrame
#  Columns: []
#  Index: [],
#  'tam_Taml': Empty DataFrame
#  Columns: []
#  Index: [],
#  'guj_Gujr': Empty DataFrame
#  Columns: []
#  Index: [],
#  'tel_Telu': Empty DataFrame
#  Columns: []
#  Index: [],
#  'hin_Deva': Empty DataFrame
#  Columns: []
#  Index: [],
#  'kan_Knda': Empty DataFrame
#  Columns: []
#  Index: [],
#  'ory_Orya': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
# Traverse through each folder of XXXU and print the folder names
for folder in os.listdir('BPCC/'):
    # folders.append(folder)
    # print(folder)
    # Traverse these folders and print the file names
    # for sub_folder in os.listdir('BPCC/'+folder):
    # tqdm progress bar
    for sub_folder in tqdm.tqdm(os.listdir('BPCC/'+folder)):
        # print(file)
        eng, indic_lang = sub_folder.split('-') # source and target langs
        if indic_lang in lang_script_list:
            # print the file names within the sub folders
            for file in os.listdir('BPCC/'+folder+'/'+sub_folder):
                print('BPCC/'+folder+'/'+sub_folder+'/'+file)
                if 'train' in file:
                    df = pd.DataFrame(columns=['eng_Latn', indic_lang])
                    if 'eng_Latn' in file:
                        # df['eng_Latn'] = pd.read_csv('BPCC/'+folder+'/'+sub_folder+'/'+file, sep='\t', encoding='utf-8', )
                        # print('early now: BPCC/'+folder+'/'+sub_folder+'/'+file)
                        with open('BPCC/'+folder+'/'+sub_folder+'/'+file) as f:
                            df_en = f.readlines()
                    else:
                        # df[indic_lang] = pd.read_csv('BPCC/'+folder+'/'+sub_folder+'/'+file, sep='\t', encoding='utf-8')
                        # print('now: BPCC/'+folder+'/'+sub_folder+'/'+file)
                        with open('BPCC/'+folder+'/'+sub_folder+'/'+file) as f:
                            df_ind = f.readlines()
            df = pd.DataFrame()
            df['eng_Latn'] = df_en
            df[indic_lang] = df_ind
            
            df_list[indic_lang] = pd.concat([df_list[indic_lang], df], axis=0)

                    
df_list        



# BPCC/nllb_filtered/eng_Latn-ory_Orya/train.eng_Latn
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 30174.85it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# BPCC/nllb_filtered/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-ory_Orya/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-ory_Orya/train.ory_Orya
#  11%|█         | 2/19 [00:02<00:20,  1.23s/it]
# BPCC/nllb_filtered/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-pan_Guru/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-pan_Guru/train.pan_Guru
#  16%|█▌        | 3/19 [00:05<00:29,  1.86s/it]
# BPCC/nllb_filtered/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-mar_Deva/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-mar_Deva/train.mar_Deva
#  26%|██▋       | 5/19 [00:11<00:35,  2.57s/it]
# BPCC/nllb_filtered/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-guj_Gujr/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-guj_Gujr/train.guj_Gujr
#  37%|███▋      | 7/19 [00:21<00:43,  3.65s/it]
# BPCC/nllb_filtered/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-ben_Beng/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-ben_Beng/train.ben_Beng
#  53%|█████▎    | 10/19 [00:38<00:41,  4.58s/it]
# BPCC/nllb_filtered/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-tel_Telu/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-tel_Telu/train.tel_Telu
#  58%|█████▊    | 11/19 [00:54<00:53,  6.69s/it]
# BPCC/nllb_filtered/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/nllb_filtered/eng_Latn-tam_Taml/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-tam_Taml/labse_scores.txt
#  68%|██████▊   | 13/19 [01:03<00:36,  6.06s/it]
# BPCC/nllb_filtered/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-mal_Mlym/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-mal_Mlym/train.mal_Mlym
#  84%|████████▍ | 16/19 [01:14<00:14,  4.93s/it]
# BPCC/nllb_filtered/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-hin_Deva/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-hin_Deva/train.hin_Deva
#  95%|█████████▍| 18/19 [01:22<00:04,  4.67s/it]
# BPCC/nllb_filtered/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/nllb_filtered/eng_Latn-kan_Knda/labse_scores.txt
# BPCC/nllb_filtered/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 19/19 [01:34<00:00,  4.96s/it]
#   0%|          | 0/17 [00:00<?, ?it/s]
# BPCC/comparable/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/comparable/eng_Latn-ory_Orya/labse_scores.txt
# BPCC/comparable/eng_Latn-ory_Orya/train.ory_Orya
#   6%|▌         | 1/17 [00:00<00:14,  1.11it/s]
# BPCC/comparable/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/comparable/eng_Latn-pan_Guru/labse_scores.txt
# BPCC/comparable/eng_Latn-pan_Guru/train.pan_Guru
#  12%|█▏        | 2/17 [00:01<00:11,  1.32it/s]
# BPCC/comparable/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/comparable/eng_Latn-mar_Deva/labse_scores.txt
# BPCC/comparable/eng_Latn-mar_Deva/train.mar_Deva
#  18%|█▊        | 3/17 [00:03<00:16,  1.15s/it]
# BPCC/comparable/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/comparable/eng_Latn-guj_Gujr/labse_scores.txt
# BPCC/comparable/eng_Latn-guj_Gujr/train.guj_Gujr
#  29%|██▉       | 5/17 [00:05<00:13,  1.10s/it]
# BPCC/comparable/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/comparable/eng_Latn-ben_Beng/labse_scores.txt
# BPCC/comparable/eng_Latn-ben_Beng/train.ben_Beng
#  47%|████▋     | 8/17 [00:06<00:06,  1.30it/s]
# BPCC/comparable/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/comparable/eng_Latn-tel_Telu/labse_scores.txt
# BPCC/comparable/eng_Latn-tel_Telu/train.tel_Telu
#  53%|█████▎    | 9/17 [00:08<00:07,  1.10it/s]
# BPCC/comparable/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/comparable/eng_Latn-tam_Taml/train.eng_Latn
# BPCC/comparable/eng_Latn-tam_Taml/labse_scores.txt
#  65%|██████▍   | 11/17 [00:09<00:04,  1.21it/s]
# BPCC/comparable/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/comparable/eng_Latn-mal_Mlym/labse_scores.txt
# BPCC/comparable/eng_Latn-mal_Mlym/train.mal_Mlym
#  82%|████████▏ | 14/17 [00:11<00:02,  1.39it/s]
# BPCC/comparable/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/comparable/eng_Latn-hin_Deva/labse_scores.txt
# BPCC/comparable/eng_Latn-hin_Deva/train.hin_Deva
#  88%|████████▊ | 15/17 [00:14<00:02,  1.06s/it]
# BPCC/comparable/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/comparable/eng_Latn-kan_Knda/labse_scores.txt
# BPCC/comparable/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 17/17 [00:15<00:00,  1.11it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# BPCC/samanantar_v0.3_filtered/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-ory_Orya/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-ory_Orya/train.ory_Orya
#   9%|▉         | 1/11 [00:00<00:07,  1.32it/s]
# BPCC/samanantar_v0.3_filtered/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-pan_Guru/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-pan_Guru/train.pan_Guru
#  18%|█▊        | 2/11 [00:02<00:13,  1.47s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-mar_Deva/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-mar_Deva/train.mar_Deva
#  27%|██▋       | 3/11 [00:04<00:13,  1.72s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-guj_Gujr/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-guj_Gujr/train.guj_Gujr
#  45%|████▌     | 5/11 [00:06<00:07,  1.30s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-ben_Beng/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-ben_Beng/train.ben_Beng
#  55%|█████▍    | 6/11 [00:11<00:11,  2.23s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-tel_Telu/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-tel_Telu/train.tel_Telu
#  64%|██████▎   | 7/11 [00:14<00:10,  2.57s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/samanantar_v0.3_filtered/eng_Latn-tam_Taml/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-tam_Taml/labse_scores.txt
#  73%|███████▎  | 8/11 [00:18<00:08,  2.85s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-mal_Mlym/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-mal_Mlym/train.mal_Mlym
#  82%|████████▏ | 9/11 [00:21<00:05,  2.93s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-hin_Deva/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-hin_Deva/train.hin_Deva
#  91%|█████████ | 10/11 [00:28<00:04,  4.27s/it]
# BPCC/samanantar_v0.3_filtered/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/samanantar_v0.3_filtered/eng_Latn-kan_Knda/labse_scores.txt
# BPCC/samanantar_v0.3_filtered/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 11/11 [00:31<00:00,  2.85s/it]
#   0%|          | 0/13 [00:00<?, ?it/s]
# BPCC/samanantar_v2/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-ory_Orya/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-ory_Orya/train.ory_Orya
#   8%|▊         | 1/13 [00:03<00:38,  3.21s/it]
# BPCC/samanantar_v2/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-pan_Guru/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-pan_Guru/train.pan_Guru
#  15%|█▌        | 2/13 [00:11<01:05,  5.92s/it]
# BPCC/samanantar_v2/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-mar_Deva/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-mar_Deva/train.mar_Deva
#  23%|██▎       | 3/13 [00:24<01:33,  9.32s/it]
# BPCC/samanantar_v2/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-guj_Gujr/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-guj_Gujr/train.guj_Gujr
#  38%|███▊      | 5/13 [00:38<01:04,  8.02s/it]
# BPCC/samanantar_v2/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-ben_Beng/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-ben_Beng/train.ben_Beng
#  46%|████▌     | 6/13 [00:56<01:16, 10.93s/it]
# BPCC/samanantar_v2/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-tel_Telu/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-tel_Telu/train.tel_Telu
#  54%|█████▍    | 7/13 [01:10<01:11, 11.93s/it]
# BPCC/samanantar_v2/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/samanantar_v2/eng_Latn-tam_Taml/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-tam_Taml/labse_scores.txt
#  62%|██████▏   | 8/13 [01:23<01:01, 12.26s/it]
# BPCC/samanantar_v2/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-mal_Mlym/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-mal_Mlym/train.mal_Mlym
#  85%|████████▍ | 11/13 [01:41<00:17,  8.63s/it]
# BPCC/samanantar_v2/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-hin_Deva/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-hin_Deva/train.hin_Deva
#  92%|█████████▏| 12/13 [02:20<00:15, 15.11s/it]
# BPCC/samanantar_v2/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/samanantar_v2/eng_Latn-kan_Knda/labse_scores.txt
# BPCC/samanantar_v2/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 13/13 [02:38<00:00, 12.20s/it]
#   0%|          | 0/22 [00:00<?, ?it/s]
# BPCC/daily/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/daily/eng_Latn-ory_Orya/train.ory_Orya
#   5%|▍         | 1/22 [00:02<00:50,  2.42s/it]
# BPCC/daily/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/daily/eng_Latn-pan_Guru/train.pan_Guru
#   9%|▉         | 2/22 [00:05<00:52,  2.62s/it]
# BPCC/daily/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/daily/eng_Latn-mar_Deva/train.mar_Deva
#  18%|█▊        | 4/22 [00:07<00:32,  1.83s/it]
# BPCC/daily/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/daily/eng_Latn-guj_Gujr/train.guj_Gujr
#  27%|██▋       | 6/22 [00:10<00:26,  1.66s/it]
# BPCC/daily/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/daily/eng_Latn-ben_Beng/train.ben_Beng
#  55%|█████▍    | 12/22 [00:15<00:10,  1.02s/it]
# BPCC/daily/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/daily/eng_Latn-tel_Telu/train.tel_Telu
#  59%|█████▉    | 13/22 [00:18<00:12,  1.34s/it]
# BPCC/daily/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/daily/eng_Latn-tam_Taml/train.eng_Latn
#  68%|██████▊   | 15/22 [00:21<00:09,  1.36s/it]
# BPCC/daily/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/daily/eng_Latn-mal_Mlym/train.mal_Mlym
#  82%|████████▏ | 18/22 [00:24<00:05,  1.26s/it]
# BPCC/daily/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/daily/eng_Latn-hin_Deva/train.hin_Deva
#  86%|████████▋ | 19/22 [00:30<00:05,  1.92s/it]
# BPCC/daily/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/daily/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 22/22 [00:33<00:00,  1.51s/it]
#   0%|          | 0/7 [00:00<?, ?it/s]
# BPCC/massive/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/massive/eng_Latn-ben_Beng/train.ben_Beng
#  14%|█▍        | 1/7 [00:03<00:23,  3.93s/it]
# BPCC/massive/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/massive/eng_Latn-tel_Telu/train.tel_Telu
#  29%|██▊       | 2/7 [00:07<00:17,  3.44s/it]
# BPCC/massive/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/massive/eng_Latn-tam_Taml/train.eng_Latn
#  43%|████▎     | 3/7 [00:09<00:11,  2.87s/it]
# BPCC/massive/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/massive/eng_Latn-mal_Mlym/train.mal_Mlym
#  71%|███████▏  | 5/7 [00:11<00:04,  2.01s/it]
# BPCC/massive/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/massive/eng_Latn-hin_Deva/train.hin_Deva
#  86%|████████▌ | 6/7 [00:15<00:02,  2.55s/it]
# BPCC/massive/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/massive/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 7/7 [00:18<00:00,  2.65s/it]
#   0%|          | 0/22 [00:00<?, ?it/s]
# BPCC/wiki/eng_Latn-ory_Orya/train.eng_Latn
# BPCC/wiki/eng_Latn-ory_Orya/train.ory_Orya
# BPCC/wiki/eng_Latn-ory_Orya/domain.txt
#   5%|▍         | 1/22 [00:01<00:22,  1.09s/it]
# BPCC/wiki/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/wiki/eng_Latn-pan_Guru/domain.txt
# BPCC/wiki/eng_Latn-pan_Guru/train.pan_Guru
#   9%|▉         | 2/22 [00:02<00:31,  1.57s/it]
# BPCC/wiki/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/wiki/eng_Latn-mar_Deva/domain.txt
# BPCC/wiki/eng_Latn-mar_Deva/train.mar_Deva
#  18%|█▊        | 4/22 [00:05<00:26,  1.48s/it]
# BPCC/wiki/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/wiki/eng_Latn-guj_Gujr/train.guj_Gujr
# BPCC/wiki/eng_Latn-guj_Gujr/domain.txt
#  32%|███▏      | 7/22 [00:09<00:19,  1.28s/it]
# BPCC/wiki/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/wiki/eng_Latn-ben_Beng/train.ben_Beng
# BPCC/wiki/eng_Latn-ben_Beng/domain.txt
#  59%|█████▉    | 13/22 [00:13<00:07,  1.14it/s]
# BPCC/wiki/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/wiki/eng_Latn-tel_Telu/train.tel_Telu
# BPCC/wiki/eng_Latn-tel_Telu/domain.txt
#  64%|██████▎   | 14/22 [00:16<00:09,  1.15s/it]
# BPCC/wiki/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/wiki/eng_Latn-tam_Taml/train.eng_Latn
# BPCC/wiki/eng_Latn-tam_Taml/domain.txt
#  68%|██████▊   | 15/22 [00:18<00:09,  1.36s/it]
# BPCC/wiki/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/wiki/eng_Latn-mal_Mlym/domain.txt
# BPCC/wiki/eng_Latn-mal_Mlym/train.mal_Mlym
#  82%|████████▏ | 18/22 [00:21<00:04,  1.21s/it]
# BPCC/wiki/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/wiki/eng_Latn-hin_Deva/domain.txt
# BPCC/wiki/eng_Latn-hin_Deva/train.hin_Deva
#  86%|████████▋ | 19/22 [00:26<00:05,  1.77s/it]
# BPCC/wiki/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/wiki/eng_Latn-kan_Knda/domain.txt
# BPCC/wiki/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 22/22 [00:28<00:00,  1.31s/it]
#   0%|          | 0/16 [00:00<?, ?it/s]
# BPCC/ilci/eng_Latn-pan_Guru/train.eng_Latn
# BPCC/ilci/eng_Latn-pan_Guru/train.pan_Guru
#   6%|▋         | 1/16 [00:01<00:26,  1.78s/it]
# BPCC/ilci/eng_Latn-mar_Deva/train.eng_Latn
# BPCC/ilci/eng_Latn-mar_Deva/train.mar_Deva
#  12%|█▎        | 2/16 [00:03<00:28,  2.01s/it]
# BPCC/ilci/eng_Latn-guj_Gujr/train.eng_Latn
# BPCC/ilci/eng_Latn-guj_Gujr/train.guj_Gujr
#  25%|██▌       | 4/16 [00:06<00:17,  1.47s/it]
# BPCC/ilci/eng_Latn-ben_Beng/train.eng_Latn
# BPCC/ilci/eng_Latn-ben_Beng/train.ben_Beng
#  38%|███▊      | 6/16 [00:09<00:15,  1.54s/it]
# BPCC/ilci/eng_Latn-tel_Telu/train.eng_Latn
# BPCC/ilci/eng_Latn-tel_Telu/train.tel_Telu
#  44%|████▍     | 7/16 [00:11<00:15,  1.77s/it]
# BPCC/ilci/eng_Latn-tam_Taml/train.tam_Taml
# BPCC/ilci/eng_Latn-tam_Taml/train.eng_Latn
#  56%|█████▋    | 9/16 [00:14<00:10,  1.51s/it]
# BPCC/ilci/eng_Latn-mal_Mlym/train.eng_Latn
# BPCC/ilci/eng_Latn-mal_Mlym/train.mal_Mlym
#  75%|███████▌  | 12/16 [00:16<00:04,  1.18s/it]
# BPCC/ilci/eng_Latn-hin_Deva/train.eng_Latn
# BPCC/ilci/eng_Latn-hin_Deva/train.hin_Deva
#  81%|████████▏ | 13/16 [00:20<00:04,  1.64s/it]
# BPCC/ilci/eng_Latn-kan_Knda/train.eng_Latn
# BPCC/ilci/eng_Latn-kan_Knda/train.kan_Knda
# 100%|██████████| 16/16 [00:22<00:00,  1.42s/it]
# {'pan_Guru':                                                 eng_Latn  \
#  0                                     ! money's worth.\n
#  1                                  ! outside the city.\n
#  2      !' (which means 'Little girl, I say to you, ge...
#  3             """ """"You are the light of the world."\n
#  4      """ ""A leader takes people where they want to...
#  ...                                                  ...
#  71501  Perfumed oils or perfume related thought and t...
#  71502  Geranium and Osimum Filimund - karikum plants ...
#  71503  Kule method : - In this method a metal has a h...
#  71504  Extraction through solvents : - Despite being ...
#  71505  Enflurez at normal temperature : - This method...
#
#                                                  pan_Guru
#  0                                       ਪੈਸੇ ਦੀ ਕੀਮਤ !\n
#  1                                       ਸ਼ਹਿਰ ਦੇ ਬਾਹਰ!\n
#  2      """ (ਜਿਸਦਾ ਅਰਥ ਹੈ ""ਹੇ ਕੰਨਿਆ, ਮੈਂ ਤੈਨੂੰ ਆਖਦਾ ਹ...
#  3                         """ਤੁਸੀਂ ਦੁਨੀਆਂ ਦੇ ਚਾਨਣ ਹੋ।"\n
#  4      "1. ""ਇੱਕ ਲੀਡਰ ਉਹ ਲੋਕ ਲੈ ਜਾਂਦੇ ਹਨ ਜਿੱਥੇ ਉਹ ਚਾਹ...
#  ...                                                  ...
#  71501  ਸਗੰਧ ਤੇਲ ਅਤੇ ਇਤਰ ਸਬੰਧਿਤ ਵਿਚਾਰ ਅਤੇ ਇਹਨਾਂ ਨੂੰ ਪ੍...
#  71502  ਜਿਰੇਨਿਅਮ ਅਤੇ ਓਸਿਮਮ ਫਿਲਿਮੰਡ-ਕੈਰਿਕਮ ਬੂਟਿਆਂ ਤੋਂ ਖ...
#  71503  ਕਯੂਲ ਵਿਧੀ :- ਇਸ ਵਿਚ ਇਕ ਧਾਤੂ ਦੀ ਖੋਖਲੀ ਨਲੀ ਹੁੰਦੀ...
#  71504  ਘੋਲਕ ਦੁਆਰਾ ਨਿਚੋੜ :- ਇਹ ਵਿਧੀ ਚੰਗੀ ਹੋਣ ਦੇ ਬਾਵਜੂਦ...
#  71505  ਸਾਧਾਰਨ ਤਾਪਕ੍ਰਮ ਤੇ ਇਨਫ਼ਲੂਰੇਜ :- ਇਹ ਵਿਧੀਮੁੱਖ ਰੂਪ ...
#
#  [9960680 rows x 2 columns],
#  'ben_Beng':                                                  eng_Latn  \
#  0                               ! capital of the State.\n
#  1                                     ! detailed below.\n
#  2                                ! for the same reason.\n
#  3              ! his son had fallen in love with a girl\n
#  4       ! is a special character to bash, it is used t...
#  ...                                                   ...
#  123761  Artisan well This well is situated about 15 km...
#  123762  Artists from across the country converge on th...
#  123763       Aruvikkad waterfalls is also near Kundala.\n
#  123764  Aruvikkara Dam 16 kms away -This picturesque p...
#  123765  Arya Vaidya hospital, the main wing of Arya Va...
#
#                                                   ben_Beng
#  0                                      রাজ্যের রাজধানী!\n
#  1                                       নিচে বিস্তারিত.\n
#  2                                        সেই একই কারণে!\n
#  3                   আমার ছেলে একটি মেয়ের প্রেমে পড়েছে\n
#  4       bash এর একটি বিশেষ চরিত্র, এটি পূর্ববর্তী কমান...
#  ...                                                   ...
#  123761  কারূক কুয়ো ডাল্টনগঙ্জ থেকে প্রায় 15 কি.মি. দূ...
#  123762  সারা দেশ থেকে শিল্পীরা চিত্রানুগ দ্বীপের একই জ...
#  123763  অরভিক্কাদ জলপ্রপাতও কুন্দলার কাছাকাছি অবস্থিত ।\n
#  123764  ১৬ কিমি দুরে অরুভিক্কারাম বাঁধ রয়েছে-এই চিত্রা...
#  123765  আর্য ভায়দিয়া হাসপাতাল, আর্য ভায়দিয়া শালা দাতব্...
#
#  [33036854 rows x 2 columns],
#  'mal_Mlym':                                                 eng_Latn  \
#  0                          ! author's name is unknown.\n
#  1                    ! been in the army for six years.\n
#  2                    ! she had first come to the room.\n
#  3      !), most of the time installed as a software o...
#  4                       !--- This is the primary link.\n
#  ...                                                  ...
#  87922  Dizziness usually gets better by itself or is ...
#  87923  However, it can be a symptom of other disorder...
#  87924  Medicines may cause dizziness, or problems wit...
#  87925         Motion sickness can also make you dizzy.\n
#  87926                     There are many other causes.\n
#
#                                                  mal_Mlym
#  0                   ഗ്രന്ഥകാരന്റെ നാമധേയം അജ്ഞാതമാണു്.\n
#  1                  ആറു വർഷമായി സൈന്യത്തിൽ ചേർന്നിട്ട്.\n
#  2          ആദ്യം മുറിയിൽ മടങ്ങിയെത്തിയത് അവളായിരുന്നു.\n
#  3      ), സെർവറിലെ ഒരു സോഫ്റ്റ്വെയറായി ഇൻസ്റ്റാൾ ചെയ്...
#  4                               ഇത് - പ്രാഥമിക ലിങ്ക്.\n
#  ...                                                  ...
#  87922  തലകറക്കം സാധാരണയായി സ്വയം ഭേദമാവുന്നു അല്ലെങ്ക...
#  87923  എങ്കിലും , ഇത് മറ്റു രോഗങ്ങളുടെ ഒരു ലക്ഷണം ആയി...
#  87924  മരുന്നുകള്‍ തലകറക്കത്തിനോ നിങ്ങളുടെ ചെവിക്ക് പ...
#  87925  ചലനത്തിന്‍റെ രോഗത്തിനും നിങ്ങളുടെ തലചുറ്റിക്കു...
#  87926                   മറ്റ് അനേകം കാരണങ്ങള്‍ ഉണ്ട് .\n
#
#  [23736956 rows x 2 columns],
#  'mar_Deva':                                                  eng_Latn  \
#  0                                        ! 4 years ago.\n
#  1                               ! capital of the State.\n
#  2                                    ! mother's mother.\n
#  3                                    ! on this subject.\n
#  4                                  ! over the internet.\n
#  ...                                                   ...
#  116974  These are commonly eaten in the Southeastern U...
#  116975  The Brazilian dessert canjica is made by boili...
#  116976  Maize can also be harvested and consumed in th...
#  116977  Unripe maize must usually be cooked to become ...
#  116978  Sweet corn, a genetic variety that is high in ...
#
#                                                   mar_Deva
#  0                                     चार वर्षांपूर्वी!\n
#  1                                     राज्याची राजधानी!\n
#  2                                     . आईच्या मायेची .\n
#  3                                           या विषयावर!\n
#  4                                       इंटरनेट द्वारे!\n
#  ...                                                   ...
#  116974  हे दक्षिणपूर्व युनायटेड स्टेट्समध्ये सर्रासपणे...
#  116975  ब्राझिलियन मिष्टान्न कॅनजीका हे गोड दुधामध्ये ...
#  116976  जेंव्हा दाणे हे पूर्णपणे परिपक्व आणि मऊ असतात ...
#  116977  कच्चा मका सहसा रुचकर होण्यासाठी त्याला शिजवणे ...
#  116978  पिष्टसत्वामध्ये कमी आणि साखरेमध्ये उच्च असलेल्...
#
#  [19173549 rows x 2 columns],
#  'tam_Taml':                                                  eng_Latn  \
#  0                                        ! at her home.\n
#  1                                  ! at the same price.\n
#  2              ! i'm trying to have a pleasant evening.\n
#  3                                        ! in the city.\n
#  4                                   ! part of the city.\n
#  ...                                                   ...
#  120735  Artisan well This well is situated about 15 km...
#  120736  Artists from across the country converge on th...
#  120737       Aruvikkad waterfalls is also near Kundala.\n
#  120738  Aruvikkara Dam 16 kms away -This picturesque p...
#  120739  Arya Vaidya hospital, the main wing of Arya Va...
#
#                                                   tam_Taml
#  0                                   அவளது இல்லத்திற்கே!\n
#  1                               , அதுவும் அதே விலையில்!\n
#  2                       அழகான மாலைக்கு முயற்சிக்கிறேன்.\n
#  3                                          ! நகரத்தில்.\n
#  4                                     நகரின் ஒரு பகுதி!\n
#  ...                                                   ...
#  120735  ஆர்டி்ஷன் கிணறு - இந்த கிணறு டல்டோன்கஜியில் இர...
#  120736  நாடு முழுவதும் உள்ள கலைஞர்கள் இந்த அழகிய தீவில...
#  120737  அருவிகாடு நீர்வீழ்ச்சிகளும் குண்டலா அருகில் உள...
#  120738  அருவிகாரா அணை 16 கி.மீ தூரத்தில் - இந்த அழகிய ...
#  120739  ஆர்ய வைத்யா மருத்துவமனை , ஆர்ய வைத்யா கல்விக்க...
#
#  [20798208 rows x 2 columns],
#  'guj_Gujr':                                                  eng_Latn  \
#  0       ! - Input provided by the user is entered from...
#  1                                     ! at high school.\n
#  2                                     ! in high school.\n
#  3                                  ! over the internet.\n
#  4                              ! power can be obtained.\n
#  ...                                                   ...
#  107380       Aruvikkad waterfalls is also near Kundala.\n
#  107381  Aruvikkara Dam 16 kms away -This picturesque p...
#  107382  Arya Vaidya hospital, the main wing of Arya Va...
#  107383              It’s so nice to be in Goa in winter\n
#  107384  It’s so nice to sitting in the sun on the beac...
#
#                                                   guj_Gujr
#  0       - વપરાશકર્તા દ્વારા આપવામાં આવતી ઇનપુટ સામાન્ય...
#  1                                         ઉચ્ચ શાળામાં!\n
#  2                                         ઉચ્ચ શાળામાં!\n
#  3                                      ઇન્ટરનેટ મારફતે!\n
#  4                                બળ પ્રાપ્ત કરી શકે છે.\n
#  ...                                                   ...
#  107380  માધવન નાયર ફાઉન્ડેશન તે ત્યાંના પ્રકારનું કેરળ...
#  107381  ઈ.સ. ૧૯૩૧ થી ૪૪માં બનેલ આર્ટ ડેકો પેલેસ એ યુરો...
#  107382  અહીંના લોકો, કલા, સંસ્કૃતિ, સંગીતમાં એટલાબધા ન...
#  107383  જો આ સ્થળની તમે નિંદા કરતા હો કે વખોડતા હો તો ...
#  107384               તેના ઘરને સારું એવું કમ્પાઉંડ નથી.\n
#
#  [20808391 rows x 2 columns],
#  'tel_Telu':                                                 eng_Latn  \
#  0                                   ! and her husband.\n
#  1                      ! but they could never be used.\n
#  2                                ! change at any time.\n
#  3                                 ! explained to them.\n
#  4                           ! is as small as possible.\n
#  ...                                                  ...
#  73564  Perfumed oils or perfume related thought and t...
#  73565  Geranium and Osimum Filimund - karikum plants ...
#  73566  Kule method : - In this method a metal has a h...
#  73567  Extraction through solvents : - Despite being ...
#  73568  Enflurez at normal temperature : - This method...
#
#                                                  tel_Telu
#  0                                      మరియు ఆమె భర్త!\n
#  1                      కాని వాటిని ఎన్నడూ ఉపయోగించలేం.\n
#  2                               ఏ సమయంలోనైనా మార్చండి.\n
#  3                                   వారికి వివరించారు.\n
#  4                                     వీలైనంత చిన్నది.\n
#  ...                                                  ...
#  73564  సుగంధతైలాలు మరియు అత్తరు సంబంధించిన ఆలోచన అలాగ...
#  73565  జిరోనియం మరియు ఓరిమం ఫిలమండ్ - కైరికం మొక్కల న...
#  73566  దీనిలో ఒక ధాతువు యొక్క బోలుగా వుండే గొట్టం ఉంట...
#  73567  ద్రావకాల ద్వారా తీయడం ఈ పద్ధతి మంచిదైనప్పటికి ...
#  73568  సాధారణ ఉష్ణం మీద తీయడం ఈ పద్ధతి ముఖ్యంగా మల్లె...
#
#  [23508834 rows x 2 columns],
#  'hin_Deva':                                                  eng_Latn  \
#  0                     ! available throughout the world.\n
#  1       ! concerns, suggestions, or anything you would...
#  2                                   ! days of the week.\n
#  3                         ! expulsion from the country.\n
#  4                                      ! is 60 seconds.\n
#  ...                                                   ...
#  165644  After plucking the fruits they are filled in w...
#  165645  Under this initiative there is technology tran...
#  165646  India occupies ninth position in large retail ...
#  165647  Why suicide news of the farmers are coming fro...
#  165648  They , getting away from the whole calculation...
#
#                                                   hin_Deva
#  0                                 उपलब्ध दुनिया भर में!\n
#  1       आपके जो भी सवाल, सुझाव या कोई अन्य बात जो आप ह...
#  2                                       सप्ताह के दिन !\n
#  3                                     देश से निष्कासित!\n
#  4                                          ← 60 सेकेंड!\n
#  ...                                                   ...
#  165644  फलों को तोड़ने के पश्चात् लकड़ी की पेटियों में भ...
#  165645  इस पहल के तहत भारत के कृषि क्षेत्र के लिए टेक्...
#  165646  बड़े खुदरा व्यापार विपणन क्षेत्रों में भारत को ...
#  165647  क्यों देश के अलग-अलग कोनों से किसानों की आत्मह...
#  165648  वे तमाम गणितों से दूर होकर एक ही बात कहते हैं ...
#
#  [39333242 rows x 2 columns],
#  'kan_Knda':                                                 eng_Latn  \
#  0      ! - Input provided by the user is entered from...
#  1                                   ! and her husband.\n
#  2                                       ! more easily.\n
#  3                                   ! not forthcoming.\n
#  4      ! this software has already been installed on ...
#  ...                                                  ...
#  76534  Perfumed oils or perfume related thought and t...
#  76535  Geranium and Osimum Filimund - karikum plants ...
#  76536  Kule method : - In this method a metal has a h...
#  76537  Extraction through solvents : - Despite being ...
#  76538  Enflurez at normal temperature : - This method...
#
#                                                  kan_Knda
#  0      - ಬಳಕೆದಾರರಿಂದ ಒದಗಿಸಲಾದ ಇನ್ಪುಟ್ ಅನ್ನು ಸಾಮಾನ್ಯ ಬ...
#  1                                       ಮತ್ತು ಅವಳ ಪತಿ!\n
#  2                                     ಹೆಚ್ಚು ಸುಲಭವಾಗಿ!\n
#  3                                 ಮುಂಬರುವ ಮಾಡುವುದಿಲ್ಲ.\n
#  4      ನಿಮ್ಮ ಕಂಪ್ಯೂಟರ್ನಲ್ಲಿ ಈ ಅನ್ರ್ಯಾಕಿಂಗ್ ಸಾಫ್ಟ್ವೇರ್...
#  ...                                                  ...
#  76534  ಸುಗಂಧದ ಎಣ್ಣೆ ಹಾಗು ಇತ್ರಕ್ಕೆ ಸಂಬಂಧಿತ ವಿಷಯ ಮತ್ತು ...
#  76535  ಜೆರೇನಿಯಂ ಅಥವಾ ಆಸಿಮಂ ಫಿಲಿಮಂಡ್–ಕೆರಿಕಂ ಸಸ್ಯಗಳಿಂದ ...
#  76536  ಕ್ಯೂಲ್ ವಿಧಾನ :- ಇದರಲ್ಲಿ ಲೋಹದ ಒಂದು ಟೊಳ್ಳು ಕೊಳವೆ...
#  76537  ದ್ರಾವಣದ ಮೂಲಕ ಬೇರ್ಪಡಿಸುವಿಕೆ :- ಈ ವಿಧಾನವು ಉತ್ತಮ ...
#  76538  ಸಾಧಾರಣ ಉಷ್ಣಾಂಶದಲ್ಲಿ ಇನ್ಫ್ಲುರೇಜ :- ಈ ವಿಧಾನವನ್ನು...
#
#  [23578123 rows x 2 columns],
#  'ory_Orya':                                                 eng_Latn  \
#  0                                       ! at the door.\n
#  1                                   ! father's office.\n
#  2               """ Active participation of students."\n
#  3      """ It appears from the statements issued by t...
#  4      """ ""All this I have spoken while still with ...
#  ...                                                  ...
#  33722  “What shall I do? Nobody will help me now,” wa...
#  33723  It was the best time the family had enjoyed si...
#  33724  Soon the news spread far and wide. Sringeri Sr...
#  33725  He waved his hands at the drivers to stop the ...
#  33726  The ribbit ribbit of the frogs was noisy. The ...
#
#                                                  ory_Orya
#  0                                          ! କବାଟ ରେ ।\n
#  1                                      ବାପା ଙ୍କ ଅଫିସ ।\n
#  2                 => ଶିକ୍ଷାର୍ଥୀଙ୍କର ସକ୍ରିୟ ଅଂଶଗ୍ରହଣ. .\n
#  3      ଉଭୟ ସେନା ଦ୍ୱାରା ଜାରି ବିବୃତ୍ତିରୁ ଏହା ଜଣାପଡିଛି ଯ...
#  4      "25 ""ମୁଁ ତୁମ୍ଭ ସହିତ ଥିବା ସମୟେର ଏହି ସବୁ କଥା ତୁ...
#  ...                                                  ...
#  33722  "ମୁଁ ଏବେ କଅଣ କରିବି? କେହି ମୋତେ ସାହାଯ୍ୟ କରିବେ ନା...
#  33723  ତାଲାବନ୍ଦ ହେବା ଦିନ ଠାରୁ, ଏହି ସମୟଟି ସାରା ପରିବାର ...
#  33724  ଅତିଶୀଘ୍ର ଏ ଖବର ଦୂର ଦୂରାନ୍ତରେ ପ୍ରଚାର ହେଇଗଲା। ଶ୍...
#  33725  ସେ ହାତ ହଲେଇ ଡ୍ରାଇଭର ମାନଙ୍କୁ ଏ ଶବ୍ଦ ବନ୍ଦ କରିବାକ...
#  33726  ବେଙ୍ଗମାନଙ୍କର କେଁ-କଟର ରଡି ଗୋଳମାଳ କଲା। ଝିଙ୍କାରି ...
#
#  [5918966 rows x 2 columns]}

# %%
# ambiguos relations:
ambiguos = [
    # 'uncle', 'aunt', 'grandfather', 'grandmother',
    #          'brother in law', 'brother-in-law', 'sister in law', 'sister-in-law',
             'cousin', 'nephew', 'niece', 'child', 'children', 
             # singular possessive
             'uncle\'s', 'aunt\'s', 'grandfather\'s', 'grandmother\'s', 
                'brother in law\'s', 'brother-in-law\'s', 'sister in law\'s', 'sister-in-law\'s',
                'cousin\'s', 'nephew\'s', 'niece\'s', 'child\'s', 'children\'s',
                # plural possessive
                'uncles\'', 'aunts\'', 'grandfathers\'', 'grandmothers\'',
                'brothers in law\'s', 'brothers-in-law\'s', 'sisters in law\'s', 'sisters-in-law\'s',
                'cousins\'', 'nephews\'', 'nieces\'', 
                # plural
                'uncles', 'aunts', 'grandfathers', 'grandmothers',
                'brothers in law', 'brothers-in-law', 'sisters in law', 'sisters-in-law',
                'cousins', 'nephews', 'nieces',

             ]

# %%
# remove duplicates

# do for all languages in df_list
for lang in df_list:
    df_list[lang] = df_list[lang][~df_list[lang].index.duplicated()]
    print(lang, df_list[lang].shape)
    # save the dataframes
    df_list[lang].to_csv('BPCC_'+lang+'.csv', index=False)
# Out:
# pan_Guru (6275797, 2)
# ben_Beng (16055075, 2)
# mal_Mlym (12378602, 2)
# mar_Deva (10806011, 2)
# tam_Taml (9690253, 2)
# guj_Gujr (11630301, 2)
# tel_Telu (11100046, 2)
# hin_Deva (27187805, 2)
# kan_Knda (12500959, 2)
# ory_Orya (2863078, 2)

# %%
df_list_copy = df_list.copy() # make a copy of the original dataframes to save them for later use

# %% [markdown]
# ## Filtering Dataframes as per English Ambiguous Relations

# %%
# tqdm progress bar for the for loop on df_list
# import tqdm
df_dict = {} # this dictionary will have key as language from df_list and value as another dictionary.
# this inner dictionary will have key as the word from ambiguos and value as the filtered dataframe containing that word in the english column. 

# using all ambiguous words make a regex pattern and filter the dataframes
# do for all languages in df_list

regex_pattern = '|'.join(ambiguos)

for lang in tqdm.tqdm(df_list):
    df = df_list[lang]
    df_dict[lang] = {}
    for word in ambiguos:
        df_dict[lang][word] = df[df['eng_Latn'].str.contains(word, case=False, )]
        print(lang, word, df_dict[lang][word].shape)
        df_dict[lang][word].to_csv(f'{lang}_{word}_bpcc.csv', index=False)
    
    # .to_csv(f'{lang}_bpcc.csv', index=False)

df_dict
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# pan_Guru cousin (627, 2)
# pan_Guru nephew (461, 2)
# pan_Guru niece (208, 2)
# pan_Guru child (82880, 2)
# pan_Guru children (52452, 2)
# pan_Guru uncle's (14, 2)
# pan_Guru aunt's (8, 2)
# pan_Guru grandfather's (23, 2)
# pan_Guru grandmother's (39, 2)
# pan_Guru brother in law's (0, 2)
# pan_Guru brother-in-law's (2, 2)
# pan_Guru sister in law's (0, 2)
# pan_Guru sister-in-law's (4, 2)
# pan_Guru cousin's (15, 2)
# pan_Guru nephew's (4, 2)
# pan_Guru niece's (3, 2)
# pan_Guru child's (2399, 2)
# pan_Guru children's (3559, 2)
# pan_Guru uncles' (0, 2)
# pan_Guru aunts' (0, 2)
# pan_Guru grandfathers' (0, 2)
# pan_Guru grandmothers' (0, 2)
# pan_Guru brothers in law's (0, 2)
# pan_Guru brothers-in-law's (0, 2)
# pan_Guru sisters in law's (0, 2)
# pan_Guru sisters-in-law's (0, 2)
# pan_Guru cousins' (0, 2)
# pan_Guru nephews' (0, 2)
# pan_Guru nieces' (0, 2)
# pan_Guru uncles (106, 2)
# pan_Guru aunts (107, 2)
# pan_Guru grandfathers (50, 2)
# pan_Guru grandmothers (73, 2)
# pan_Guru brothers in law (1, 2)
# pan_Guru brothers-in-law (13, 2)
# pan_Guru sisters in law (0, 2)
# pan_Guru sisters-in-law (9, 2)
# pan_Guru cousins (198, 2)
# pan_Guru nephews (47, 2)
#  10%|█         | 1/10 [04:19<38:58, 259.84s/it]
# pan_Guru nieces (24, 2)
# ben_Beng cousin (909, 2)
# ben_Beng nephew (425, 2)
# ben_Beng niece (291, 2)
# ben_Beng child (167661, 2)
# ben_Beng children (100246, 2)
# ben_Beng uncle's (132, 2)
# ben_Beng aunt's (44, 2)
# ben_Beng grandfather's (301, 2)
# ben_Beng grandmother's (256, 2)
# ben_Beng brother in law's (0, 2)
# ben_Beng brother-in-law's (5, 2)
# ben_Beng sister in law's (1, 2)
# ben_Beng sister-in-law's (6, 2)
# ben_Beng cousin's (47, 2)
# ben_Beng nephew's (12, 2)
# ben_Beng niece's (13, 2)
# ben_Beng child's (6817, 2)
# ben_Beng children's (11038, 2)
# ben_Beng uncles' (1, 2)
# ben_Beng aunts' (0, 2)
# ben_Beng grandfathers' (0, 2)
# ben_Beng grandmothers' (1, 2)
# ben_Beng brothers in law's (0, 2)
# ben_Beng brothers-in-law's (0, 2)
# ben_Beng sisters in law's (0, 2)
# ben_Beng sisters-in-law's (0, 2)
# ben_Beng cousins' (1, 2)
# ben_Beng nephews' (0, 2)
# ben_Beng nieces' (0, 2)
# ben_Beng uncles (192, 2)
# ben_Beng aunts (211, 2)
# ben_Beng grandfathers (47, 2)
# ben_Beng grandmothers (94, 2)
# ben_Beng brothers in law (1, 2)
# ben_Beng brothers-in-law (10, 2)
# ben_Beng sisters in law (1, 2)
# ben_Beng sisters-in-law (15, 2)
# ben_Beng cousins (229, 2)
# ben_Beng nephews (64, 2)
#  20%|██        | 2/10 [12:49<54:14, 406.81s/it]
# ben_Beng nieces (50, 2)
# mal_Mlym cousin (1207, 2)
# mal_Mlym nephew (634, 2)
# mal_Mlym niece (316, 2)
# mal_Mlym child (168945, 2)
# mal_Mlym children (110541, 2)
# mal_Mlym uncle's (227, 2)
# mal_Mlym aunt's (64, 2)
# mal_Mlym grandfather's (179, 2)
# mal_Mlym grandmother's (238, 2)
# mal_Mlym brother in law's (0, 2)
# mal_Mlym brother-in-law's (5, 2)
# mal_Mlym sister in law's (0, 2)
# mal_Mlym sister-in-law's (3, 2)
# mal_Mlym cousin's (61, 2)
# mal_Mlym nephew's (11, 2)
# mal_Mlym niece's (8, 2)
# mal_Mlym child's (5414, 2)
# mal_Mlym children's (8248, 2)
# mal_Mlym uncles' (3, 2)
# mal_Mlym aunts' (0, 2)
# mal_Mlym grandfathers' (0, 2)
# mal_Mlym grandmothers' (1, 2)
# mal_Mlym brothers in law's (0, 2)
# mal_Mlym brothers-in-law's (0, 2)
# mal_Mlym sisters in law's (0, 2)
# mal_Mlym sisters-in-law's (0, 2)
# mal_Mlym cousins' (2, 2)
# mal_Mlym nephews' (1, 2)
# mal_Mlym nieces' (0, 2)
# mal_Mlym uncles (231, 2)
# mal_Mlym aunts (283, 2)
# mal_Mlym grandfathers (64, 2)
# mal_Mlym grandmothers (132, 2)
# mal_Mlym brothers in law (1, 2)
# mal_Mlym brothers-in-law (8, 2)
# mal_Mlym sisters in law (0, 2)
# mal_Mlym sisters-in-law (10, 2)
# mal_Mlym cousins (296, 2)
# mal_Mlym nephews (64, 2)
#  30%|███       | 3/10 [19:48<48:07, 412.54s/it]
# mal_Mlym nieces (46, 2)
# mar_Deva cousin (836, 2)
# mar_Deva nephew (648, 2)
# mar_Deva niece (232, 2)
# mar_Deva child (126951, 2)
# mar_Deva children (82564, 2)
# mar_Deva uncle's (60, 2)
# mar_Deva aunt's (32, 2)
# mar_Deva grandfather's (145, 2)
# mar_Deva grandmother's (85, 2)
# mar_Deva brother in law's (0, 2)
# mar_Deva brother-in-law's (2, 2)
# mar_Deva sister in law's (0, 2)
# mar_Deva sister-in-law's (6, 2)
# mar_Deva cousin's (22, 2)
# mar_Deva nephew's (4, 2)
# mar_Deva niece's (9, 2)
# mar_Deva child's (3964, 2)
# mar_Deva children's (6986, 2)
# mar_Deva uncles' (0, 2)
# mar_Deva aunts' (0, 2)
# mar_Deva grandfathers' (1, 2)
# mar_Deva grandmothers' (0, 2)
# mar_Deva brothers in law's (0, 2)
# mar_Deva brothers-in-law's (0, 2)
# mar_Deva sisters in law's (0, 2)
# mar_Deva sisters-in-law's (0, 2)
# mar_Deva cousins' (0, 2)
# mar_Deva nephews' (0, 2)
# mar_Deva nieces' (0, 2)
# mar_Deva uncles (127, 2)
# mar_Deva aunts (197, 2)
# mar_Deva grandfathers (58, 2)
# mar_Deva grandmothers (88, 2)
# mar_Deva brothers in law (0, 2)
# mar_Deva brothers-in-law (16, 2)
# mar_Deva sisters in law (0, 2)
# mar_Deva sisters-in-law (6, 2)
# mar_Deva cousins (239, 2)
# mar_Deva nephews (31, 2)
#  40%|████      | 4/10 [25:30<38:27, 384.59s/it]
# mar_Deva nieces (19, 2)
# tam_Taml cousin (812, 2)
# tam_Taml nephew (331, 2)
# tam_Taml niece (186, 2)
# tam_Taml child (123647, 2)
# tam_Taml children (81998, 2)
# tam_Taml uncle's (146, 2)
# tam_Taml aunt's (48, 2)
# tam_Taml grandfather's (218, 2)
# tam_Taml grandmother's (125, 2)
# tam_Taml brother in law's (0, 2)
# tam_Taml brother-in-law's (6, 2)
# tam_Taml sister in law's (1, 2)
# tam_Taml sister-in-law's (6, 2)
# tam_Taml cousin's (44, 2)
# tam_Taml nephew's (14, 2)
# tam_Taml niece's (6, 2)
# tam_Taml child's (3601, 2)
# tam_Taml children's (6523, 2)
# tam_Taml uncles' (0, 2)
# tam_Taml aunts' (0, 2)
# tam_Taml grandfathers' (0, 2)
# tam_Taml grandmothers' (1, 2)
# tam_Taml brothers in law's (0, 2)
# tam_Taml brothers-in-law's (0, 2)
# tam_Taml sisters in law's (0, 2)
# tam_Taml sisters-in-law's (0, 2)
# tam_Taml cousins' (2, 2)
# tam_Taml nephews' (0, 2)
# tam_Taml nieces' (0, 2)
# tam_Taml uncles (155, 2)
# tam_Taml aunts (188, 2)
# tam_Taml grandfathers (53, 2)
# tam_Taml grandmothers (43, 2)
# tam_Taml brothers in law (0, 2)
# tam_Taml brothers-in-law (4, 2)
# tam_Taml sisters in law (0, 2)
# tam_Taml sisters-in-law (7, 2)
# tam_Taml cousins (215, 2)
# tam_Taml nephews (45, 2)
#  50%|█████     | 5/10 [30:47<30:01, 360.24s/it]
# tam_Taml nieces (40, 2)
# guj_Gujr cousin (1736, 2)
# guj_Gujr nephew (803, 2)
# guj_Gujr niece (430, 2)
# guj_Gujr child (165507, 2)
# guj_Gujr children (100357, 2)
# guj_Gujr uncle's (96, 2)
# guj_Gujr aunt's (36, 2)
# guj_Gujr grandfather's (139, 2)
# guj_Gujr grandmother's (155, 2)
# guj_Gujr brother in law's (2, 2)
# guj_Gujr brother-in-law's (6, 2)
# guj_Gujr sister in law's (1, 2)
# guj_Gujr sister-in-law's (11, 2)
# guj_Gujr cousin's (48, 2)
# guj_Gujr nephew's (14, 2)
# guj_Gujr niece's (5, 2)
# guj_Gujr child's (7062, 2)
# guj_Gujr children's (8664, 2)
# guj_Gujr uncles' (0, 2)
# guj_Gujr aunts' (0, 2)
# guj_Gujr grandfathers' (0, 2)
# guj_Gujr grandmothers' (1, 2)
# guj_Gujr brothers in law's (0, 2)
# guj_Gujr brothers-in-law's (0, 2)
# guj_Gujr sisters in law's (0, 2)
# guj_Gujr sisters-in-law's (0, 2)
# guj_Gujr cousins' (1, 2)
# guj_Gujr nephews' (0, 2)
# guj_Gujr nieces' (0, 2)
# guj_Gujr uncles (196, 2)
# guj_Gujr aunts (374, 2)
# guj_Gujr grandfathers (72, 2)
# guj_Gujr grandmothers (156, 2)
# guj_Gujr brothers in law (0, 2)
# guj_Gujr brothers-in-law (14, 2)
# guj_Gujr sisters in law (1, 2)
# guj_Gujr sisters-in-law (14, 2)
# guj_Gujr cousins (534, 2)
# guj_Gujr nephews (94, 2)
#  60%|██████    | 6/10 [38:55<26:54, 403.51s/it]
# guj_Gujr nieces (70, 2)
# tel_Telu cousin (1427, 2)
# tel_Telu nephew (499, 2)
# tel_Telu niece (245, 2)
# tel_Telu child (150536, 2)
# tel_Telu children (100862, 2)
# tel_Telu uncle's (84, 2)
# tel_Telu aunt's (37, 2)
# tel_Telu grandfather's (79, 2)
# tel_Telu grandmother's (109, 2)
# tel_Telu brother in law's (0, 2)
# tel_Telu brother-in-law's (4, 2)
# tel_Telu sister in law's (0, 2)
# tel_Telu sister-in-law's (3, 2)
# tel_Telu cousin's (45, 2)
# tel_Telu nephew's (10, 2)
# tel_Telu niece's (3, 2)
# tel_Telu child's (4956, 2)
# tel_Telu children's (9366, 2)
# tel_Telu uncles' (0, 2)
# tel_Telu aunts' (0, 2)
# tel_Telu grandfathers' (0, 2)
# tel_Telu grandmothers' (0, 2)
# tel_Telu brothers in law's (0, 2)
# tel_Telu brothers-in-law's (0, 2)
# tel_Telu sisters in law's (0, 2)
# tel_Telu sisters-in-law's (0, 2)
# tel_Telu cousins' (5, 2)
# tel_Telu nephews' (0, 2)
# tel_Telu nieces' (1, 2)
# tel_Telu uncles (182, 2)
# tel_Telu aunts (269, 2)
# tel_Telu grandfathers (42, 2)
# tel_Telu grandmothers (76, 2)
# tel_Telu brothers in law (0, 2)
# tel_Telu brothers-in-law (11, 2)
# tel_Telu sisters in law (0, 2)
# tel_Telu sisters-in-law (6, 2)
# tel_Telu cousins (449, 2)
# tel_Telu nephews (74, 2)
#  70%|███████   | 7/10 [46:28<20:59, 419.68s/it]
# tel_Telu nieces (51, 2)
# hin_Deva cousin (4175, 2)
# hin_Deva nephew (4476, 2)
# hin_Deva niece (1474, 2)
# hin_Deva child (286203, 2)
# hin_Deva children (186655, 2)
# hin_Deva uncle's (139, 2)
# hin_Deva aunt's (37, 2)
# hin_Deva grandfather's (279, 2)
# hin_Deva grandmother's (194, 2)
# hin_Deva brother in law's (0, 2)
# hin_Deva brother-in-law's (8, 2)
# hin_Deva sister in law's (1, 2)
# hin_Deva sister-in-law's (14, 2)
# hin_Deva cousin's (78, 2)
# hin_Deva nephew's (32, 2)
# hin_Deva niece's (21, 2)
# hin_Deva child's (6491, 2)
# hin_Deva children's (10227, 2)
# hin_Deva uncles' (1, 2)
# hin_Deva aunts' (1, 2)
# hin_Deva grandfathers' (0, 2)
# hin_Deva grandmothers' (1, 2)
# hin_Deva brothers in law's (0, 2)
# hin_Deva brothers-in-law's (0, 2)
# hin_Deva sisters in law's (0, 2)
# hin_Deva sisters-in-law's (0, 2)
# hin_Deva cousins' (1, 2)
# hin_Deva nephews' (0, 2)
# hin_Deva nieces' (0, 2)
# hin_Deva uncles (361, 2)
# hin_Deva aunts (829, 2)
# hin_Deva grandfathers (126, 2)
# hin_Deva grandmothers (160, 2)
# hin_Deva brothers in law (1, 2)
# hin_Deva brothers-in-law (50, 2)
# hin_Deva sisters in law (1, 2)
# hin_Deva sisters-in-law (72, 2)
# hin_Deva cousins (1032, 2)
# hin_Deva nephews (220, 2)
#  80%|████████  | 8/10 [1:04:59<21:19, 640.00s/it]
# hin_Deva nieces (104, 2)
# kan_Knda cousin (1771, 2)
# kan_Knda nephew (783, 2)
# kan_Knda niece (408, 2)
# kan_Knda child (182736, 2)
# kan_Knda children (119475, 2)
# kan_Knda uncle's (91, 2)
# kan_Knda aunt's (49, 2)
# kan_Knda grandfather's (128, 2)
# kan_Knda grandmother's (251, 2)
# kan_Knda brother in law's (2, 2)
# kan_Knda brother-in-law's (12, 2)
# kan_Knda sister in law's (0, 2)
# kan_Knda sister-in-law's (6, 2)
# kan_Knda cousin's (41, 2)
# kan_Knda nephew's (20, 2)
# kan_Knda niece's (4, 2)
# kan_Knda child's (6252, 2)
# kan_Knda children's (10386, 2)
# kan_Knda uncles' (0, 2)
# kan_Knda aunts' (0, 2)
# kan_Knda grandfathers' (0, 2)
# kan_Knda grandmothers' (1, 2)
# kan_Knda brothers in law's (0, 2)
# kan_Knda brothers-in-law's (0, 2)
# kan_Knda sisters in law's (0, 2)
# kan_Knda sisters-in-law's (0, 2)
# kan_Knda cousins' (5, 2)
# kan_Knda nephews' (0, 2)
# kan_Knda nieces' (0, 2)
# kan_Knda uncles (221, 2)
# kan_Knda aunts (337, 2)
# kan_Knda grandfathers (67, 2)
# kan_Knda grandmothers (159, 2)
# kan_Knda brothers in law (2, 2)
# kan_Knda brothers-in-law (10, 2)
# kan_Knda sisters in law (0, 2)
# kan_Knda sisters-in-law (8, 2)
# kan_Knda cousins (600, 2)
# kan_Knda nephews (105, 2)
#  90%|█████████ | 9/10 [1:13:52<10:06, 606.46s/it]
# kan_Knda nieces (78, 2)
# ory_Orya cousin (167, 2)
# ory_Orya nephew (84, 2)
# ory_Orya niece (50, 2)
# ory_Orya child (39738, 2)
# ory_Orya children (24809, 2)
# ory_Orya uncle's (28, 2)
# ory_Orya aunt's (9, 2)
# ory_Orya grandfather's (45, 2)
# ory_Orya grandmother's (50, 2)
# ory_Orya brother in law's (0, 2)
# ory_Orya brother-in-law's (1, 2)
# ory_Orya sister in law's (0, 2)
# ory_Orya sister-in-law's (0, 2)
# ory_Orya cousin's (8, 2)
# ory_Orya nephew's (3, 2)
# ory_Orya niece's (2, 2)
# ory_Orya child's (1203, 2)
# ory_Orya children's (1794, 2)
# ory_Orya uncles' (1, 2)
# ory_Orya aunts' (0, 2)
# ory_Orya grandfathers' (0, 2)
# ory_Orya grandmothers' (2, 2)
# ory_Orya brothers in law's (0, 2)
# ory_Orya brothers-in-law's (0, 2)
# ory_Orya sisters in law's (0, 2)
# ory_Orya sisters-in-law's (0, 2)
# ory_Orya cousins' (0, 2)
# ory_Orya nephews' (0, 2)
# ory_Orya nieces' (0, 2)
# ory_Orya uncles (24, 2)
# ory_Orya aunts (34, 2)
# ory_Orya grandfathers (14, 2)
# ory_Orya grandmothers (14, 2)
# ory_Orya brothers in law (0, 2)
# ory_Orya brothers-in-law (2, 2)
# ory_Orya sisters in law (0, 2)
# ory_Orya sisters-in-law (3, 2)
# ory_Orya cousins (34, 2)
# ory_Orya nephews (7, 2)
# 100%|██████████| 10/10 [1:15:22<00:00, 452.20s/it]
# ory_Orya nieces (4, 2)
# {'pan_Guru': {'cousin':                                                   eng_Latn  \
#   24229              """May I ask who this 'cousin' is?"""\n
#   24829                            """My cousin's a girl."\n
#   26741           """Oh, cousin...what happened to you?"""\n
#   28148    """Play is important for cats,"" says Mark Cou...
#   73760    "Both are distant cousins of the English words...
#   ...                                                    ...
#   6234581       After that we headed to my cousin's house.\n
#   6244791  Youth commits suicide after killing cousin sis...
#   6258479            Three cousins killed in road accident\n
#   6260259  Abhay Deol is nephew of veteran actor Dharmend...
#   6270199  Rhea's sister Sonam Kapoor and her husband, An...
#
#                                                     pan_Guru
#   24229    """ਕੀ ਮੈ ਇਹ ਪੁੱਛ ਸਕਦਾ ਹਾਂ ਕਿ ਇਹ ਸਵਾਲ ਪੁੱਛਣ ਵਾਲ...
#   24829                               """ਮੇਰੇ ਇੱਕ ਕੁੜੀ ਐ।"\n
#   26741         """ਹੈ ਮੇਰੀ ਕਮਲੀ ਭੈਣ. . . ਤੈਨੂੰ ਕੀ ਹੋ ਗਿਆ."\n
#   28148    """ਬਿੱਲੀਆਂ ਲਈ ਖੇਡਣਾ ਮਹੱਤਵਪੂਰਣ ਹੈ,"" ਮਾਰਕ ਕਜ਼ਨਜ...
#   73760    "ਦੋਨੋ, ""ਸਹੀ"" ਅਤੇ ""ਸਿੱਧੇ"" ਅੰਗਰੇਜ਼ੀ ਦੇ ਦੂਰ ਦ...
#   ...                                                    ...
#   6234581  ਇਸ ਮਗਰੋਂ ਉਹ ਨੇੜੇ ਰਹਿੰਦੀ ਸਾਡੀ ਮਾਸੀ ਦੇ ਘਰ ਚਲਾ ਗਿ...
#   6244791  ਜ਼ਮੀਨੀ ਝਗੜੇ ਚ ਨੌਜਵਾਨ ਨੇ ਅਪਣੀ ਹੀ ਚਚੇਰੀ ਭੈਣ ਦੀ ਕਰ...
#   6258479     ਸੜਕ ਹਾਦਸੇ ਵਿੱਚ ਤਿੰਨ ਸਕੇ ਭਰਾਵਾਂ ਦੀ ਮੌਤ ਹੋ ਗਈ।\n
#   6260259  ਉਹ ਫ਼ਿਲਮ ਅਦਾਕਾਰ ਧਰਮਿੰਦਰ ਦੇ ਭਤੀਜੇ ਅਤੇ ਈਸ਼ਾ ਦਿਓਲ...
#   6270199  ਜਿਸ ਵਿੱਚ ਰਿਆ ਕਪੂਰ, ਅਨਿਲ ਕਪੂਰ, ਸੁਨੀਤਾ ਕਪੂਰ, ਸੋਨ...
#
#   [627 rows x 2 columns],
#   'nephew':                                                   eng_Latn  \
#   10926                        """He ain't your nephew!"""\n
#   16010    """I look like Morgan Freeman's nephew,"" Kevi...
#   34521    """Then he brought back all the goods, and als...
#   70640    "And Richard III actually usurped the throne f...
#   80915    "Google derived its name from the word ""googo...
#   ...                                                    ...
#   6227497           BSP leader, nephew shot dead in Bijnor\n
#   6235418  Sanji Ram was allegedly joined by special poli...
#   6260259  Abhay Deol is nephew of veteran actor Dharmend...
#   6264190                                      Nephew: Ha!\n
#   6266770  “Saddened to know about the demise of Abhay Si...
#
#                                                     pan_Guru
#   10926                      """ ਉਹ ਤੁਹਾਡਾ ਸਮੀਹਾ ਨਹੀਂ ਹੈ!"\n
#   16010    'ਮੈਂ ਮੋਰਗਨ ਫ੍ਰੀਮੈਨ ਦੇ ਭਤੀਜੇ ਵਰਗਾ ਦਿਖਦਾ ਹਾਂ,' ਕ...
#   34521    ਉਹ ਸਾਰੇ ਮਾਲ ਧਨ ਨੂੰ, ਅਤੇ ਆਪਣੇ ਭਤੀਜੇ ਲੂਤ ਅਤੇ ਉਸ ...
#   70640    "ਅਤੇ ਰਿਚਰਡ III ਨੇ ਅਸਲ ਵਿੱਚ ਆਪਣੇ ਭਤੀਜਿਆਂ - ""ਪ੍...
#   80915    "ਗੂਗਲ ਸ਼ਬਦ ਇੱਕ ਪਨ ਤੋਂ ਆਇਆ ਹੈਃ ""ਗੋਗੋਲ"" ਇੱਕ ਸ਼...
#   ...                                                    ...
#   6227497  ਬਿਜਨੌਰ: BSP ਨੇਤਾ ਅਤੇ ਉਸ ਦੇ ਭਤੀਜੇ ਦਾ ਗੋਲੀਆਂ ਮਾਰ...
#   6235418  ਸਾਂਜੀ ਰਾਮ ਦਾ ਲੜਕਾ ਵਿਸ਼ਾਲ ਜੰਗੋਤਰਾ ਉਰਫ ਸ਼ਾਮਾ, ਉਸਦਾ...
#   6260259  ਉਹ ਫ਼ਿਲਮ ਅਦਾਕਾਰ ਧਰਮਿੰਦਰ ਦੇ ਭਤੀਜੇ ਅਤੇ ਈਸ਼ਾ ਦਿਓਲ...
#   6264190                                       ਚੇਲੇ: ਹਾਂ!\n
#   6266770  ਉਨ੍ਹਾਂ ਇੱਕ ਟਵੀਟ ਕਰਦੇ ਹੋਏ ਲਿਖਿਆ ਕਿ ਸ਼ਹੀਦ-ਏ-ਆਜ਼ਮ...
#
#   [461 rows x 2 columns],
#   'niece':                                                   eng_Latn  \
#   12224                              """Hitler's niece is"\n
#   83672    "Hindu groups in the US have sought an apology...
#   95285    "Kaur started her filming career in 2014 with ...
#   143227   +All children who live in your home, including...
#   200197   387.On 3 August, he married Menen Asfaw of Amb...
#   ...                                                    ...
#   6072773  Nawazuddin Siddiqui's brother opens up on his ...
#   6089645  She is the niece of Shabana Azmi and Baba Azmi...
#   6115399  Saiyami is the daughter of yesteryear actress ...
#   6132503  Sushant's sister Shweta Singh Kirti and niece ...
#   6181582  Including one from his rather famous niece: Vi...
#
#                                                     pan_Guru
#   12224                                 """ਹਿਟਲਰ ਦੀ ਧੀ ਨੇ"\n
#   83672    ਅਮਰੀਕਾ ਦੀਆਂ ਹਿੰਦੂ ਜਥੇਬੰਦੀਆਂ ਨੇ ਸੈਨੇਟਰ ਕਮਲਾ ਹੈਰ...
#   95285    ਕੌਰ ਨੇ 2014 ਵਿੱਚ ਪ੍ਰਦੀਪ ਸਰਕਾਰ ਦੀ ਹਿੰਦੀ ਫਿਲਮ 'ਮ...
#   143227   ਤੁਹਾਡੇ ਘਰ ਵਿੱਚ ਰਹਿਣ ਵਾਲੇ ਸਾਰੇ ਬੱਚੇ, ਫੋਸਟਰ ਬੱਚਿ...
#   200197   3 ਅਗਸਤ ਨੂੰ, ਉਸਨੇ ਅੰਬੈਸਲ ਦੇ ਮੇਨਨ ਅਸਫੌ ਨਾਲ ਵਿਆਹ ...
#   ...                                                    ...
#   6072773  ਨਵਾਜ਼ੂਦੀਨ ਸਿਦੀਕੀ ਦੀ ਭਤੀਜੀ ਨੇ ਕੀਤੇ ਵੱਡੇ ਖੁਲਾਸੇ, ...
#   6089645  ਅਦਾਕਾਰਾ ਤੱਬੂ ਸ਼ਬਾਨਾ ਆਜ਼ਮੀ ਦੀ ਭਤੀਜੀ ਅਤੇ ਫਰਾਹ ਨਾ...
#   6115399  ਕੈਫੀ ਆਜ਼ਮੀ ਦੀ ਬੇਟੀ ਸ਼ਬਾਨਾ ਆਜ਼ਮੀ ਬਾਲੀਵੁੱਡ ਦੀ ਮਸ...
#   6132503  ਅੰਕਿਤਾ ਦੀ ਇਸ ਪੋਸਟ ਉੱਤੇ ਸੁਸ਼ਾਂਤ ਸਿੰਘ ਰਾਜਪੂਤ ਦਾ ਭ...
#   6181582  ਇਨ੍ਹਾਂ ’ਚੋਂ ਇੱਕ ਸੰਦੇਸ਼ ਉਸ ਦੀ ਬਹੁਤ ਮਸ਼ਹੂਰ ਭਤੀਜੀ...
#
#   [208 rows x 2 columns],
#   'child':                                                   eng_Latn  \
#   160      """ According to the report, around 818 millio...
#   167      """ All children complete eight years of eleme...
#   168      """ All children complete five years of primar...
#   178      """ And he took the children in his arms, put ...
#   587      """ Such policies are best suited for planning...
#   ...                                                    ...
#   6275508  Both parents share legal responsibility for su...
#   6275599  winter hats for newborns should cover not only...
#   6275665             This is a bad influence on children.\n
#   6275756  For example, the Italians "prophylactically" g...
#   6275764             And if you have more than one child?\n
#
#                                                     pan_Guru
#   160      ਰਿਪੋਰਟ ਅਨੁਸਾਰ ਲਗਭਗ 818 ਮਿਲੀਅਨ ਸਕੂਲਾਂ ਵਿੱਚ ਬੱਚਿ...
#   167      ਸਾਰੇ ਬੱਚੇ 2010 ਤੱਕ 8 ਸਾਲਾਂ ਦੀ ਸਕੂਲੀ ਸਿੱਖਿਆ ਪੂਰ...
#   168      ਸਾਰੇ ਬੱਚੇ 2007 ਤੱਕ 5 ਸਾਲ ਦੀ ਪ੍ਰਾਇਮਰੀ ਸਿੱਖਿਆ ਪੂ...
#   178      """ ਫਿਰ ਉਸ ਨੇ ""ਬੱਚਿਆਂ ਨੂੰ ਆਪਣੀਆਂ ਬਾਹਾਂ ਵਿਚ ਲਿ...
#   587      ਇਸ ਤਰ੍ਹਾਂ ਦੀਆਂ ਪਾਲਿਸੀਆਂ ਬੱਚਿਆਂ ਦੀ ਉੱਚ ਸਿੱਖਿਆ ਅ...
#   ...                                                    ...
#   6275508    ਦੋਨੋ ਮਾਪੇ ਔਲਾਦ ਦੀ ਦੇਖ ਵਿਚ ਆਪਣੀ ਜ਼ਿੰਮੇਵਾਰੀ ਹੈ.\n
#   6275599  ਨਵਜੰਮੇ ਬੱਚਿਆਂ ਲਈ ਸਰਦੀਆਂ ਦੀਆਂ ਟੌਰੀਆਂ ਨੂੰ ਨਾ ਸਿਰ...
#   6275665       ਬੱਚਿਆਂ ਦੀ ਨਜ਼ਰ ਉੱਤੇ ਕਾਫ਼ੀ ਭੈੜਾ ਅਸਰ ਪੈਂਦਾ ਹੈ।\n
#   6275756  ਉਦਾਹਰਨ ਲਈ, ਇਟਾਲੀਅਨਜ਼ "ਪ੍ਰੋਫਾਈਲੈਕਟੀਕਲੀ" ਆਪਣੇ ਬੱ...
#   6275764               ਕੀ ਤੁਹਾਡੇ ਕੋਲ ਇੱਕ ਤੋਂ ਵੱਧ ਬੱਚੇ ਹਨ?\n
#
#   [82880 rows x 2 columns],
#   'children':                                                   eng_Latn  \
#   160      """ According to the report, around 818 millio...
#   167      """ All children complete eight years of eleme...
#   168      """ All children complete five years of primar...
#   178      """ And he took the children in his arms, put ...
#   587      """ Such policies are best suited for planning...
#   ...                                                    ...
#   6274570  After all, parents are their children’s first ...
#   6274813  Children do not listen to their parents and re...
#   6275473  Thematic planning of educational and education...
#   6275665             This is a bad influence on children.\n
#   6275756  For example, the Italians "prophylactically" g...
#
#                                                     pan_Guru
#   160      ਰਿਪੋਰਟ ਅਨੁਸਾਰ ਲਗਭਗ 818 ਮਿਲੀਅਨ ਸਕੂਲਾਂ ਵਿੱਚ ਬੱਚਿ...
#   167      ਸਾਰੇ ਬੱਚੇ 2010 ਤੱਕ 8 ਸਾਲਾਂ ਦੀ ਸਕੂਲੀ ਸਿੱਖਿਆ ਪੂਰ...
#   168      ਸਾਰੇ ਬੱਚੇ 2007 ਤੱਕ 5 ਸਾਲ ਦੀ ਪ੍ਰਾਇਮਰੀ ਸਿੱਖਿਆ ਪੂ...
#   178      """ ਫਿਰ ਉਸ ਨੇ ""ਬੱਚਿਆਂ ਨੂੰ ਆਪਣੀਆਂ ਬਾਹਾਂ ਵਿਚ ਲਿ...
#   587      ਇਸ ਤਰ੍ਹਾਂ ਦੀਆਂ ਪਾਲਿਸੀਆਂ ਬੱਚਿਆਂ ਦੀ ਉੱਚ ਸਿੱਖਿਆ ਅ...
#   ...                                                    ...
#   6274570  ਮਾਂ – ਬਾਪ ਬੱਚੇ ਦੇ ਸਭ ਤੋਂ ਪਹਿਲੇ ਸਿੱਖਿਅਕ ਹੁੰਦੇ ਹ...
#   6274813  ਬੱਚਿਆਂ ਨੂੰ ਆਪਣੀ ਮਾਂ-ਬਾਪ ਦੀ ਗੱਲ ਸੁਣਨੀ ਪਸੰਦ ਹੀ ਨ...
#   6275473  ਵਿਦਿਅਕ ਅਤੇ ਵਿੱਦਿਅਕ ਕੰਮ ਦੀ ਵਿਸਤ੍ਰਿਤ ਯੋਜਨਾ ਇਹ ਹੈ...
#   6275665       ਬੱਚਿਆਂ ਦੀ ਨਜ਼ਰ ਉੱਤੇ ਕਾਫ਼ੀ ਭੈੜਾ ਅਸਰ ਪੈਂਦਾ ਹੈ।\n
#   6275756  ਉਦਾਹਰਨ ਲਈ, ਇਟਾਲੀਅਨਜ਼ "ਪ੍ਰੋਫਾਈਲੈਕਟੀਕਲੀ" ਆਪਣੇ ਬੱ...
#
#   [52452 rows x 2 columns],
#   "uncle's":                                                   eng_Latn  \
#   57935    "20 ""A man must not have sexual relations wit...
#   67053    "<20> ""A man must not have sexual relations w...
#   341164   As a young man of 18, Jack (Nicholas Hoult) he...
#   353273   At that age, Bhagat Singh read his uncle's rev...
#   622006                        He was my uncle's as well.\n
#   791747   In 1956, he had to leave his maternal uncle's ...
#   1035991  Next seen as a young man of eighteen, Jack (Ni...
#   1123294  Pliny the Younger refers to Tacitus's reliance...
#   1386421  The girl further alleged that when she went to...
#   1412312  The most important thing for me now, was to st...
#   2944607  Actor Deepak Parashar confirmed the news of hi...
#   5228645  He had come to his uncle's residence a few day...
#   6019835  After the incident, the woman went to her mate...
#   6146895  As a teenager, Muhammad went along with his un...
#
#                                                     pan_Guru
#   57935    "20 ""ਕਿਸੇ ਆਦਮੀ ਨੂੰ ਆਪਣੇ ਚਾਚੇ ਦੀ ਪਤਨੀ ਨਾਲ ਜਿਨਸ...
#   67053    "20 ""ਕਿਸੇ ਆਦਮੀ ਨੂੰ ਆਪਣੇ ਚਾਚੇ ਦੀ ਪਤਨੀ ਨਾਲ ਜਿਨਸ...
#   341164   18 ਸਾਲਾਂ ਦਾ ਜਵਾਨ ਹੋਣ ਦੇ ਨਾਤੇ, ਜੈਕ (ਨਿਕੋਲਸ ਹੌਲਟ...
#   353273   ਇਸ ਉਮਰ ਵਿੱਚ ਭਗਤ ਸਿੰਘ ਆਪਣੇ ਚਾਚਿਆਂ ਦੀਆਂ ਕ੍ਰਾਂਤੀਕ...
#   622006                              ਉਹ ਮੇਰਾ ਗਰਾਈਂ ਵੀ ਸੀ।\n
#   791747   1956 ਵਿਚ, ਉਸਨੂੰ ਆਪਣੇ ਮਾਮੇ ਦਾ ਘਰ ਛੱਡਣਾ ਪਿਆ ਅਤੇ ...
#   1035991  18 ਸਾਲਾਂ ਦਾ ਜਵਾਨ ਹੋਣ ਦੇ ਨਾਤੇ, ਜੈਕ (ਨਿਕੋਲਸ ਹੌਲਟ...
#   1123294  ਛੋਟੇ ਪਲੀਨੀ ਨੇ ਟੈਸੀਟਸ ਦੀ ਆਪਣੇ ਅੰਕਲ ਦੀ ਕਿਤਾਬ, ਜਰ...
#   1386421  ਲੜਕੀ ਨੇ ਅੱਗੇ ਦੋਸ਼ ਲਾਇਆ ਹੈ ਕਿ ਜਦੋਂ ਉਹ ਆਪਣੇ ਮਾਮੇ...
#   1412312  ਹੁਣ ਮੇਰੇ ਲਈ ਸਭ ਤੋਂ ਮਹੱਤਵਪੂਰਨ ਗੱਲ ਮੇਰੇ ਚਾਚੇ ਦੇ ...
#   2944607  ਅਦਾਕਾਰ ਦੀਪਕ ਪਰਾਸ਼ਰ ਨੇ ਟਵਿੱਟਰ ਤੇ ਇਸਦੀ ਜਾਣਕਾਰੀ ਦਿ...
#   5228645  ਪਿਛਲੇ ਕੁਝ ਦਿਨਾਂ ਤੋਂ ਉਹ ਪਿੰਡ ਛੋਟੇ ਭਰਾ ਕੋਲ ਆਇਆ ਸ...
#   6019835         ਇਸ ਸਭ ਤੋਂ ਬਾਅਦ, ਔਰਤ ਆਪਣੇ ਪੇਕੇ ਘਰ ਚਲੀ ਗਈ।\n
#   6146895  ਇੱਕ ਨੌਜਵਾਨ ਦੇ ਤੌਰ ਤੇ, ਮੁਹੰਮਦ ਸੀਰੀਆ ਨੂੰ ਉਸ ਦੇ ਚ...  ,
#   "aunt's":                                                   eng_Latn  \
#   431953   Colonel Mordaunt's cockfight in Lucknow, 1784-...
#   431954   Colonel Mordaunt's cockfight in Lucknow, 1784-...
#   789638   In 1369 Chaucer wrote The Book of the Duchess,...
#   1756506  While Raina was in Dubai for the IPL, his aunt...
#   3435725  """Be calm,"" João Pedro wrote back, explainin...
#   3498823  Bollywood actor Sonam Kapoor got married to he...
#   4234963  The woman said that Jeetendra, who is her aunt...
#   5867204  The woman said that Jeetendra, who is her aunt...
#
#                                                     pan_Guru
#   431953   ਲਖਨਊ ਵਿੱਚ ਕੁੱਕੜਾਂ ਦੀ ਲੜਾਈ, 1784-1786, ਫੋਟੋਃ ਜੋ...
#   431954   ਲਖਨਊ ਵਿੱਚ ਕੁੱਕੜਾਂ ਦੀ ਲੜਾਈ, 1784-1786, ਫੋਟੋਃ ਜੋ...
#   789638   1369 ਵਿੱਚ ਚੌਸਰ ਨੇ ਦ ਬੁੱਕ ਆਫ਼ ਦ ਡਚੇਸ ਲਿਖੀ, ਸੰਭਾ...
#   1756506  ਜਦੋਂ ਰੈਨਾ ਆਈਪੀਐਲ ਲਈ ਦੁਬਈ ਸੀ, ਉਸੇ ਸਮੇਂ, ਪੰਜਾਬ ਵ...
#   3435725  “ਸ਼ਾਂਤ ਰਹੋ,” ਜੋਓ ਪੇਡਰੋ ਨੇ ਵਾਪਸ ਲਿਖਿਆ, ਇਹ ਸਮਝਾਉ...
#   3498823  ਮੁੰਬਈ ਵਿੱਚ ਬਾਲੀਵੁੱਡ ਅਦਾਕਾਰਾ ਸੋਨਮ ਕਪੂਰ ਅਤੇ ਉਸ ਦ...
#   4234963  ਔਰਤ ਨੇ ਕਿਹਾ ਕਿ ਜਿਤੇਂਦਰ, ਜੋ ਉਸ ਦੀ ਭੂਆ ਦੇ ਪੁੱਤਰ ...
#   5867204  ਔਰਤ ਨੇ ਕਿਹਾ ਕਿ ਜਿਤੇਂਦਰ, ਜੋ ਉਸ ਦੀ ਭੂਆ ਦੇ ਪੁੱਤਰ ...  ,
#   "grandfather's":                                                   eng_Latn  \
#   35446    """These are not your grandfather's Playboy,""...
#   36604           """This is my great-grandfather's land."\n
#   36667    """This is not your grandfather's mill,"" he a...
#   36875    """This isn't your grandfather's fire departme...
#   105946   "She notes that modern performances are signif...
#   105947   "She notes that modern performances are signif...
#   646888                  His grandfather's name is Jacob.\n
#   646894      His grandmother was my grandfather's sister.\n
#   647734     His mother was my great-grandfather's sister.\n
#   1020191                         My grandfather's did it.\n
#   1078898  One day, I went with my father to my grandfath...
#   1389299                     The grandfather's reply was.\n
#   1558567  This film is about a British documentary filmm...
#   1621952     Today is my paternal grandfather's birthday.\n
#   1672717  We are the fruition of our grandfather's dream...
#   1905569                           my grandfather's radio\n
#   1955077                         was grandfather's reply.\n
#   3768883  Also in the Palace there is a museum where you...
#   4960425  His father's name was Syed Muhammad Irfan and ...
#   5154916  His father's name was Dhanadutta and grandfath...
#   5226473  Both of his paternal grandfather's parents wer...
#   5760644  In yet another incident, a 15-year-old boy in ...
#   5907842  His father's name was Syed Muhammad Irfan and ...
#
#                                                     pan_Guru
#   35446    """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   36604                    """ਇਹ ਸਾਡੇ ਵਡੇਰਿਆਂ ਦੀ ਧਰਤੀ ਹੈ।"\n
#   36667    """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   36875    """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   105946   """ ਉਹ ਦੱਸਦੀ ਹੈ ਕਿ ਆਧੁਨਿਕ ਪ੍ਰਦਰਸ਼ਨ ਉਸਦੇ ਦਾਦੇ ਦ...
#   105947   """ ਉਹ ਦੱਸਦੀ ਹੈ ਕਿ ਆਧੁਨਿਕ ਪ੍ਰਦਰਸ਼ਨ ਉਸਦੇ ਦਾਦੇ ਦ...
#   646888                    ਉਹਨਾਂ ਦੇ ਪਿਤਾ ਦਾ ਨਾਮ ਜੇਕਬ ਐਬਟ।\n
#   646894               ਉਨ੍ਹਾਂ ਦੀ ਪਤਨੀ ਮੇਰੇ ਦਾਦੇ ਦੀ ਭੈਣ ਸੀ।\n
#   647734               ਉਨ੍ਹਾਂ ਦੀ ਪਤਨੀ ਮੇਰੇ ਦਾਦੇ ਦੀ ਭੈਣ ਸੀ।\n
#   1020191                         ਮੇਰੀ ਦਾਦੀ ਨੇ ਅਜਿਹਾ ਕੀਤਾ.\n
#   1078898            ਇਕ ਵਾਰ ਆਪਣੇ ਦਾਦੇ ਨਾਲ ਮੈਂ ਉਹਦੇ ਘਰ ਗਿਆ।\n
#   1389299                                 ਦਾਦੀ ਦਾ ਜਵਾਬ ਸੀ।\n
#   1558567  ਕਹਾਣੀ ਇੱਕ ਬ੍ਰਿਟਿਸ਼ ਦਸਤਾਵੇਜ਼ੀ ਨਿਰਮਾਤਾ ਦੀ ਹੈ ਜੋ ...
#   1621952          ਅੱਜ ਉਨ੍ਹਾਂ ਦੇ ਮਰਹੂਮ ਪਿਤਾ ਦਾ ਜਨਮਦਿਨ ਹੈ ।\n
#   1672717        ਅਸੀਂ ਆਪਣੇ ਦਾਦਾ-ਦਾਦੀ ਦੇ ਸੁਪਨਿਆਂ ਦੇ ਬੀਜ ਹਾਂ\n
#   1905569                               ਮੇਰੇ ਬਾਬੇ ਦਾ ਰੇਡੀਓ\n
#   1955077                                 ਦਾਦੀ ਦਾ ਜਵਾਬ ਸੀ।\n
#   3768883  ਮਹਿਲ ਵਿਚ ਇਕ ਅਜਾਇਬਘਰ ਵੀ ਹੈ ਜਿੱਥੇ ਤੁਸੀਂ ਦਾਦਾ ਜੀ ...
#   4960425  ਉਹਨਾਂ ਦੇ ਪਿਤਾ ਦਾ ਨਾ ਸ੍ਰ. ਮਹਿੰਦਰ ਸਿੰਘ ਸਰਾਂ ਅਤੇ ...
#   5154916  ਉਨ੍ਹਾਂ ਦੇ ਪਿਤਾ ਦਾ ਨਾਮ ਬ੍ਰਜਨਾਥ ਤੇ ਮਾਤਾ ਦਾ ਨਾਮ ਭ...
#   5226473  ਇਸਦੇ ਮਾਂ-ਪਿਉ ਦੋਵੇਂ ਹੀ ਫ਼ਰਾਂਸੀਸੀ-ਕੈਨੇਡੀਅਨ ਮੂਲ ਦ...
#   5760644  ਰਿਪੋਰਟ ਦੇ ਅਨੁਸਾਰ, ਪੰਜਾਬ ਦੇ ਮੁਹਾਲੀ ਵਿੱਚ ਇੱਕ 15 ...
#   5907842  ਜਿਸ ਦਾ ਨਾਮ ਸ਼ਮਸ਼ੇਰ ਸਿੰਘ ਤੇ ਪਿਤਾ ਦਾ ਨਾਮ ਨਿਰਭੈਅ ਸਿ...  ,
#   "grandmother's":                                                   eng_Latn  \
#   4927     """Becker grew up listening to her grandmother...
#   36669    """This is not your grandmother's cheder,"" he...
#   36670    """This is not your grandmother's chintz,"" sh...
#   91032    "In the years to come, we will hear ad nauseam...
#   118220   "This is not your grandmother's possession,"" ...
#   295677   Although her Welsh parents lived in London, ju...
#   396992   But really it began when she was a little girl...
#   635223   Her mother was my great-grandmother's older si...
#   830182   In this color-saturated psychedelic thriller, ...
#   885877   It is my maternal grandmother's third great-gr...
#   1013649                      Mother's and Grandmother's!\n
#   1133960  Prince Harry was due to issue a statement on W...
#   1229670  Sometimes leave the twins at a grandmother's h...
#   1573257       This is my 3rd great grandmother's sister.\n
#   1599712             This was my grandmother's childhood:\n
#   1880852                     great grandmother's daughter\n
#   2135979  Example: The house that stood on the mountain ...
#   2200748  "As practice shows, you can water your home fl...
#   2290610  If you conduct a survey among different people...
#   2527966  Treatment of cold without temperature with the...
#   3251902  To decide which color is better for a bedroom,...
#   3328980  Are you living in your mother's or grandmother...
#   3618707  What is the grandmother's house in the village...
#   3923196  Many are mistaken if they think that a handker...
#   4206824  The times when the lot of the bride and groom ...
#   4422308  Brooches can be searched at flea markets, anti...
#   4636349  Yes, and my grandmother's young assistant in t...
#   4869833  Many parents seek to use "grandmother's" advic...
#   4915498  The restaurant serves dishes enlisted in her g...
#   4966047            Why dream of the grandmother's death?\n
#   4996111  But if strong drugs cause fears in you, then y...
#   5244135  The next morning, the grandfather returned fro...
#   5298589  The day after his grandmother's death, Jesse r...
#   5372915  Many of us loved to go to my grandmother's vil...
#   5573711  Elderly it becomes difficult to use the bathro...
#   5585214  "And what to choose - good old ""grandmother's...
#   5654212  Many people tend to think that this innovation...
#   6097911  The last and most weighty argument in his favo...
#   6191457  After all, it could be the sea, the grandmothe...
#
#                                                     pan_Guru
#   4927     """ਬੇਕਰ ਆਪਣੀ ਦਾਦੀ ਦੀਆਂ ਕਹਾਣੀਆਂ ਸੁਣਦਿਆਂ ਵੱਡੀ ਹੋ...
#   36669    """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   36670    """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   91032    "ਆਉਣ ਵਾਲੇ ਸਾਲਾਂ ਵਿੱਚ, ਅਸੀਂ ਵਿਗਿਆਨਕ ਮਤਲੀ ਨੂੰ ਸੁ...
#   118220   """ਇਹ ਤੁਹਾਡੇ ਦਾਦਾ ਜੀ ਦੀ ਪਲੇਬਿਊ ਨਹੀਂ ਹਨ,"" ਉਸ ਨ...
#   295677   ਭਾਵੇਂ ਕਿ ਉਸਦੇ ਵੈਲੇਸ਼ ਮਾਤਾ-ਪਿਤਾ ਲੰਡਨ ਵਿਚ ਰਹਿੰਦੇ...
#   396992   ਪਰ ਅਸਲ ਵਿੱਚ ਇਹ ਉਦੋਂ ਸ਼ੁਰੂ ਹੋਇਆ ਜਦੋਂ ਉਹ ਇੱਕ ਛੋਟ...
#   635223               ਉਨ੍ਹਾਂ ਦੀ ਪਤਨੀ ਮੇਰੇ ਦਾਦੇ ਦੀ ਭੈਣ ਸੀ।\n
#   830182   ਇਸ ਰੰਗ-ਸੰਤ੍ਰਿਪਤ ਸਾਈਕੇਡੈਲਿਕ ਥ੍ਰਿਲਰ ਵਿੱਚ, ਮਾਰਸੀ ...
#   885877                     ਇਹ ਤੀਜੀ ਮੇਰੀ ਮਾਸੀ ਦੀ ਲੜਕੀ ਹੈ।\n
#   1013649                                 ਉਮਰ ਦੇ ਮੰਮੀ ਅਤੇ!\n
#   1133960  ਲੰਡਨ: ਪ੍ਰਿੰਸ ਹੈਰੀ ਨੂੰ ਆਪਣੀ ਨਵਜੰਮੀ ਬੱਚੀ ਦਾ ਨਾਮ ...
#   1229670  ਕਈ ਵਾਰ ਜੁੜਵਾਂ ਨੂੰ ਦਾਦੀ ਦੇ ਘਰ ਜਾਂ ਕਿਸੇ ਦੋਸਤ ਦੇ ...
#   1573257                    ਇਹ ਤੀਜੀ ਮੇਰੀ ਮਾਸੀ ਦੀ ਲੜਕੀ ਹੈ।\n
#   1599712                      ਇਹ ਬਚਪਨ ਸੀ ਮੇਰੀ ਦਾਦੀ ਜੀ ਦਾ,\n
#   1880852                             ਮਹਾਨ ਮਾਤਾਵਾਂ ਦੀ ਬੇਟੀ\n
#   2135979  ਉਦਾਹਰਨ: ਘਰ ਹੈ, ਜੋ ਕਿ ਪਹਾੜੀ 'ਤੇ ਖੜ੍ਹਾ ਸੀ, ਮੇਰੇ ...
#   2200748  "ਜਿਵੇਂ ਕਿ ਅਭਿਆਸ ਦਿਖਾਉਂਦਾ ਹੈ, ਤੁਸੀਂ ਆਪਣੀ ਛੁੱਟੀ ...
#   2290610  ਜੇ ਤੁਸੀਂ ਵੱਖੋ-ਵੱਖਰੇ ਲੋਕਾਂ ਵਿਚ ਇਕ ਸਰਵੇ ਕਰਵਾਉਂਦੇ...
#   2527966  ਦਵਾਈਆਂ ਦੀ ਮਦਦ ਨਾਲ ਬਿਨਾਂ ਤਾਪਮਾਨ ਦੇ ਠੰਢੇ ਇਲਾਜ ਜ਼...
#   3251902  ਇਹ ਫੈਸਲਾ ਕਰਨ ਲਈ ਕਿ ਬੈੱਡਰੂਮ ਲਈ ਕਿਹੜਾ ਰੰਗ ਬਿਹਤਰ ...
#   3328980  ਕੀ ਆਪਣੀ ਮਾਂ ਜਾਂ ਪਿਤਾ ਨਾਲ ਚਾਰਲੀ ਜੀਉਂਦੀ ਰਹਿੰਦੀ ਹ...
#   3618707            ਪਿੰਡ ਵਿਚ ਨਾਨੀ ਦੇ ਘਰ ਬਾਰੇ ਕੀ ਸੁਪਨਾ ਹੈ?\n
#   3923196  ਬਹੁਤ ਸਾਰੇ ਗਲਤੀ ਹੋ ਜਾਂਦੇ ਹਨ ਜੇ ਉਹ ਸੋਚਦੇ ਹਨ ਕਿ ਰ...
#   4206824  ਉਹ ਸਮਾਂ ਜਦੋਂ ਲਾੜੀ-ਲਾੜੀ ਦਾ ਬਹੁਤ ਸਾਰਾ ਇਕੱਠਿਆਂ ਰਜ...
#   4422308  ਬਰੂਕਸ ਨੂੰ ਫਲੀਮਾਰ ਬਾਜ਼ਾਰਾਂ, ਐਂਟੀਕ ਦੀਆਂ ਦੁਕਾਨਾਂ,...
#   4636349  ਹਾਂ, ਅਤੇ ਗਰਮੀ ਵਿੱਚ ਮੇਰੀ ਨਾਨੀ ਦੇ ਨੌਜਵਾਨ ਸਹਾਇਕ ਬ...
#   4869833  ਬਹੁਤ ਸਾਰੇ ਮਾਤਾ-ਪਿਤਾ "ਦਾਦੀ" ਦੀ ਸਲਾਹ ਲੈਣ ਦੀ ਕੋਸ਼...
#   4915498  ਇਸ ਰੈਸਟੋਰੈਂਟ ਵਿੱਚ ਉਸ ਦੀ ਦਾਦੀ ਦੀ ਰੈਸਪੀ ਬੁੱਕ ਵਿੱ...
#   4966047  ਮੈਨੂੰ ਇਹ ਸੁਪਨਾ ਕਿਉਂ ਹੈ ਕਿ ਮੇਰੀ ਦਾਦੀ ਦੀ ਮੌਤ ਹੋ ...
#   4996111  ਪਰ ਜੇ ਮਜ਼ਬੂਤ ​​ਨਸ਼ੀਲੀਆਂ ਦਵਾਈਆਂ ਤੁਹਾਡੇ ਵਿਚ ਡਰ ਪ...
#   5244135  ਅਗਲੀ ਸਵੇਰ, ਦਾਦਾ ਲਾਡਸ ਤੋਂ ਵਾਪਸ ਆ ਗਿਆ, ਜਿਸਨੇ ਆਪਣ...
#   5298589  ਦਾਦੀ ਦੀ ਮੌਤ ਤੋਂ ਇੱਕ ਦਿਨ ਬਾਅਦ ਜੈਸੀ ਨੂੰ ਉਸ ਦੇ ਭਰ...
#   5372915  ਸਾਡੇ ਵਿੱਚੋਂ ਬਹੁਤ ਸਾਰੇ ਮੇਰੇ ਨਾਨੀ ਦੇ ਪਿੰਡ ਜਾਣਾ ਪ...
#   5573711  ਬਜ਼ੁਰਗਾਂ ਨੂੰ ਬਾਥਰੂਮ ਦਾ ਇਸਤੇਮਾਲ ਕਰਨਾ ਮੁਸ਼ਕਲ ਹੋ ...
#   5585214  "ਪਰ ਕੀ ਦੀ ਚੋਣ ਕਰਨ ਲਈ - ਚੰਗੇ ਪੁਰਾਣੇ ""ਗਰੈਨੀ"" ਢ...
#   5654212  ਬਹੁਤ ਸਾਰੇ ਲੋਕ ਸੋਚਦੇ ਹਨ ਕਿ ਇਹ ਨਵੀਨਤਾ "ਦਾਦੀ ਜੀ ਦ...
#   6097911  ਉਸ ਦੇ ਪੱਖ ਵਿਚ ਆਖਰੀ ਅਤੇ ਸਭ ਤੋਂ ਭਾਰੀ ਦਲੀਲ ਉਸ ਦੀ ...
#   6191457  ਆਖਰਕਾਰ, ਇਹ ਸਮੁੰਦਰ ਹੋ ਸਕਦਾ ਹੈ, ਪਿੰਡ ਵਿੱਚ ਦਾਦੀ ਜ...  ,
#   "brother in law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "brother-in-law's":                                                   eng_Latn  \
#   2748774  Amid those being searched included Kamla Nath'...
#   3094452  Two die as police officer opens fire at brothe...
#
#                                                     pan_Guru
#   2748774  ਜਿਨ੍ਹਾਂ ਲੋਕਾਂ 'ਤੇ ਛਾਪੇ ਮਾਰੇ ਗਏ ਉਨ੍ਹਾਂ 'ਚ ਕਮਲਨਾ...
#   3094452  ਪੁਲਿਸ ਮੁਲਾਜ਼ਮ ਵੱਲੋਂ ਟੱਕਰ ਮਾਰਨ 'ਤੇ ਦੋ ਭਰਾਵਾਂ 'ਚੋ...  ,
#   "sister in law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "sister-in-law's":                                                   eng_Latn  \
#   1215074  So sad to read about your sister-in-law's pass...
#   3475906  "Confirming reports of his sister-in-law's dea...
#   5520566  Also, the actress Kareena Kapoor Khan attended...
#   5578653  "I killed her (Sarabjit Kaur) because she was ...
#
#                                                     pan_Guru
#   1215074  ਬਹੁਤ ਹੀ ਦੁੱਖ ਹੋਇਆ ਤੁਹਾਡੀ ਚਚੇਰੀ ਭੈਣ ਬਾਰੇ ਪੜ੍ਹ ਕ...
#   3475906  "ਇਸ ਖਬਰ ਦੀ ਸੰਜੈ ਕਪੂਰ ਨੇ ਪੁਸ਼ਟੀ ਕਰਦਿਆਂ ਕਿਹਾ ਕਿ ...
#   5520566  ਬਾਲੀਵੁਡ ਅਦਾਕਾਰਾ ਕਰਿਸ਼ਮਾ ਕਪੂਰ ਵੀ ਆਪਣੇ ਬੇਟੇ ਕਿਆਨ...
#   5578653  ਮਨਿੰਦਰ ਸਿੰਘ ਨੇ ਸਮਾਚਾਰ ਚੈਨਲ ਨੂੰ ਦੱਸਿਆ ਕਿ, ਮੈਂ ਉ...  ,
#   "cousin's":                                                   eng_Latn  \
#   24829                            """My cousin's a girl."\n
#   501745   Else your partner's father's second cousin's g...
#   530522   First off, many animals don't enjoy being away...
#   926045   It's one thing when you're told a story by you...
#   1375802  The film revolves around Sukhi's trip to Canad...
#   1744163  When his cousin's 7-year-old daughter died in ...
#   1759165  Whilst working as a Human Resources Manager in...
#   2705044  Also Read: Solapur: Man mistakes cousin's wife...
#   2805571  Police have arrested one accused, her cousin's...
#   3143151  Aishwarya Rai Bachchan and Abhishek Bachchan r...
#   5004001  Aamir Khan's daughter Ira Khan enjoys her cous...
#   5076828  Recently, she shared videos and photos from he...
#   5110251  Aamir Khan's daughter Ira Khan is busy with th...
#   5326194     Abdullah was Salman's paternal cousin's son.\n
#   6234581       After that we headed to my cousin's house.\n
#
#                                                     pan_Guru
#   24829                               """ਮੇਰੇ ਇੱਕ ਕੁੜੀ ਐ।"\n
#   501745   ਫ਼ੇਰ ਤੁਹਾਡੇ ਸਾਥੀ ਦੇ ਪਿਤਾ ਦੀ ਦੂਜੀ ਦੇ ਚਚੇਰੇ ਭਰਾ ...
#   530522   ਪਹਿਲਾਂ, ਬਹੁਤ ਸਾਰੇ ਜਾਨਵਰ ਕਿਸੇ ਜਾਣੂ ਘਰ ਤੋਂ ਦੂਰ ਰ...
#   926045   ਇਹ ਇਕ ਚੀਜ ਹੁੰਦੀ ਹੈ ਜਦੋਂ ਤੁਹਾਨੂੰ ਆਪਣੇ ਭਰਾ ਦੇ ਚਚ...
#   1375802  ਸੀਕਵਲ ਦੀ ਸ਼ੂਟਿੰਗ ਕਨੇਡਾ ਵਿੱਚ ਕੀਤੀ ਗਈ ਸੀ ਜਿਸ ਵਿੱ...
#   1744163  ਜਦ ਉਸ ਦੇ ਚਚੇਰੇ ਭਰਾ ਦੇ 7 ਸਾਲ ਦੀ ਉਮਰ ਦੀ ਧੀ ਨੂੰ 1...
#   1759165  ਆਪਣੇ ਚਚੇਰੇ ਭਰਾ ਦੀ ਫਰਮ ਵਿੱਚ ਮਾਨਵੀ ਸੰਸਾਧਨ ਪ੍ਰਬੰਧ...
#   2705044  ਇਹ ਵੀ ਪੜ੍ਹੋ : ਸੁਲਤਾਨਪੁਰ ਲੋਧੀ ’ਚ ਵੱਡੀ ਵਾਰਦਾਤ, ਪ...
#   2805571  ਪੁਲਸ ਨੇ ਮਿ੍ਰਤਕਾ ਦੇ ਭਰਾ ਅਤੇ ਇਕ ਹੋਰ ਦੋਸ਼ੀ ਨੂੰ ਗਿ੍...
#   3143151  ਹਾਲ ‘ਚ ਬੇਟੀ ਅਤੇ ਪਤਨੀ ਨਾਲ ਰੋਮ ਪਹੁੰਚੇ ਅਭਿਸ਼ੇਕ ਬੱਚ...
#   5004001  ਆਮਿਰ ਖਾਨ ਦੀ ਬੇਟੀ ਈਰਾ ਖਾਨ ਹੋਈ ਰੋਮਾਂਟਿਕ, ਆਪਣੇ ਬੁ...
#   5076828  ਹਾਲ ਹੀ ਵਿੱਚ, ਉਸ ਨੇ ਆਪਣੀ ਬਿਕਨੀ ਅਤੇ ਸਵੀਮਵੀਅਰ ਦੀਆ...
#   5110251  ਆਮਿਰ ਖ਼ਾਨ ਦੀ ਧੀ ਇਰਾ ਖ਼ਾਨ ਅੱਜ–ਕੱਲ੍ਹ ਆਪਣੇ ਯੂਰੋਪੀ...
#   5326194      ਅਬਦੁੱਲਾਹ ਉਨ੍ਹਾਂ ਦੀ ਭੂਆ ਦੇ ਬੇਟੇ ਦਾ ਪੁੱਤਰ ਸੀ।\n
#   6234581  ਇਸ ਮਗਰੋਂ ਉਹ ਨੇੜੇ ਰਹਿੰਦੀ ਸਾਡੀ ਮਾਸੀ ਦੇ ਘਰ ਚਲਾ ਗਿ...  ,
#   "nephew's":                                                   eng_Latn  \
#   1197743                  She was my nephew's only child.\n
#   1236143  Sridevi had been to Dubai with her family to a...
#   4229629  Tusshar Kapoor attended his nephew's birthday ...
#   4671112  What does a growing man need, or Congratulatio...
#
#                                                     pan_Guru
#   1197743                 ਉਹ ਮੇਰੀ ਭੈਣ ਦਾ ਇੱਕਲੌਤਾ ਪੁੱਤਰ ਸੀ।\n
#   1236143  ਸ਼੍ਰੀਦੇਵੀ ਦੁਬਈ 'ਚ ਇਕ ਵਿਆਹ ਸਮਾਰੋਹ 'ਚ ਸ਼ਿਰਕਤ ਕਰਨ...
#   4229629  ਬਰਥਡੇ ਪਾਰਟੀ 'ਚ ਤੁਸ਼ਾਰ ਕਪੂਰ ਆਪਣੇ ਬੇਟੇ ਲਕਸ਼ ਨਾਲ ਪਹ...
#   4671112  ਇੱਕ ਵਧ ਰਹੇ ਆਦਮੀ ਨੂੰ ਕੀ ਕਰਨਾ ਚਾਹੀਦਾ ਹੈ, ਜਾਂ ਉਸਦ...  ,
#   "niece's":                                                   eng_Latn  \
#   2636614  He was shot in UP for filing an FIR to book hi...
#   5537480  13-year-old Paris is prettier and starred in h...
#   6072773  Nawazuddin Siddiqui's brother opens up on his ...
#
#                                                     pan_Guru
#   2636614  ਆਪਣੀ ਭਤੀਜੀ ਨਾਲ ਛੇੜਛਾੜ ਕਰਨ ਵਾਲਿਆਂ 'ਤੇ ਐੱਫਆਈਆਰ ਦ...
#   5537480  13 ਸਾਲਾ ਪੈਰੀਸ ਆਪਣੀ ਪਹਿਲੀ ਫ਼ਿਲਮ "ਲੰਡਨ ਬ੍ਰਿਜ ਅਤੇ...
#   6072773  ਨਵਾਜ਼ੂਦੀਨ ਸਿਦੀਕੀ ਦੀ ਭਤੀਜੀ ਨੇ ਕੀਤੇ ਵੱਡੇ ਖੁਲਾਸੇ, ...  ,
#   "child's":                                                   eng_Latn  \
#   10845    """Have you planned for your Child's Higher Ed...
#   12750    """How sweet a thing it is for a strong health...
#   12751    """How sweet a thing it is for a strong, healt...
#   21813                 """It looks like a child's toy!"""\n
#   22150    """It was terrifying to hear that these pathog...
#   ...                                                    ...
#   6259226         How to knock down a child's temperature?\n
#   6270561  Remember that your child's health is in your h...
#   6271136  The height of the chair, backrest, seat depth ...
#   6272163  It will be even more interesting if you put a ...
#   6275599  winter hats for newborns should cover not only...
#
#                                                     pan_Guru
#   10845    ਕੀ ਤੁਸੀਂ ਆਪਣੇ ਬੱਚੇ ਦੀ ਉੱਚ ਸਿੱਖਿਆ ਲਈ ਯੋਜਨਾ ਬਣਾਈ...
#   12750    ਇੱਕ ਮਜ਼ਬੂਤ ਤੰਦਰੁਸਤ ਆਦਮੀ ਲਈ ਇੱਕ womanਰਤ ਦੀ ਅੱਖ ...
#   12751    ਇੱਕ ਮਜ਼ਬੂਤ ਤੰਦਰੁਸਤ ਆਦਮੀ ਲਈ ਇੱਕ womanਰਤ ਦੀ ਅੱਖ ...
#   21813     """ਇਹ ਇਕ ਬੱਚੇ ਦੇ ਖਿਡੌਣਿਆਂ ਦੀ ਤਰ੍ਹਾਂ ਲੱਗਦਾ ਹੈ!"\n
#   22150    "ਬੱਚੇ ਦੀ ਮਾਂ ਨੇ ਕਿਹਾ, ""ਇਹ ਸੁਣ ਕੇ ਬਹੁਤ ਦੁੱਖ ਹੋ...
#   ...                                                    ...
#   6259226  ਮੈਂ ਇੱਕ ਬੱਚੇ ਦੇ ਤਾਪਮਾਨ ਨੂੰ ਤੇਜ਼ੀ ਨਾਲ ਕਿਵੇਂ ਕਢ ...
#   6270561  ਆਖ਼ਰਕਾਰ, ਤੁਹਾਡੇ ਬੱਚੇ ਦੀ ਸਿਹਤ ਤੁਹਾਡੇ ਹੱਥਾਂ ਵਿਚ ...
#   6271136  ਕੁਰਸੀ ਦੀ ਉੱਚਾਈ, ਬੈਕਸਟ, ਸੀਟ ਦੀ ਗਹਿਰਾਈ ਨੂੰ ਬੱਚੇ ...
#   6272163  ਇਹ ਹੋਰ ਵੀ ਦਿਲਚਸਪ ਹੋਵੇਗਾ ਜੇਕਰ ਤੁਸੀਂ ਬੱਚੇ ਦੇ ਹੱਥ...
#   6275599  ਨਵਜੰਮੇ ਬੱਚਿਆਂ ਲਈ ਸਰਦੀਆਂ ਦੀਆਂ ਟੌਰੀਆਂ ਨੂੰ ਨਾ ਸਿਰ...
#
#   [2399 rows x 2 columns],
#   "children's":                                                   eng_Latn  \
#   587      """ Such policies are best suited for planning...
#   6378     """Children's children are a crown to the aged...
#   6379     """Children's children are a crown to the aged...
#   6380     """Children's lives and health is very importa...
#   6381     """Children's speech is largely free of gramma...
#   ...                                                    ...
#   6265709  Children's household appliances are considered...
#   6266788  Admission fee for children's group tours is $4...
#   6267782  He can easily glue a broken children's toy, ce...
#   6271275  Write an application to the Children's Service...
#   6273393  Also, there's a children's pool for youngsters.\n
#
#                                                     pan_Guru
#   587      ਇਸ ਤਰ੍ਹਾਂ ਦੀਆਂ ਪਾਲਿਸੀਆਂ ਬੱਚਿਆਂ ਦੀ ਉੱਚ ਸਿੱਖਿਆ ਅ...
#   6378     """ਪੁਤ੍ਤ-ਪੋਤਰੇ ਆਪਣੇ ਦਾਦਾ-ਦਾਦੀ ਲਈ ਅਨਾਦਰ ਵਾਂਗ ਹੁ...
#   6379     """ਪੁਤ੍ਤ-ਪੋਤਰੇ ਆਪਣੇ ਦਾਦਾ-ਦਾਦੀ ਲਈ ਅਨਾਦਰ ਵਾਂਗ ਹੁ...
#   6380     ਬੱਚਿਆਂ ਦੀ ਜ਼ਿੰਦਗੀ ਅਤੇ ਸਿਹਤ ਸਾਡੇ ਲਈ ਬਹੁਤ ਮਹੱਤਵਪ...
#   6381     """ਬੱਚਿਆਂ ਦੇ ਭਾਸ਼ਣ ਜਿਆਦਾਤਰ ਇਸ ਕਿਸਮ ਦੇ ਵਿਆਕਰਣ ਪ...
#   ...                                                    ...
#   6265709  ਛੋਟੇ ਘਰੇਲੂ ਨੌਕਰਾਣੀਆਂ ਲਈ ਬੱਚਿਆਂ ਦੇ ਘਰੇਲੂ ਉਪਕਰਣਾ...
#   6266788  ਦਾਖ਼ਲੇ ਬਾਲਗ ਲਈ $ 5 ਅਤੇ ਬਜ਼ੁਰਗਾਂ ਅਤੇ ਬੱਚਿਆਂ ਲਈ ...
#   6267782  ਉਹ ਆਸਾਨੀ ਨਾਲ ਟੁੱਟੇ ਹੋਏ ਬੱਚਿਆਂ ਦੇ ਖਿਡੌਣੇ, ਵਸਰਾਵ...
#   6271275  ਬੱਚੇ ਦੀ ਪਾਲਣਾ ਕਰਨ ਦੀ ਬੇਨਤੀ ਨਾਲ ਬੱਚਿਆਂ ਦੀ ਸੇਵਾ ...
#   6273393  ਬੱਚੇ ਲਈ ਵੀ ਉਥੇ ਬਾਲਗ ਪੂਲ ਵਿੱਚ ਇੱਕ ਖੋਖਲਾ ਡੱਬੇ ਹੈ.\n
#
#   [3559 rows x 2 columns],
#   "uncles'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "aunts'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "grandfathers'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "grandmothers'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "brothers in law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "brothers-in-law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "sisters in law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "sisters-in-law's": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "cousins'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "nephews'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   "nieces'": Empty DataFrame
#   Columns: [eng_Latn, pan_Guru]
#   Index: [],
#   'uncles':                                                   eng_Latn  \
#   74140    "But being the legitimate heir to a king/queen...
#   82333    "He said to his uncles and all of his mother's...
#   82334    "He said to his uncles and all of his mother's...
#   82335    "He said to his uncles and all of his mother's...
#   99278    "Naveen does not need to worry about her futur...
#   ...                                                    ...
#   6002209  Also surviving are numerous aunts, uncles, cou...
#   6054524  The suspects have been identified as the victi...
#   6057689  These include brothers, sisters, nephews, uncl...
#   6146730  A mother, a father, a brother or sister, grand...
#   6223793  Mother, father, brothers and sisters, spouse, ...
#
#                                                     pan_Guru
#   74140    "ਪਰ ਕਿਸੇ ਰਾਜੇ/ਰਾਣੀ ਦਾ ਜਾਇਜ਼ ਵਾਰਸ ਬਣਨਾ ਦਫਤਰ ਲਈ ...
#   82333    "ਉਸਨੇ ਆਪਣੇ ਚਾਚਿਆਂ ਅਤੇ ਮਾਤਾ ਦੇ ਸਾਰੇ ਪਰਿਵਾਰ ਨੂੰ ...
#   82334    "ਉਸਨੇ ਆਪਣੇ ਚਾਚਿਆਂ ਅਤੇ ਮਾਤਾ ਦੇ ਸਾਰੇ ਪਰਿਵਾਰ ਨੂੰ ...
#   82335    "ਉਸਨੇ ਆਪਣੇ ਚਾਚਿਆਂ ਅਤੇ ਮਾਤਾ ਦੇ ਸਾਰੇ ਪਰਿਵਾਰ ਨੂੰ ...
#   99278    'ਨਵੀਨ ਨੂੰ ਆਪਣੇ ਭਵਿੱਖ ਬਾਰੇ ਚਿੰਤਾ ਕਰਨ ਦੀ ਜ਼ਰੂਰਤ ...
#   ...                                                    ...
#   6002209  ਪਰਿਵਾਰ ਦੇ ਹੋਰ ਮੈਂਬਰਾਂ ਜਿਵੇਂ ਕਿ ਮਾਵਾਂ, ਚਾਚਿਆਂ, ...
#   6054524  ਮੁਲਜ਼ਮਾਂ ਦੀ ਪਛਾਣ ਮਿ੍ਤਕਾ ਗੁਰਲੀਨ ਕੌਰ ਦੇ ਪਤੀ ਜਸਕਰਨ...
#   6057689                ਉਹ ਭਰਾ, ਭੈਣ, ਭਤੀਜੇ, ਅੰਕਲ, ਭੂਆ ਹਨ.\n
#   6146730  ਮਾਂ, ਬੀਵੀ ਅਤੇ ਬੇਟੀ, ਭਾਈ, ਭੈਣ ਤੇ ਬੀਵੀ ਜਾਂ ਦੋਸਤ ...
#   6223793  ਮਾਤਾ, ਪਿਤਾ, ਭੈਣ ਭਰਾ, ਪਤਨੀ, ਦਾਦੀ, ਭੂਆ, ਅੰਕਲ - ਜ...
#
#   [106 rows x 2 columns],
#   'aunts':                                                   eng_Latn  \
#   37750    """Today, the fear of genericide haunts the pr...
#   93895    "Jesse Sheidlower, author of ""The F-Word"" (R...
#   287999   All the kids, aunts and uncles, grandparents, ...
#   379317   Blended families and changing family relations...
#   466396   Do they have families and aunts and uncles and...
#   ...                                                    ...
#   6057689  These include brothers, sisters, nephews, uncl...
#   6100158       15-yr-old girl strangled to death by aunts\n
#   6109137  The Redmi 8 also flaunts a - 6.22-inch HD+ IPS...
#   6146730  A mother, a father, a brother or sister, grand...
#   6223793  Mother, father, brothers and sisters, spouse, ...
#
#                                                     pan_Guru
#   37750    """ਅੱਜ, ਜਨਤਕ ਸ਼ਮੂਲੀਅਤ ਦੇ ਡਰ ਨੂੰ ਕਲੇਨੇਕਸ, ਬਾਗਜੀ...
#   93895    """ਐਫ-ਵਾਈਡ"" (ਰੈਂਡਮ ਹਾਊਸਃ 1999) ਦੇ ਲੇਖਕ, ਜੇਸੀ ...
#   287999      ਸਾਰੇ ਬੱਚੇ, ਚਾਚੇ ਅਤੇ ਚਾਚੇ, ਦਾਦਾ-ਦਾਦੀ, ਹਰ ਕੋਈ!\n
#   379317   ਮਿਲਾਏ ਹੋਏ ਪਰਿਵਾਰ ਅਤੇ ਪਰਿਵਾਰਕ ਰਿਸ਼ਤੇ ਬਦਲਦੇ ਦਾਦਾ...
#   466396   ਕੀ ਉਨ੍ਹਾਂ ਦੇ ਪਰਿਵਾਰ ਅਤੇ ਚਾਚੇ, ਚਾਚੇ ਅਤੇ ਬਿੱਲੀਆਂ...
#   ...                                                    ...
#   6057689                ਉਹ ਭਰਾ, ਭੈਣ, ਭਤੀਜੇ, ਅੰਕਲ, ਭੂਆ ਹਨ.\n
#   6100158  15 ਸਾਲਾ ਕੁੜੀ ਨੇ ਖ਼ੁਦ ਨੂੰ ਦਿੱਤੀ ਭਿਆਨਕ ਮੌਤ, ਫਾਹੇ...
#   6109137  ਰੈੱਮਡੀ 8ਏ ਡਿਊਲ ਸਮਾਰਟਫੋਨ 'ਚ 6.22 ਇੰਚ ਦੀ ਐੱਚ.ਡੀ....
#   6146730  ਮਾਂ, ਬੀਵੀ ਅਤੇ ਬੇਟੀ, ਭਾਈ, ਭੈਣ ਤੇ ਬੀਵੀ ਜਾਂ ਦੋਸਤ ...
#   6223793  ਮਾਤਾ, ਪਿਤਾ, ਭੈਣ ਭਰਾ, ਪਤਨੀ, ਦਾਦੀ, ਭੂਆ, ਅੰਕਲ - ਜ...
#
#   [107 rows x 2 columns],
#   'grandfathers':                                                   eng_Latn  \
#   229195   A correspondent of the New York Times, in 1928...
#   229196   A correspondent of the New York Times, in 1928...
#   283091        All my family, all the great-grandfathers,\n
#   640404                     Here's my great grandfathers.\n
#   791093   In 1928 a correspondent wrote in the New York ...
#   791107   In 1928, a New York Times correspondent wrote ...
#   1020192               My grandfathers were both farmers.\n
#   1020221         My great-grandfathers were also farmers.\n
#   1579264            This is the land of our grandfathers.\n
#   2019801  Most grandmothers and grandfathers love insane...
#   2300534  Both her paternal and maternal grandfathers we...
#   2303519  Such a postcard can be congratulated grandmoth...
#   2415980              Both me grandfathers were soldiers.\n
#   2471956  Both of my grandfathers and my father were phy...
#   2562973  But I know many of them–my own father, the fat...
#   2565808        Both of his grandfathers were physicians.\n
#   2650129  Many toys were played in childhood by grandmot...
#   2771916                  Both his grandfathers are dead.\n
#   2795005           Both my grandfathers were in the army.\n
#   2935998  This is especially true if the baby does not h...
#   2939087  Both her grandfathers and her father had been ...
#   3091079  That means men reading this article will on av...
#   3359928                  Both grandfathers were doctors.\n
#   3421888  The state lotteries of Russia have such a rich...
#   3442103      “Both my grandfathers were in the military.\n
#   3449087  Chokshi recalled that chance propelled his gra...
#   3620011  Brothers, sisters, sons, grandsons, parents, g...
#   3888927     Both my Grandfathers served in the military.\n
#   3967758  In general, all sorts of lovely household triv...
#   3982547  And how did their "grandmothers" and "grandfat...
#   4069779  Therefore, we will not be like our great-grand...
#   4082859  These can be our wives, husbands, moms, dads, ...
#   4345752                       Both men are grandfathers.\n
#   4467236  Both of my grandfathers and my father served i...
#   4531694  Fathers and sons, grandmothers, grandfathers a...
#   4581017  Taking a swipe at the Shiromani Akali Dal (SAD...
#   4596669         Both of my grandfathers were professors.\n
#   4646433  Chokshi recalled that chance propelled his gra...
#   4717777                 Both of my grandfathers did too.\n
#   4760632                  Both grandfathers were farmers.\n
#   5089322  Both his grandfathers had been doctors, aa was...
#   5109874  The Victory Day is the pride of not only our g...
#   5204836  As a child she was inspired by her grandfather...
#   5219422  For example, in the Ukrainian villages Melanka...
#   5234987           Both his grandfathers were physicians.\n
#   5259600  a complex family - consists of a married coupl...
#   5701866  " Our great-grandfathers knew that sometimes y...
#   5786785  Our great-grandfathers knew very well that in ...
#   5850806  Both of his grandfathers fought in World War I...
#   6078116  Taking a swipe at the Shiromani Akali Dal (SAD...
#
#                                                     pan_Guru
#   229195   ਸਾਲ 1928 ਵਿੱਚ ਨਿਊਯਾਰਕ ਟਾਈਮਸ ਦੇ ਇੱਕ ਪੱਤਰਕਾਰ ਨੇ ...
#   229196   ਸਾਲ 1928 ਵਿੱਚ ਨਿਊਯਾਰਕ ਟਾਈਮਸ ਦੇ ਇੱਕ ਪੱਤਰਕਾਰ ਨੇ ...
#   283091       ਸਾਰੇ ਮੇਰੇ ਪਰਿਵਾਰ ਦੇ, ਬੜੇ ਹੀ ਨਿਆਰੇ ਨਿਆਰੇ ਨੇ,\n
#   640404                 ਇੱਥੇ ਮੇਰੇ ਵਡੇਰਿਆਂ ਦੀਆਂ ਜੜ੍ਹਾਂ ਨੇ।\n
#   791093   ਸਾਲ 1928 ਵਿੱਚ ਨਿਊਯਾਰਕ ਟਾਈਮਸ ਦੇ ਇੱਕ ਪੱਤਰਕਾਰ ਨੇ ...
#   791107   ਸਾਲ 1928 ਵਿੱਚ ਨਿਊਯਾਰਕ ਟਾਈਮਸ ਦੇ ਇੱਕ ਪੱਤਰਕਾਰ ਨੇ ...
#   1020192                       ਮੇਰੇ ਵੀ ਬਾਪ-ਦਾਦਾ ਕਿਸਾਨ ਸਨ।\n
#   1020221                       ਮੇਰੇ ਵੀ ਬਾਪ-ਦਾਦਾ ਕਿਸਾਨ ਸਨ।\n
#   1579264                  """ਇਹ ਸਾਡੇ ਵਡੇਰਿਆਂ ਦੀ ਧਰਤੀ ਹੈ।"\n
#   2019801  ਜ਼ਿਆਦਾਤਰ ਨਾਨੀ ਅਤੇ ਦਾਦਾ ਪਰਿਵਾਰ ਦੇ ਨਿੱਕੇ ਜਿਹੇ ਮੈ...
#   2300534              ਉਸ ਦੀ ਦਾਦੀ ਅਤੇ ਦਾਦਾ ਦੋਵੇਂ ਡਾਕਟਰ ਸਨ।\n
#   2303519  ਅਜਿਹੇ ਇੱਕ ਪੋਸਟਕਾਰਡ ਨੂੰ ਦਾਦੀ, ਦਾਦਾ ਅਤੇ ਹੋਰ ਰਿਸ਼...
#   2415980          ਮੇਰੇ ਪਿਤਾ ਅਤੇ ਦਾਦਾ ਜੀ ਦੋਵੇਂ ਫੌਜ ਵਿਚ ਸਨ।\n
#   2471956              ਉਸ ਦੀ ਦਾਦੀ ਅਤੇ ਦਾਦਾ ਦੋਵੇਂ ਡਾਕਟਰ ਸਨ।\n
#   2562973  ਮੈਂ ਉਸ ਦੇ ਮਾਪਿਆਂ, ਦਾਦਾ-ਦਾਦੀ, ਚਾਚੇ-ਤਾਏ, ਭੂਆ-ਫੁੱ...
#   2565808              ਉਸ ਦੀ ਦਾਦੀ ਅਤੇ ਦਾਦਾ ਦੋਵੇਂ ਡਾਕਟਰ ਸਨ।\n
#   2650129  ਬੱਚਿਆਂ ਦੇ ਦਾਦਾ-ਦਾਦੀ ਅਤੇ ਨਾਨਾ-ਨਾਨੀ ਨੇ ਬਹੁਤ ਸਾਰੀ...
#   2771916      ਦੋਵਾਂ ਭਰਾਵਾਂ ਦੇ ਪਿਤਾ ਦੀ ਵੀ ਮੌਤ ਹੋ ਚੁੱਕੀ ਹੈ।\n
#   2795005          ਮੇਰੇ ਪਿਤਾ ਅਤੇ ਦਾਦਾ ਜੀ ਦੋਵੇਂ ਫੌਜ ਵਿਚ ਸਨ।\n
#   2935998  ਇਹ ਵਿਸ਼ੇਸ਼ ਤੌਰ 'ਤੇ ਸੱਚ ਹੈ ਜੇਕਰ ਬੱਚੇ ਦੇ ਦਾਦੇ ਜਾ...
#   2939087              ਉਸ ਦੀ ਦਾਦੀ ਅਤੇ ਦਾਦਾ ਦੋਵੇਂ ਡਾਕਟਰ ਸਨ।\n
#   3091079  ਇਸਦਾ ਅਰਥ ਇਹ ਹੈ ਕਿ ਇਸ ਲੇਖ ਨੂੰ ਪੜ੍ਹਨ ਵਾਲੇ ਮਰਦਾਂ ...
#   3359928                      ਦੋਵੇਂ ਹੀ ਪੇਸ਼ੇ ਤੋਂ ਡਾਕਟਰ ਸਨ।\n
#   3421888  ਰੂਸ ਦੇ ਸਟੇਟ ਲਾਟਰੀਆਂ ਦਾ ਅਜਿਹਾ ਅਮੀਰ ਇਤਿਹਾਸ ਹੈ, ਜ...
#   3442103                     – ਮੇਰੇ ਦਾਦਾ ਜੀ ਫ਼ੌਜ ਵਿੱਚ ਸਨ।\n
#   3449087  ” ਚੋਕਸੀ ਨੇ ਯਾਦ ਕੀਤਾ ਕਿ ਮੌਕਿਆਂ ਦੇ ਕਾਰਨ ਦੋ ਪੀੜ੍ਹ...
#   3620011  ਧੀਆਂ-ਭੈਣਾਂ, ਮਾਂ-ਪਿਉ, ਭੈਣ-ਭਰਾਵਾਂ, ਯਾਰ-ਮਿੱਤਰ ਅਤੇ...
#   3888927          ਮੇਰੇ ਪਿਤਾ ਅਤੇ ਦਾਦਾ ਜੀ ਦੋਵੇਂ ਫੌਜ ਵਿਚ ਸਨ।\n
#   3967758  ਆਮ ਤੌਰ 'ਤੇ, ਸਭ ਤਰ੍ਹਾਂ ਦੀ ਸੁੰਦਰ ਪਰਿਵਾਰਕ ਮਾਮਲਿਆਂ...
#   3982547  ਅਤੇ ਉਨ੍ਹਾਂ ਦੀਆਂ "ਦਾਦੀ" ਅਤੇ "ਦਾਦੇ" ਕਿਸ ਤਰ੍ਹਾਂ ਦ...
#   4069779  ਇਸ ਲਈ, ਅਸੀਂ ਆਪਣੇ ਮਹਾਨ ਦਾਦਾ ਜੀ ਵਾਂਗ ਨਹੀਂ ਹੋਵਾਂਗ...
#   4082859  ਇਹ ਸਾਡੇ ਪਤਨੀ, ਪਤੀ, ਮਾਤਾ, ਪਿਉ, ਦਾਦੀ ਹੋ ਸਕਦਾ ਹੈ,...
#   4345752                               ਦੋਵੇਂ ਸੱਸ ਨੂੰਹ ਹਨ।\n
# ...
#   1833935                         ସେମାନେ ମୋ ଅଣନାତି-ନାତୁଣୀ।\n
#   2257468  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   2559250  ଝିଅକୁ ଦୁଷ୍କର୍ମ କରିବା ଅଭିଯୋଗରେ ଜେଲରେ କାଟିଲେ ୧୦ ...
#   2578164                             ମୁଁ ବାପଘରକୁ ଯାଇଥିଲି।\n
#   2653981  ପରିବାରର ବାପା, ମା, ପିଲା ଛୁଆ, ଭାଇ, ଭଉଣୀ ସମସ୍ତେ ଏ...
#   2728000  ନାବାଳିକା ଦୁଷ୍କର୍ମ ମାମଲା, ଅଭିଯୁକ୍ତକୁ ୧୦ବର୍ଷ ସଶ୍...
#   2823755  ବାପା ମା’ ସାନ ଭାଇ, ଭାଇବୋହୂ, ପୁତୁରା, ଝିଆରୀ ଏମିତ...  ,
#   'aunts':                                                   eng_Latn  \
#   166694   A number of fires targeting local haunts and s...
#   337335   But it haunts me why I had to forgive him the ...
#   339344   But it's the house that still haunts my dreams.\n
#   623289   He said that his parents and uncles and aunts ...
#   691013                His crime continues to haunts him.\n
#   912258                           In fact, he taunts you.\n
#   920662   In the accident, the victim and her lawyer wer...
#   920663   In the accident, two aunts of the teen victim ...
#   983679                             It haunts the cinema.\n
#   1375723                    She taunts him night and day.\n
#   1430477                   Stay away from the old haunts.\n
#   1544437  The actress often flaunts photographs of her p...
#   1601621  The family also flaunts pictures via social me...
#   1695865  The rape survivor and her lawyer were critical...
#   1733500  The tragedy of the 16 migrant labourers run ov...
#   1741764  The victim and her lawyer have been critically...
#   1895446      This is a question that haunts every heart.\n
#   1934764     This question haunts almost every one of us.\n
#   1991938                      Trump's taunts are not new.\n
#   2267855                            haunts me at night...\n
#   2267856                        haunts me in the night...\n
#   2443295                   This question haunts everyone.\n
#   2501910     However, her two aunts died in the accident.\n
#   2508354                   This question haunts everyone.\n
#   2559380  The Maharashtra government must ignore all thi...
#   2587636  Her aunts succumbed to injuries in a district ...
#   2635650  Ranveer Singh flaunts various looks in the fil...
#   2646574  The complainant and her lawyer are in serious ...
#   2653981  Grandparents, parents, uncles, aunts, and chil...
#   2710328                   This question haunts everyone.\n
#   2712809                   This question haunts everyone.\n
#   2796405  Boys have sisters, mothers, aunts, and grandmo...
#   2820236                   This question haunts everyone.\n
#   2830192  Coming to the cameras, it flaunts an 8MP rear ...
#
#                                                     ory_Orya
#   166694   ଏହାବାଦ ସ୍ଥାନୀୟ ଅଞ୍ଚଳରେ ଥିବା ଅନେକ ଘର, ଦୋକାନରେ ମ...
#   337335   ମାତ୍ର ପଶ୍ଚାତାପ କରେ ଏହା ଭାବି ଯେ ମୁଁ କଣ ପାଇଁ ତାଙ...
#   339344   କିନ୍ତୁ ଇଏ କଣ ମୋର ସେଇ ସ୍ବପ୍ନର ଘର ଯାହାକୁ ମୁଁ ଏବେ...
#   623289   ସେ କହିଛନ୍ତି ଯେ ତାଙ୍କ ପିତାମାତା, ମାମୁଁ ଓ ମାଉସୀମା...
#   691013         ତାର ଅପରାଧବୋଧ ତାକୁ ନିରନ୍ତର ଲାଞ୍ଛିତ କରୁଛି ।\n
#   912258                  ପ୍ରକୃତରେ ସେ ଆପଣଙ୍କୁ ଗାଳି ଦେଉଛି ।\n
#   920662   ଏହି ଦୁର୍ଘଟଣାରେ ବଳାତ୍କାର ପୀଡ଼ିତା ଏବଂ ତାଙ୍କର ଓକି...
#   920663   ଯାହା ଫଳରେ ଘଟଣାସ୍ଥଳରେ ପୀଡ଼ିତାଙ୍କ ଦୁଇ ସଂପର୍କୀୟ ମ...
#   983679                ଏହା ସିନେମା ଜଗତକୁ କୁଠାରାଘାତ କରୁଛି ।\n
#   1375723                        ସେ ତାଙ୍କୁ ଦିନ ରାତି ଖଟଉଛି।\n
#   1430477                   ପୁରୁଣା ଝଞଟ ଠାରୁ ଦୂରରେ ରୁହନ୍ତୁ।\n
#   1544437  ଏହି ଅଭିନେତ୍ରୀ ପ୍ରାୟତଃ ନିଜ instagram ରେ ନିଜର ବୋ...
#   1601621  ପରିବାର ସହିତ ଫଟୋ ମଧ୍ୟ ସୋଶାଲ୍ ମିଡିଆରେ ଶେଆର୍ କରନ୍...
#   1695865  ଏହି ଦୁର୍ଘଟଣାରେ ବଳାତ୍କାର ପୀଡ଼ିତା ଏବଂ ତାଙ୍କର ଓକି...
#   1733500  ମେ ୮ ତାରିଖ ମହାରାଷ୍ଟ୍ରର ଔରଙ୍ଗାବାଦ ନିକଟରେ ୧୬ ଜଣ ...
#   1741764  ଏହି ଦୁର୍ଘଟଣାରେ ବଳାତ୍କାର ପୀଡ଼ିତା ଏବଂ ତାଙ୍କର ଓକି...
#   1895446              ଏହି ପ୍ରଶ୍ନ ସମସ୍ତ ମନରେ ଉଙ୍କି ମାରୁଛି।\n
#   1934764  ଏହି ପ୍ରଶ୍ନ ସବୁବେଳେ ସମସ୍ତଙ୍କୁ ପ୍ରାୟ ଆନ୍ଦୋଳିତ କର...
#   1991938     ତେବେ ଟ୍ରମ୍ପଙ୍କ ଏଭଳି ବେପରୁଆ ବୟାନ୍ ନୂଆ ନୁହେଁ ।\n
#   2267855                        ମୋତେ ରାତିରେ ରେପ୍ କଲେ. . .\n
#   2267856                        ମୋତେ ରାତିରେ ରେପ୍ କଲେ. . .\n
#   2443295                   ଏମିତି ପ୍ରଶ୍ନ ସମସ୍ତଙ୍କୁ ଘାରିଛି।\n
#   2501910  ତେବେ ଏଥିରେ କିନ୍ତୁ ତାଙ୍କର ଦୁଇ ଖୁଡ଼ି ମୃତ୍ୟୁବରଣ କ...
#   2508354       ଏହି ପ୍ରଶ୍ନ ସମସ୍ତଙ୍କ ମନକୁ ଆନ୍ଦେଳିତ କରୁଥିବ ।\n
#   2559380  ମହାରାଷ୍ଟ୍ର ସରକାର ଏସବୁକୁ(ଟିଭିରେ ଅର୍ଣ୍ଣବ ଗୋସ୍ୱାମ...
#   2587636  ପୀଡିତାଙ୍କ ମାଈଁ ଜିଲା ହସ୍ପିଟାଲ୍‌ରେ ମୃତ୍ୟୁବରଣ କରି...
#   2635650  ରଣବୀର ତାଙ୍କର ପ୍ରତିଟି ଫିଲ୍ମରେ ଭିନ୍ନ ଲୁକ୍‌ରେ ନଜର...
#   2646574  ଏଥିରେ ଦୁଇ ସମ୍ପର୍କୀୟଙ୍କ ମୃତ୍ୟୁ ଘଟିଥିବାବେଳେ ପୀଡ଼...
#   2653981  ପରିବାରର ବାପା, ମା, ପିଲା ଛୁଆ, ଭାଇ, ଭଉଣୀ ସମସ୍ତେ ଏ...
#   2710328             ଏହି ପ୍ରଶ୍ନ ସମସ୍ତଙ୍କୁ ଆନ୍ଦୋଳିତ କରୁଛି।\n
#   2712809            ଏହି ପ୍ରଶ୍ନ ଆଜି ବି ସମସ୍ତଙ୍କୁ ଥରାଇଥାଏ ।\n
#   2796405           ଘରେ ବାପା, ମାଆ, ଭାଇ ଭଉଣୀ ଓ ବୋହୂ ଅଛନ୍ତି।\n
#   2820236      ଏହି ପ୍ରଶ୍ନ ଏବେ ସମସ୍ତଙ୍କ ମନରେ ଉଙ୍କି ମାରିଛି ।\n
#   2830192  ଏହାର କ୍ୟାମେରା ବିଷୟରେ କହିଲେ ଏଥିରେ ୮ମେଗାପିକ୍ସେଲର...  ,
#   'grandfathers':                                                   eng_Latn  \
#   103      """ Both of his grandfathers were arrested on ...
#   274103   As a young kid I was inspired by both my grand...
#   693077    His father and both grandfathers were pastors.\n
#   1137646  Meaning - There Arjuna could see, within the m...
#   1171222                    My grandfathers were farmers.\n
#   1171307              My great-grandfathers were farmers.\n
#   1764888  There Arjuna could see, within the midst of th...
#   1764889  There Arjuna saw, in the midst of the armies o...
#   1863522  They're also educated, coming from very rich f...
#   1863523  They're also educated, coming from very rich f...
#   1863524  They're also educated, coming from very rich f...
#   1943436  This tradition has been passed down from our p...
#   2257468  ere, Arjun could see stationed in both armies,...
#   2808221  Both his grandfathers had been doctors, aa was...
#
#                                                     ory_Orya
#   103      """ [୮] ୧୯୩୦ ମସିହାରେ ତାଙ୍କ ଦୁଇ ଜେଜେବାପାଙ୍କୁ ମି...
#   274103   ପିଲାଦିନେ ମୁଁ ମୋ ଅଜା ଏବଂ ମୋ ମାମୁଁଙ୍କଠାରୁ ବହୁତ ଅ...
#   693077         ତାଙ୍କ ପିତା ଏବଂ ଜେଜେବାପା ଉଭୟ ପ୍ରଚାରକ ଥିଲେ।\n
#   1137646  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   1171222                    """ମୋର ପୂର୍ବଜମାନେ ଚାଷୀ ଥିଲେ।"\n
#   1171307                    """ମୋର ପୂର୍ବଜମାନେ ଚାଷୀ ଥିଲେ।"\n
#   1764888  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   1764889  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   1863522  ସେମାନେ ମଧ୍ୟ ଶିକ୍ଷିତ, ବହୁତ ଧନୀ ପରିବାରରୁ ମଧ୍ୟ ଆସ...
#   1863523  ସେମାନେ ମଧ୍ୟ ଶିକ୍ଷିତ, ବହୁତ ଧନୀ ପରିବାରରୁ ମଧ୍ୟ ଆସ...
#   1863524  ସେମାନେ ମଧ୍ୟ ଶିକ୍ଷିତ, ବହୁତ ଧନୀ ପରିବାରରୁ ମଧ୍ୟ ଆସ...
#   1943436    ଏହି ପରମ୍ପରା ଆମ ପୂର୍ବପୁରୁଷଙ୍କଠାରୁ ଚାଲି ଆସିଛି ।\n
#   2257468  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   2808221             ତାଙ୍କର ଅଜା ଓ ବାପା ଉଭୟେ ଡାକ୍ତର ଥିଲେ ।\n  ,
#   'grandmothers':                                                   eng_Latn  \
#   799647        I hear the voice of my grandmothers' song.\n
#   812580             I miss my grandmothers and my Mother.\n
#   812589                   I miss my mom and grandmothers.\n
#   812594                I miss my mom and my grandmothers.\n
#   1064787                      It's not just grandmothers.\n
#   1065106            It's not mine, it is my grandmothers.\n
#   1171279                           My grandmothers hands.\n
#   1819892              These are mothers and grandmothers.\n
#   1864350                   They're moms and grandmothers.\n
#   2076514  We've all seen old photographs of our mothers ...
#   2098003                What is your grandmothers's name?\n
#   2108855                   What's your grandmothers name?\n
#   2266149                                 grandmothers (4)\n
#   2796405  Boys have sisters, mothers, aunts, and grandmo...
#
#                                                     ory_Orya
#   799647                         ଜେଜେମା'ର ଗୀତ ଶୁଣି ଶୋଉଛି ।\n
#   812580            ମୋର ମାଆ ଓ ବଡ଼ଦେଈ କଥା ବହୁତ ମନେ ପଡ଼ିଲା ।\n
#   812589            ମୋର ମାଆ ଓ ବଡ଼ଦେଈ କଥା ବହୁତ ମନେ ପଡ଼ିଲା ।\n
#   812594            ମୋର ମାଆ ଓ ବଡ଼ଦେଈ କଥା ବହୁତ ମନେ ପଡ଼ିଲା ।\n
#   1064787                              କେବଳ ଜେମା ନୁହନ୍ତି ।\n
#   1065106  ମୋ ନିଜର ନହେଲେ ନାହିଁ ଏମାନେ ବି ତ ମୋ ନାତିନାତୁଣୀଙ୍...
#   1171279                               ମୋ ନାତୁଣୀର ହାତ ଧର।\n
#   1819892                    ସେମାନେ ହେଉଛନ୍ତି ଆଈ ଓ ନାତୁଣୀ ।\n
#   1864350                    ସେମାନେ ହେଉଛନ୍ତି ଆଈ ଓ ନାତୁଣୀ ।\n
#   2076514  ତେବେ ଆମେ ଆମ ମା ତଥା ଜେଜେମା ମାନଙ୍କର ପୁରାତନ ଫୋଟୋ ...
#   2098003                              ତୁମ ଜେଜେଙ୍କ ନାମ କ'ଣ\n
#   2108855                              ତୁମ ଜେଜେଙ୍କ ନାମ କ'ଣ\n
#   2266149                     ନାତି ନାତୁଣୀମାନେ (4) ପିତାମାତା\n
#   2796405           ଘରେ ବାପା, ମାଆ, ଭାଇ ଭଉଣୀ ଓ ବୋହୂ ଅଛନ୍ତି।\n  ,
#   'brothers in law': Empty DataFrame
#   Columns: [eng_Latn, ory_Orya]
#   Index: [],
#   'brothers-in-law':                                                   eng_Latn  \
#   2392717  Bolangir: A man was allegedly beaten to death ...
#   2462834  A mother and father-in law, two brothers-in-la...
#
#                                                     ory_Orya
#   2392717  ବଲାଙ୍ଗିର: ଜିଲ୍ଲାର ବଙ୍ଗୋମୁଣ୍ଡା ବ୍ଳକ ଅନ୍ତର୍ଗତ କୁ...
#   2462834  ଘରେ ତାଙ୍କ ବିଧବା ମା’, ଭାଉଜ ଦୁଇ ପୁତୁରା, ପତ୍ନୀ ଓ ...  ,
#   'sisters in law': Empty DataFrame
#   Columns: [eng_Latn, ory_Orya]
#   Index: [],
#   'sisters-in-law':                                                   eng_Latn  \
#   929556   In this video that has gone viral on the inter...
#   2462834  A mother and father-in law, two brothers-in-la...
#   2810408  Right: Hausabai (right) with her sisters-in-la...
#
#                                                     ory_Orya
#   929556   ଇଣ୍ଟରନେଟରେ ଭାଇରାଲ ହେଉଥିବା ଏହି ଭିଡିଓରେ ଦେଖାଯାଇପ...
#   2462834  ଘରେ ତାଙ୍କ ବିଧବା ମା’, ଭାଉଜ ଦୁଇ ପୁତୁରା, ପତ୍ନୀ ଓ ...
#   2810408  ଡାହାଣ - ସ୍ୱାଧୀନତା ପରେ ଉଠାଯାଇଥିବା ଗୋଟିଏ ଫଟୋରେ ହ...  ,
#   'cousins':                                                   eng_Latn  \
#   48567                            "Are they ""cousins""?"\n
#   128509   3 The men of Judah asked their cousins, the me...
#   148116   A Pakistani man married two cousins of his own.\n
#   186352   According to police, the cousins were in love ...
#   257965   Another of his cousins, North Korea's most pow...
#   321752                        Both were distant cousins.\n
#   505622   For years, the Kauravas, led by Duryodhan, had...
#   607618    He lives with his grandmother and two cousins.\n
#   608502   He loved my kids as much as he loved me and my...
#   869558   I'm the youngest in my family and one of the y...
#   897770   In 1926, she met Margaret E. Cousins, the foun...
#   897771   In 1926, she met the suffragette Margaret E. C...
#   897772   In 1926, she met the suffragette Margaret E. C...
#   1123252  Malan's younger sister (who is married and liv...
#   1139979  Meena was the first of the two cousins to star...
#   1277646  Parineeti Chopra, Meera Chopra and Mannara Cho...
#   1338903  Saeed Anwar also married one of his cousins Lu...
#   1422672  Sonam Kapoor and Ranveer Singh are maternal co...
#   1569205  The children, parents, grandparents and cousin...
#   1638534  The investigating agency had registered a case...
#   1638535  The investigating agency had registered a case...
#   1739171                    The two were distant cousins.\n
#   1800555  There was a quarrel between the two cousins ov...
#   1852993                  They played with their cousins.\n
#   1858472                       They were cousins of ours.\n
#   2082069     What Does It Mean to See Cousins in a Dream?\n
#   2173069  You can celebrate this day not only with your ...
#   2257468  ere, Arjun could see stationed in both armies,...
#   2485698  Arjun Kapoor, Sonam Kapoor and Rhea Kapoor are...
#   2565577  Actors Zayed Khan, Hrithik Roshan's ex-wife Su...
#   2594020  His grandparents, wife, children and cousins a...
#   2691670  Her cousins Kareena and Karisma Kapoor, daught...
#   2823755  Cousins, uncles, fathers, brothers, friends of...
#   2837378                  The two are said to be cousins.\n
#
#                                                     ory_Orya
#   48567                       "ସେମାନେ ହେଉଛନ୍ତି ""ବନ୍ଧୁ""?"\n
#   128509   3 ୟିହକ୍ସ୍ଟଦାର ପରିବାରବର୍ଗ ସମାନଙ୍କେର ଭାଇମାନେଶିମି...
#   148116   ପାକିସ୍ତାନର ଜଣେ ବ୍ୟକ୍ତି ନିଜ ଦାଦାଙ୍କ ଦୁଇ ଝିଅଙ୍କୁ...
#   186352   ପୋଲିସ ଅନୁଯାୟୀ ଭାଇ-ଭଉଣୀ ପରସ୍ପରକୁ ଭଲ ପାଉଥିଲେ ଏବଂ...
#   257965   ତାଙ୍କର ଆଉ ଜଣେ କକା ଏବଂ ଉତ୍ତର କୋରିଆର ସବୁଠାରୁ ଶକ୍...
#   321752                  ଉଭୟ ଥିଲେ ଦୂର ସମ୍ପର୍କୀୟ ଭାଇଭଉଣୀ ।\n
#   505622   ବର୍ଷ ବର୍ଷ ଧରି, ଦୁର୍ଯ୍ୟୋଧନଙ୍କ ନେତୃତ୍ୱରେ କୌରବମାନ...
#   607618   ସେ ତାଙ୍କ ଝିଅ ଓ ଦୁଇ ନାତି ନାତୁଣୀଙ୍କ ସହିତ ରହୁଛନ୍ତ...
#   608502     ସେ ମତେ ଓ ମୋ ପରି ପିଲାମାନଙ୍କୁ ବହୁତ ଭଲ ପାଆନ୍ତି ।\n
#   869558   ଆମ ପରିବାରର ସବୁଠାରୁ ବରିଷ୍ଠ ହେଉଛଣି ମୋର ଜେଜେ ଏବଂ ...
#   897770   ୧୯୨୬ମସିହାରେ ଅଲ୍ ଇଣ୍ଡିଆ ୱିମେନ୍ସ କଂଗ୍ରେସର ସଂସ୍ଥା...
#   897771   ୧୯୨୬ମସିହାରେ ଅଲ୍ ଇଣ୍ଡିଆ ୱିମେନ୍ସ କଂଗ୍ରେସର ସଂସ୍ଥା...
#   897772   ୧୯୨୬ମସିହାରେ ଅଲ୍ ଇଣ୍ଡିଆ ୱିମେନ୍ସ କଂଗ୍ରେସର ସଂସ୍ଥା...
#   1123252  ମାଲନଙ୍କ ସାନ ଭଉଣୀ (ବିବାହ କରି ପୁନେରେ ରହୁଛନ୍ତି) ଏ...
#   1139979  ଦୁଇ ସମ୍ପର୍କୀୟଙ୍କ ମଧ୍ୟରୁ ପ୍ରଥମେ ମୀନାର ଋତୁସ୍ରାବ ...
#   1277646  ଅଭିନେତ୍ରୀ ପ୍ରିୟଙ୍କା ଚୋପ୍ରା, ମୀରା ଚୋପ୍ରା ଏବଂ ମନ...
#   1338903  ସଇଦ୍ ଅନୱର୍ ମଧ୍ୟ ନିଜ ସମ୍ପର୍କୀୟ ଭଉଣୀ ଲୁବନାଙ୍କୁ 1...
#   1422672  ଅଭିନେତ୍ରୀ ସୋନମ କପୁର ଓ ଗଲି ବଏ ରଣବୀର ସିଂହ ହେଉଛନ୍...
#   1569205          ଶିଶୁର ମା', ବାପା, ଭଉଣୀ ଓ ଜେଜେବାପା ସମସ୍ତେ\n
#   1638534  ଏହି ଦୁର୍ନୀତି ଘଟଣାରେ କେନ୍ଦ୍ରୀୟ ତଦନ୍ତକାରୀ ଏଜେନ୍ସ...
#   1638535  ଏହି ଦୁର୍ନୀତି ଘଟଣାରେ କେନ୍ଦ୍ରୀୟ ତଦନ୍ତକାରୀ ଏଜେନ୍ସ...
#   1739171                 ଉଭୟ ଥିଲେ ଦୂର ସମ୍ପର୍କୀୟ ଭାଇଭଉଣୀ ।\n
#   1800555  ଏହାକୁ ନେଇ ଦୁଇଭାଇଙ୍କ ମଧ୍ୟରେ ଝଗଡା ଉଗ୍ରରୂପ ନେଇଥିଲ...
#   1852993                 ସମ୍ପର୍କୀୟ ଭାଇଭଣୀଙ୍କ ସହ ଖେଳୁଥିଲା।\n
#   1858472                   ସେମାନେ ଥିଲେ ଆମ ଲାସ୍ତାଲ କନ୍ତା ।\n
#   2082069   ପିତୃପୁରୁଷଙ୍କୁ ସ୍ୱପ୍ନରେ ଦେଖିବାର ଅର୍ଥ କଣ ରହିଛି ?\n
#   2173069  ଆପଣ ଏହି ଦିନଟି କେବଳ ତୁମର ତୁରନ୍ତ ଭାଇ ସହିତ ନୁହେଁ ...
#   2257468  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   2485698   ସୋନମ କପୁର ଏବଂ ଅର୍ଜୁନ କପୁର ସମ୍ପର୍କରେ ଭାଇ ଭଉଣୀ ।\n
#   2565577  ଫରାହ ଖାନ ଅଲି ହେଉଛନ୍ତି ଅଭିନେତା ହ୍ରିତିକ ରୋଶନଙ୍କ ...
#   2594020  ଘରେ ତାଙ୍କର ବୁଢ଼ା ବାପା, ବୁଢୀ ମା’, ପତ୍ନୀ ଓ ପିଲା ...
#   2691670  ସେହିପରି ତାଙ୍କ ଭାଇ ରଣଧୀରଙ୍କ ଝିଅ କରିନା କପୁର ଓ କର...
#   2823755  ବାପା ମା’ ସାନ ଭାଇ, ଭାଇବୋହୂ, ପୁତୁରା, ଝିଆରୀ ଏମିତ...
#   2837378          ଉଭୟେ ସମ୍ପର୍କରେ ଦିଅର-ଭାଉଜ ବୋଲି ଜଣାପଡ଼ିଛି।\n  ,
#   'nephews':                                                   eng_Latn  \
#   394195   Coverage available for proposer and up to 3 de...
#   902510   In Bengal, those village men who are experts i...
#   919550   In the 1830s, the 10th Earl of Home and his ne...
#   925750   In the s, the 10th Earl of Home and his nephew...
#   2257468  ere, Arjun could see stationed in both armies,...
#   2505526  Among other family members were his nephews Ra...
#   2743953  A mother, a father, brothers and sisters, niec...
#
#                                                     ory_Orya
#   394195   କଭରେଜ୍ ପ୍ରସ୍ତାବକ, ପତି ବା ପତ୍ନୀ ଏବଂ 3 ଜଣ ନିର୍ଭର...
#   902510   ବଙ୍ଗଳା ପ୍ରଦେଶରେ, ଉକ୍ତ ଗାଁର ପୁରୁଷମାନେ ଯେଉଁମାନେ ...
#   919550   ସନ ୧୮୩୦ରେ ଆଲେକଜାଣ୍ଡର ହୋମ, ଦଶମ ଇଅର୍ଲ ଅଫ ହୋମ (10...
#   925750   ସନ ୧୮୩୦ରେ ଆଲେକଜାଣ୍ଡର ହୋମ, ଦଶମ ଇଅର୍ଲ ଅଫ ହୋମ (10...
#   2257468  ଅର୍ଜୁନ ସେଠାରେ ଉଭୟ ପକ୍ଷ ସୈନ୍ୟବାହିନୀରେ ତାଙ୍କର ପି...
#   2505526  ରଣବୀର-ଆଲିଆଙ୍କ ବ୍ୟତୀତ ନୀତୁ କପୁର, ରିଦ୍ଧିମା କପୁର ...
#   2743953           ଘରେ ବାପା, ମାଆ, ଭାଇ ଭଉଣୀ ଓ ବୋହୂ ଅଛନ୍ତି।\n  ,
#   'nieces':                                                   eng_Latn  \
#   22021    """Some of them though have passed on the work...
#   394195   Coverage available for proposer and up to 3 de...
#   2519558  Among the dead, he said, were his wife, two ch...
#   2743953  A mother, a father, brothers and sisters, niec...
#
#                                                     ory_Orya
#   22021    "ରାହୁଲ କୁହନ୍ତି,""ସେମାନଙ୍କ ମଧ୍ୟରୁ କିଛି ଏହି କାମକ...
#   394195   କଭରେଜ୍ ପ୍ରସ୍ତାବକ, ପତି ବା ପତ୍ନୀ ଏବଂ 3 ଜଣ ନିର୍ଭର...
#   2519558  ମୃତକଙ୍କ ମଧ୍ୟରେ ଅଛନ୍ତି ସ୍ୱାମୀ, ସ୍ତ୍ରୀ ଓ ସେମାନଙ୍...
#   2743953           ଘରେ ବାପା, ମାଆ, ଭାଇ ଭଉଣୀ ଓ ବୋହୂ ଅଛନ୍ତି।\n  }}

# %%
df_list
# Out:
# {'pan_Guru':                                                   eng_Latn  \
#  816              """ You don't know what you're saying."\n
#  817            """ You gotta ask yourself one question."\n
#  818                           """ You have 3 seconds!"""\n
#  819                             """ You have a child?"""\n
#  820      """ You have saved me now three times...I had ...
#  ...                                                    ...
#  6275792                  All other amenities were great.\n
#  6275793   One person died while being taken to hospital.\n
#  6275794                      Aren’t we currently at war?\n
#  6275795            Car falls into canal,5 of family dead\n
#  6275796                                                 \n
#
#                                                    pan_Guru
#  816           """ਤੈਨੂੰ ਪਤਾ ਨਹੀਂ ਕਿ ਤੂੰ ਕੀ ਕਹਿ ਰਹੀਂ ਹੈਂ।"\n
#  817       'ਤੁਹਾਨੂੰ ਆਪਣੇ ਆਪ ਤੋਂ ਇਕ ਸਵਾਲ ਪੁੱਛਣਾ ਚਾਹੀਦਾ ਹੈ.\n
#  818                    """ਤੁਹਾਡੇ ਕੋਲ ਤੀਹ ਸਕਿੰਟ ਬਾਕੀ ਹਨ!"\n
#  819                           """ਤੁਹਾਡਾ ਕੋਈ ਬੱਚਾ ਵੀ ਹੈ?"\n
#  820      """ਤੁਸੀਂ ਹੁਣ ਤਿੰਨ ਵਾਰ ਮੈਨੂੰ ਬਚਾਇਆ ਹੈ . . . ਮੇਰ...
#  ...                                                    ...
#  6275792                           ਬਾਕੀ ਸਭ ਸਹੂਲਤਾਂ ਵੀ ਹਨ।\n
#  6275793  ਜਦੋਂ ਤੱਕ ਉਹ ਲੋਕ ਹਸਪਤਾਲ ਪਹੁੰਚੇ, ਇੱਕ ਬੰਦਾ ਮਰ ਚੁੱ...
#  6275794                             ਕੀ ਅਸੀਂ ਜੰਗ ਵਿਚ ਹਾਂ?\n
#  6275795  ਭਿਆਨਕ ਸੜਕ ਹਾਦਸੇ 'ਚ ਕਾਰ ਤਬਾਹ, ਪਰਿਵਾਰ ਦੇ 5 ਜੀਆਂ ...
#  6275796                                                 \n
#
#  [6274981 rows x 2 columns],
#  'ben_Beng':                                                    eng_Latn  \
#  0                                 ! capital of the State.\n
#  1                                       ! detailed below.\n
#  2                                  ! for the same reason.\n
#  3                ! his son had fallen in love with a girl\n
#  4         ! is a special character to bash, it is used t...
#  ...                                                     ...
#  16055070  However, Home Ministry has denied receiving an...
#  16055071           He was lucky on quite a few occasions.\n
#  16055072                          Because it so often is.\n
#  16055073                   Be certain you want to get to.\n
#  16055074                                                 \n
#
#                                                     ben_Beng
#  0                                        রাজ্যের রাজধানী!\n
#  1                                         নিচে বিস্তারিত.\n
#  2                                          সেই একই কারণে!\n
#  3                     আমার ছেলে একটি মেয়ের প্রেমে পড়েছে\n
#  4         bash এর একটি বিশেষ চরিত্র, এটি পূর্ববর্তী কমান...
#  ...                                                     ...
#  16055070  অবশ্য কেন্দ্রীয় স্বরাষ্ট্রমন্ত্রক এই ধরনের খবর...
#  16055071                 এরকম অনেক বিষয়ে সে ভাগ্যবান ছিল।\n
#  16055072                            কারণ এমনটা প্রায়ই হয়।\n
#  16055073           নিশ্চিত হন আপনি সেখানে আসলেও যেতে চান।\n
#  16055074                                                 \n
#
#  [16055075 rows x 2 columns]}

# %% [markdown]
# ## Dict of partition of translations

# %%
# load file from lang_rel_dict/ory_Orya/ory_Orya_grandmother_bpcc.csv
df_lang_rel = pd.read_csv('lang_rel_dict/ory_Orya/ory_Orya_grandmother_bpcc.csv')

df_lang_rel
# Out:
#                                               eng_Latn  \
# 0    """Dreams come true, my roommate Pradeep Krish...
# 1    """I never got a paisa's compensation from gov...
# 2    """I would see the child in only her underwear...
# 3    """I've become a grandmother,"" she says, ""bu...
# 4    """My grandmother was the first person that I ...
# ..                                                 ...
# 353  He has a grandmother, wife and three children ...
# 354   The mother and grandmother have been arrested.\n
# 355                     But I am not my Grandmother.\n
# 356                       "My grandmother said . . .\n
# 357  The boy's mother, grandmother and brother also...
#
#                                               ory_Orya
# 0    ଏହାସହ ନାଗାର୍ଜୁନ ଲେଖିଛନ୍ତି, ' ସ୍ୱପ୍ନ ସତ ହେଲା, ମ...
# 1    """କ୍ଷତିପୂରଣ ବାବଦକୁ ମୁଁ ସରକାରଙ୍କ ଠାରୁ କାଣି କଉଡ...
# 2    """ମୁଁ ଶିଶୁଟିକୁ କେବଳ ଚଡ଼ି ପିନ୍ଧି ଚୁପ୍ଚାପ୍ ତା' ...
# 3    "ସେ କୁହନ୍ତି, ""ମୁଁ ଗୋଟିଏ ଆଈ ହୋଇଯାଇଛି କିନ୍ତୁ ଜଣ...
# 4    ସେ କହିଥିଲେ ଯେ, ମୋର ଜେଜେ ହେଉଛନ୍ତି ପ୍ରଥମ ବ୍ୟକ୍ତି...
# ..                                                 ...
# 353  ସେହି ଘରେ ତା ସ୍ତ୍ରୀ କାଞ୍ଚନ, ବୁଢ଼ୀ ମାଆ ଆଉ ପିଲା ତ...
# 354                   ଶାଶୁ-ଶ୍ୱଶୁରଙ୍କୁ ଗିରଫ କରାଯାଇଛି।\n
# 355                           କିନ୍ତୁ ମୁଁ ବୋକା ନୁହେଁ।\n
# 356                                ” ଏନେଇ ମାଆ କହିଲା…\n
# 357  ଛୁରାମାଡ଼ରେ ଭଉଣୀ, ଭଣଜା ଓ ପୁତୁରା ମଧ୍ୟ ଆହତ ହୋଇଛନ୍...
#
# [358 rows x 2 columns]

# %%
possible_odia_grandmother = ['ଜେଜେମା', 'ଆଈ']
# TODO: dictionary of such words language wise with paternal or maternal annoattaion

possible_indic_relations = {
    'grandmother': {
        #od done
        'ory_Orya': {
            'ଜେଜେମା': {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'F',


            },
            'ଆଈ': {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            }

        },
        #bn done
        'ben_Beng': {
            'ঠাকুরমা': {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            ' দিদি মা': {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            }
           

        },
        #guj done
        'guj_Gujr': {
           'દાદી':
            {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'નાની':
            {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            }
        },
       
       #done
        'hin_Deva': {
           'दादी':
            {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'नानी':
            {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            }
        },
       # kn done
        'kan_Knda': {
            'ಅಜ್ಜಿ': {
                'description': 'mother of father or mother',
                'relation': 'both',
                'relation_code': 'B',
                'gender': 'F'
            }
        },
       
       #TODO
        'mal_Mlym': {
            
            'അമ്മൂമ്മ':
            {
                'description': 'mother of father or mother',
                'relation': 'both',
                'relation_code': 'B',
                'gender': 'F'
            }
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        #tam done
        'tam_Taml': {
            'அப்பத்தா':
            {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'அம்மத்தா':
            {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            },

            'சின்ன பாட்டி':
            {
                'description': 'younger grandmother',
                'relation': 'Both',
                'relation_code': 'B',
                'gender': 'F'
            },
            'பெரிய பாட்டி':
             {
                'description': 'elder grandmother',
                'relation': 'Both',
                'relation_code': 'B',
                'gender': 'F'
            },
            'பாட்டி':
            {
                'description': 'grandmother',
                'relation': 'Both',
                'relation_code': 'B',
                'gender': 'F'
            }
        },
        # telugu done
        'tel_Telu': {
            'నాన్నమ్మ':
            {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'అమ్మమ':
            {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            },

            'నాన్నమ ':
            {
                'description': 'father\'s mother\'s sister',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'చిన్న నాన్నమ':
            {
                'description': 'father\'s mother\'s younger sister',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'పెద్ద  నాన్నమ':
            {
                'description': 'father\'s mother\'s elder sister',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            
            'అమ్మమ':
            {
                'description': 'mother\'s mother\'s sister',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            },
            'చిన్న అమ్మమ':
            {
                'description': 'mother\'s mother\'s younger sister',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            },
            'పెద్ద అమ్మమ':
            {
                'description': 'mother\'s mother\'s elder sister',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            },
        },
        #Punjabi done
        'pan_Guru': {
            
            'ਦਾਦੀ':
            {
                'description': 'mother of father',
                'relation': 'paternal',
                'relation_code': 'M',
                'gender': 'F'
            },
            'ਨਾਨੀ':
            {
                'description': 'mother of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'F'
            }
        }

    }
    ,

    'grandfather':{
        #done
        'ory_Orya': {
              'ଜେଜେବାପା': {
                'description': 'father of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'ଅଜା': {
                'description': 'father of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'M'
            }
           
          
        },
        #done
        'ben_Beng': {
                'ঠাকুরদা': {
                'description': 'father of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'দাদু': {
                'description': 'father of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'M'
            }
           
        },
        #done
        'guj_Gujr': {
             'દાદા': {
                'description': 'father of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'નાના': {
                'description': 'father of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'M'
            }
           
        },
        #done
        'hin_Deva': {
             'दादा': {
                'description': 'father of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'नाना': {
                'description': 'father of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'M'
            }
           
        },
       #done
        'kan_Knda': {
              'ಅಜ್ಜ': {
                'description': 'father of father or mother',
                'relation': 'Both',
                'relation_code': 'B', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',
            },
           
           
        },
        #done
        'mal_Mlym': {
            'അപ്പൂപ്പൻ': {
                'description': 'father of father or mother',
                'relation': 'Both',
                'relation_code': 'B', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',
            }

        },
        
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        # done
        'tam_Taml': {
              'தாத்தா': {
                'description': 'father of father or mother',
                'relation': 'both',
                'relation_code': 'B', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',
              },
              'சின்ன தாத்தா': {
                'description': 'mother\'s or father\'s father\'s younger brother',
                'relation': 'both',
                'relation_code': 'B', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',
              },
                'பெரிய தாத்தா': {
                    'description': 'mother\'s or father\'s father\'s elder brother',
                    'relation': 'both',
                    'relation_code': 'B',
                    'gender': 'M',
                }


            
            
           
        },
        'tel_Telu': {
             'తాతయ్యగారు': {
                'description': 'father of father or mother',
                'relation': 'both',
                'relation_code': 'B', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'తాతయ్య': {
                'description': 'grandfather',
                'relation': 'both',
                'relation_code': 'B',
                'gender': 'M'
            },
            'చిన్న తాతయ్య':
            {
                 'description': 'younger grandfather',
                'relation': 'both',
                'relation_code': 'B',
                'gender': 'M'
            },
            'పెద్ద తాతయ్య':
            {
                 'description': 'elder grandfather',
                'relation': 'both',
                'relation_code': 'B',
                'gender': 'M'
            }

            
        },
        'pan_Guru': {
             'ਦਾਦਾ': {
                'description': 'father of father',
                'relation': 'paternal',
                'relation_code': 'M', # Male or Female Side of me or my immediate family or BOth or None
                'gender': 'M',


            },
            'ਨਾਨਾ': {
                'description': 'father of mother',
                'relation': 'maternal',
                'relation_code': 'F',
                'gender': 'M'
            }
        }

    },
          'uncle': {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    },
            'aunt': {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    },
      'brother-in-law': {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    },
    'sister-in-law':{
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    }   
   , 'cousin': {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    }
,'child':      {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    }
,'nephew'    : {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    }
,'niece':
   {
        'ory_Orya': {
            'paternal': ['ଜେଜେମା'],
            'maternal': ['ଆଈ']
        },
        'ben_Beng': {
            'paternal': ['ঠাকুরমা'],
            'maternal': ['দিদা']
        },
        'guj_Gujr': {
            'paternal': ['જેઠી'],
            'maternal': ['આઈ']
        },
        'hin_Deva': {
            'paternal': ['दादीमा'],
            'maternal': ['नानी']
        },
        'kan_Knda': {
            'paternal': ['ಅಜ್ಜಿ'],
            'maternal': ['ತಾಯಿ']
        },
        'mal_Mlym': {
            'paternal': ['പാട്ടിക'],
            'maternal': ['അമ്മമ്മ']
        },
        'mar_Deva': {
            'paternal': ['आजी'],
            'maternal': ['आई']
        },
        'tam_Taml': {
            'paternal': ['பாட்டி'],
            'maternal': ['அம்மா']
        },
        'tel_Telu': {
            'paternal': ['నానమ్మ'],
            'maternal': ['అమ్మ']
        },
        'pan_Guru': {
            'paternal': ['ਦਾਦੀ'],
            'maternal': ['ਨਾਨੀ']
        }

    }

}

# %%
# # cross the no.of langs in each word

# for word in ambiguos:
#     for lang in df_dict:
#         if word in df_dict[lang]:
#             print(lang, word, df_dict[lang][word].shape)

# %%
# make a dictionary odia_grandmother_dict with key as the word from possible_odia_grandmother and value as the 
# dataframe containing that row from df_odia_grandmother.
# if any sentence is not having any possible word from possible_odia_grandmother, then add that sentence to the
# 'others' key in the odia_grandmother_dict

result_dict = {}
for word in ambiguos:
    result_dict[word] = {}
    for lang in df_dict:
        lang_dict = {}
        for indic_word in possible_indic_relations[word][lang]['paternal']:
            lang_dict[indic_word] = df_lang_rel[df_lang_rel[lang].str.contains(indic_word, case=False, )]
            print(indic_word, lang_dict[indic_word].shape)
        
        lang_dict['others'] = df_lang_rel[~df_lang_rel[lang].str.contains('|'.join(possible_odia_grandmother), case=False, )]
        print('others', lang_dict['others'].shape)
        result_dict[word][lang] = lang_dict

lang_dict
# Out:
# ଜେଜେମା (121, 2)
# ଆଈ (6, 2)
# others (231, 2)
# {'ଜେଜେମା':                                               eng_Latn  \
#  0    """Dreams come true, my roommate Pradeep Krish...
#  1    """I never got a paisa's compensation from gov...
#  2    """I would see the child in only her underwear...
#  5        """My grandmother worked outside the home."\n
#  6                      """Now you see, grandmother!"\n
#  ..                                                 ...
#  326                            the grandmother died.\n
#  327                          the grandmother's house\n
#  329                   where my grandmother was born.\n
#  347  New Delhi: Congress chief Rahul Gandhi paid tr...
#  351  At home, there is my grandmother, grandfather,...
#
#                                                ory_Orya
#  0    ଏହାସହ ନାଗାର୍ଜୁନ ଲେଖିଛନ୍ତି, ' ସ୍ୱପ୍ନ ସତ ହେଲା, ମ...
#  1    """କ୍ଷତିପୂରଣ ବାବଦକୁ ମୁଁ ସରକାରଙ୍କ ଠାରୁ କାଣି କଉଡ...
#  2    """ମୁଁ ଶିଶୁଟିକୁ କେବଳ ଚଡ଼ି ପିନ୍ଧି ଚୁପ୍ଚାପ୍ ତା' ...
#  5                     ଜେଜେମା' ଘର ବାହାରେ କାମ କରୁଥିଲେ।\n
#  6                              """ହେଇ ଦେଖ ଜେଜେମାଆ !"\n
#  ..                                                 ...
#  326                       ଜେଜେମା'ଙ୍କ ମୃତ୍ୟୁ ଘଟିଥିଲା।\n
#  327                                      ଜେଜେମା'ର ଘର\n
#  329                  ଯେଉଁଠି ମୋ ଜେଜେମାଆ ଜନ୍ମ ହୋଇଥିଲେ।\n
#  347  ଏହି ଅବସରରେ କଂଗ୍ରେସ ନେତା ରାହୁଲ ଗାନ୍ଧୀ ତାଙ୍କ ଜେଜ...
#  351  ଘରେ ଥାଆନ୍ତି ଜେଜେବାପା, ଜେଜେମା, ବୋଉ, ମୁଁ ଆଉ ମୋ ସ...
#
#  [121 rows x 2 columns],
#  'ଆଈ':                                               eng_Latn  \
#  3    """I've become a grandmother,"" she says, ""bu...
#  27   Apart from being a freedom fighter, writer, tr...
#  31   Bollywood actress Raveena Tandon set to become...
#  223  Revathi and her sister were able to go to scho...
#  281              These are mothers and grandmothers.\n
#  283                   They're moms and grandmothers.\n
#
#                                                ory_Orya
#  3    "ସେ କୁହନ୍ତି, ""ମୁଁ ଗୋଟିଏ ଆଈ ହୋଇଯାଇଛି କିନ୍ତୁ ଜଣ...
#  27   ଆପଣ ଜଣେ ସ୍ୱାଧୀନତା ସଂଗ୍ରାମୀ, ଲେଖିକା, ଅନୁବାଦିକା ...
#  31   ବଲିଉଡ୍ର ମସ୍ତ ମସ୍ତ ଗାର୍ଲ ରବୀନା ଟଣ୍ଡନ ଖୁବ୍ଶୀଘ୍ର ...
#  223  ୭୬ ବର୍ଷୀୟ ବୟସ୍କା ଆଈଙ୍କ ବଡ଼ପଣ ହେତୁ ରେବତୀ ଏବଂ ତା...
#  281                    ସେମାନେ ହେଉଛନ୍ତି ଆଈ ଓ ନାତୁଣୀ ।\n
#  283                    ସେମାନେ ହେଉଛନ୍ତି ଆଈ ଓ ନାତୁଣୀ ।\n  ,
#  'others':                                               eng_Latn  \
#  4    """My grandmother was the first person that I ...
#  8             """What are you doing, Grandmother?"""\n
#  9             """What are you doing, grandmother?"""\n
#  11                             """Your grandmother?"\n
#  12   "But my grandmother, she wasn't having it,"" h...
#  ..                                                 ...
#  353  He has a grandmother, wife and three children ...
#  354   The mother and grandmother have been arrested.\n
#  355                     But I am not my Grandmother.\n
#  356                       "My grandmother said . . .\n
#  357  The boy's mother, grandmother and brother also...
#
#                                                ory_Orya
#  4    ସେ କହିଥିଲେ ଯେ, ମୋର ଜେଜେ ହେଉଛନ୍ତି ପ୍ରଥମ ବ୍ୟକ୍ତି...
#  8                                  """କଣ କରୁଛ ଜେମା?"\n
#  9                                  """କଣ କରୁଛ ଜେମା?"\n
#  11                                 """ତୋର ଦାଦାଙ୍କୁ?"\n
#  12    "କିନ୍ତୁ ମୋ ଶାଶୂ ଏହାକୁ ପାଇନଥିଲେ,"" ସେ କହିଥିଲେ।"\n
#  ..                                                 ...
#  353  ସେହି ଘରେ ତା ସ୍ତ୍ରୀ କାଞ୍ଚନ, ବୁଢ଼ୀ ମାଆ ଆଉ ପିଲା ତ...
#  354                   ଶାଶୁ-ଶ୍ୱଶୁରଙ୍କୁ ଗିରଫ କରାଯାଇଛି।\n
#  355                           କିନ୍ତୁ ମୁଁ ବୋକା ନୁହେଁ।\n
#  356                                ” ଏନେଇ ମାଆ କହିଲା…\n
#  357  ଛୁରାମାଡ଼ରେ ଭଉଣୀ, ଭଣଜା ଓ ପୁତୁରା ମଧ୍ୟ ଆହତ ହୋଇଛନ୍...
#
#  [231 rows x 2 columns]}

# %% [markdown]
# # defining relations

# %%
def contains_reln(sent, list_relations, is_eng=False):
  # print(sent, list_relations[0])
  # for reln in list_relations:
  #       if reln in sent:
  #           # print(sent, reln)
  #           return True
  # return False
  # check if any of the relations in list_relations are present in the sentence sent. do check with lower case if lowercase is allowed
  if is_eng:
      for reln in list_relations:
        if reln.lower() in sent.lower():
            # print(sent, reln)
            return True
  else:
      return any(reln in sent for reln in list_relations)

# %%
relations_odia = ['ବାପା',  # Father
                  'ପିତା', 'ମାତା', 'ବୋଉ'
'ନାନା',  # Nānā
    # 'ମା\'',  # Mother
    'ଭାଇ',  # Brother
    'ଭଉଣୀ',  # Sister
    'ପୁଅ',  # Son
    'ଝିଅ',  # Daughter
    'ଦିଦି',  # Didi
    'ଜେଜେମା',  # Jejemā
    'ଜେଜେବାପା',  # Jejebāpā
    'ନାତି',  # Nāti
    'ନାତୁଣୀ',  # Nātuṇī
    'ଅଣନାତି',  # Aṇanāti
    'ଅଣନାତୁଣୀ',  # Aṇanātuṇī
    'ପଣନାତି',  # Paṇanāti
    'ପଣନାତୁଣୀ',  # Paṇanātuṇī
    'ଶଳା',  # Śālā
    'ଶାଳୀ',  # Śālī
    'ଭାଉଜ',  # Bhāuja
    'ନଣନ୍ଦ',  # Nanannda
    'ଭିନେଇ',  # Bhinēi
    'ଦିଆର',  # Diāra
    # 'ଜା\'',  # Jā
    'ଭାଇବୋହୁ',  # Bhāibohu
    'ନଣନ୍ଦେଇ',  # Nanandei
   'ଦାଦା',  # Dādā
    'ଖୁଡ଼ି',  # Khudi
    'ବଡ଼ବାପା',  # Baḍabāpā
    'ବଡ଼ମା',  # Baḍamā
    'ମାମୁ',  # Māmu
    'ମାଇଁ',  # Māiṁ
   'ମାଉସୀ',
'ମଉସା',
    'ପିସା',  # Pisā
    'ପିସୀ',  # Pisī
    'ଝିଆରୀ',  # Jhīārī
    'ପୁତୁରା',  # Puturā
    'ଭଣଜା',  # Bhāṇajā
      # Bhāṇajī
      'ଜ୍ୱାଇଁ',  # Jwāiṁ
    'ଶାଶୁ',  # Śāśu
    'ଶ୍ୱଶୁର'  # Śāśurā
    'ବୋହୁ',  # Bohu
    'ସମୁଧି',  # Samudhi
    'ସମୁଧୁନୀ',  # Samudhuni
    'ଜେଜେଶାଶୁ',  # Jejeśāśu
    'ସ୍ୱାମୀ',  # Swāmī
    'ସ୍ତ୍ରୀ',  # Strī
    'ବୋଉଲା',  # Boula
    'ସଙ୍ଗାତ' ,
'ଭାଣିଜୀ',
'ଦେଢ଼ଶୁର',
'ଦେଢଶଶୁର  ','ଦେଢ଼ଶାସୁ ','ସଢ଼ୁ','ସାବତ', 'ଅଜା', 'ଆଈ']

relations_hindi =['पिता', 'माँ', 'भाई', 'बहन', 'बेटा', 'बेटी', 'दीदी', 'दादी माँ', 'दादा जी', 'दादा',
                  'नाना', 'नानी', 'चाचा', 'चाची', 'मामा', 'मामी', 'भतीजा', 'भतीजी', 'भांजा', 'भांजी',
                  'जीजा', 'जीजी', 'देवर', 'देवरानी', 'जेठ', 'जेठानी', 'सास', 'सासु', 'ननद', 
                  'भाभी',  'बहू', 'पोता','पोती', 'नातिन', 'साला','साली', 'परपोती ', 'परपोता ',  'मौसा ',
                   'मौसी ',  'भतीजे ',  'दामाद ', 'सास','ससुर ', 'बहनोई ', 'पति ', 'पत्नी ', 'सौतेला', 'सौतेली',
                   'ननदोई', 'काका', 'काकी', 'बुआ', 'फूफा',  'समधी', 'समधन', 
                   
                   ]

print("Lengths:", len(relations_odia), len(relations_hindi))
# Out:
# Lengths: 56 56

# %% [markdown]
# # Conclusion
