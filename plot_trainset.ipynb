  'kan_Knda': {'others': 3},
  'pan_Guru': {'others': 3},
  'tel_Telu': {'others': 3},
  'mal_Mlym': {'others': 3},
  'guj_Gujr': {'others': 3},
  'ben_Beng': {'others': 3}},
 'cousin': {'tam_Taml': {'others': 2},
  'mar_Deva': {'चुलत बहीण': 2},
  'ory_Orya': {'ଭାଇ': 2},
  'hin_Deva': {'भाई': 2},
  'kan_Knda': {'others': 2},
  'pan_Guru': {'others': 2},
  'tel_Telu': {'others': 2},
  'mal_Mlym': {'others': 2},
  'guj_Gujr': {'others': 2},
  'ben_Beng': {'ভাই': 2}}}

data = { # google trans data
    'child': {'tam_Taml': {'others': 58},
  'mar_Deva': {'others': 58},
  'ory_Orya': {'ପିଲା': 52, 'others': 6},
  'hin_Deva': {'others': 58},
  'kan_Knda': {'others': 54, 'ಮಗ': 4},
  'pan_Guru': {'others': 58},
  'tel_Telu': {'others': 58},
  'mal_Mlym': {'കുട്ടി': 52, 'others': 6},
  'guj_Gujr': {'બાળક': 52, 'others': 6},
  'ben_Beng': {'others': 58}},
 'aunt': {'tam_Taml': {'others': 3},
  'mar_Deva': {'others': 3},
  'ory_Orya': {'others': 3},
  'hin_Deva': {'others': 3},
  'kan_Knda': {'others': 3},
  'pan_Guru': {'others': 3},
  'tel_Telu': {'others': 3},
  'mal_Mlym': {'others': 3},
  'guj_Gujr': {'others': 3},
  'ben_Beng': {'others': 3}},
 'cousin': {'tam_Taml': {'others': 2},
  'mar_Deva': {'चुलत भाऊ': 2},
  'ory_Orya': {'ଭାଇ': 2},
  'hin_Deva': {'बहन': 2},
  'kan_Knda': {'others': 2},
  'pan_Guru': {'ਭੈਣ': 2},
  'tel_Telu': {'others': 2},
  'mal_Mlym': {'ബന്ധു': 2},
  'guj_Gujr': {'others': 2},
  'ben_Beng': {'ভাই': 2}}}

# %%
import importlib
import os
import possible_indic_relations as poss_indic_rel
# Reload the module to reflect changes
importlib.reload(poss_indic_rel)

pir= poss_indic_rel.possible_relations
pir
# Out:
# {'grandmother': {'ory_Orya': {'ଜେଜେମା': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'ଆଈ': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'ben_Beng': {'ঠাকুরমা': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'দিদি মা': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'guj_Gujr': {'દાદી': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'નાની': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'hin_Deva': {'दादी': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
# ...

# %%
# make a new dictionary of structure: level 1- relation, level 2- language, level 3- relation_code, level 4- count

data_FM_related = {}
data_gender_related = {}
# df = data_gender_related
df = data_FM_related
for relation in data:
    df[relation] = {}
    for lang in data[relation]:
        df[relation][lang] = {}
        # print(data[relation][lang].keys())
        for key in data[relation][lang].keys():
            # display the relation_code for that key from pir
            # print(key)
            # print(pir[relation][lang])
            temp_key =None
            if key in pir[relation][lang]:
                # print(key, pir[relation][lang][key]['relation_code'])
                # temp_key = pir[relation][lang][key]['relation_code']
                temp_key = pir[relation][lang][key]['gender']
                
            else :
                # print(key, "not found: others: X")
                temp_key = 'others'

            if temp_key in df[relation][lang]:
                df[relation][lang][temp_key] += data[relation][lang][key]
            else:
                df[relation][lang][temp_key] = data[relation][lang][key]
            # print(key, pir[relation][lang][key]['relation_code'])
            # data_new[relation][lang][pir[relation][lang][key]] = data[relation][lang][key]

# data_FM_related
# data_gender_related

# %%
colours_map={
    'F': '#ff9999',
    'M': '#66b3ff',
    'B':     '#99ff99',
    'others': '#ffcc99',
    'N': '#c2c2f0'
}

# %%
import matplotlib.pyplot as plt
import numpy as np


def create_stacked_bar_graph(data, title):
    languages = list(data.keys())
    categories = set()
    
    # Collect all categories
    for lang in languages:
        categories.update(data[lang].keys())
    
    categories = list(categories)
    print(categories)
    
    # Prepare data for plotting
    values = {category: [] for category in categories}
    
    for lang in languages:
        for category in categories:
            values[category].append(data[lang].get(category, 0))

    # for each label or category, check corresponding value of relation_code in pir 
    # for category in categories:
    #     for lang in languages:
    #         if category in pir[root_word][lang].keys():
    #             print(category, lang, pir[root_word][lang][category]['relation_code'])
    #         else:
    #             print(category, lang, "Not found: Both")


    # Plotting
    fig, ax = plt.subplots()
    
    bottom = [0] * len(languages)
    # Define custom colors
    # colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6','#c4e17f','#76d7c4','#ff6f61','#6b5b95',
    #           '#feb236','#d64161','#ff7b25','#f4d35e','#ee8572','#8d99ae','#f9c22e','#405d27','#d9bf77','#f4f1de',
    #             '#a8dadc','#457b9d','#1d3557','#e63946','#f1faee','#a8dadc','#457b9d','#1d3557','#e63946','#f1faee',
    #           ]
    for i, category in enumerate(categories):
        bars = ax.bar(languages, values[category], label=category, bottom=bottom, color=colours_map[category])
        bottom = [i + j for i, j in zip(bottom, values[category])]
        
        # Adding labels
        for bar in bars:
            height = bar.get_height()
            if height > 0:
                ax.annotate(f'{height}',
                            xy=(bar.get_x() + bar.get_width() / 2, bar.get_y() + height / 2),
                            xytext=(0, 0),  # 0 points vertical offset
                            textcoords="offset points",
                            ha='right', va='center_baseline')
    
    ax.set_title(title)
    ax.set_ylabel('Count')
    ax.legend()
    # show legend on the right side outside of the plot
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    # set height and width of the plot
    fig.set_figheight(8)
    fig.set_figwidth(12)
  # set x -ticks and y ticks
    ax.set_xticks(languages)
    ax.set_yticks(range(0, max(bottom) * 2, 100))
    ax.set_xticklabels(languages)
    ax.set_yticklabels(range(0, max(bottom) * 2, 100))
    
    # Adding gap at the top of the y-axis
    ax.set_ylim(0, max(bottom) * 1.1)
    
    plt.xticks(rotation=90)

     
    # Use the Noto Sans font
    # prop = fm.FontProperties(fname=noto_sans)
    # for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    #     label.set_fontproperties(prop)

        
    # Adjust layout to make room for the labels
    plt.tight_layout()
    
    # Save figure
    plt.savefig('results/source_wise/FM_test_googleT_'+title+'.png')
    
    plt.show()
    
    # # Use a font that supports the required characters
    # plt.rcParams['font.family'] = 'Noto Sans'
    
    # plt.show()



# for word in data_FM_related:
    # create_stacked_bar_graph(data_FM_related[word], word)

for word in df:
    create_stacked_bar_graph(df[word], word)
# Out:
# ['N', 'others', 'M']
# ['others']
# ['F', 'others', 'M']
