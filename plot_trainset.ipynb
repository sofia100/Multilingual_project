  'mal_Mlym': {'അമ്മാവൻ': 8, 'others': 54},
  'guj_Gujr': {'કાકા': 29, 'મામા': 5, 'others': 12},
  'ben_Beng': {'মামা': 12, 'others': 52, 'কাকু': 1}},
 'grandmother': {'tam_Taml': {'பாட்டி': 34},
  'mar_Deva': {'आजी': 28, 'others': 8},
  'ory_Orya': {'others': 2, 'ଜେଜେମା': 7},
  'hin_Deva': {'नानी': 4, 'दादी': 25, 'others': 6},
  'kan_Knda': {'ಅಜ್ಜಿ': 20, 'others': 1},
  'pan_Guru': {'ਦਾਦੀ': 10, 'ਨਾਨੀ': 2},
  'tel_Telu': {'అమ్మమ': 12, 'నాన్నమ్మ': 1, 'others': 8},
  'mal_Mlym': {'അമ്മൂമ്മ': 4, 'others': 16},
  'guj_Gujr': {'દાદી': 19, 'નાની': 4, 'others': 8},
  'ben_Beng': {'ঠাকুরমা': 5, 'others': 35}},
 'cousin': {'tam_Taml': {'others': 22, 'தம்பி': 1},
  'mar_Deva': {'चुलत भाऊ': 19, 'others': 16, 'चुलत बहीण': 2},
  'ory_Orya': {'ଭାଇ': 13, 'others': 9},
  'hin_Deva': {'भाई': 26, 'बहन': 3, 'others': 8},
  'kan_Knda': {'others': 25},
  'pan_Guru': {'others': 6, 'ਭਾਈ': 2},
  'tel_Telu': {'others': 25, 'తమ్ముడు': 1},
  'mal_Mlym': {'ബന്ധു': 16, 'others': 15},
  'guj_Gujr': {'others': 27, 'દીકરી': 1},
  'ben_Beng': {'ভাই': 28, 'others': 10}},
 'sister-in-law': {'tam_Taml': {'அண்ணி': 2},
  'mar_Deva': {'वहिनी': 2, 'मेहुणी': 1, 'others': 1},
  'ory_Orya': {},
  'hin_Deva': {'भाभी': 2},
  'kan_Knda': {'ಅತ್ತಿಗೆ': 2},
  'pan_Guru': {'ਭਾਬੀ': 2},
  'tel_Telu': {'వదిన': 2},
  'mal_Mlym': {'ചേട്ടത്തി': 1, 'others': 1},
  'guj_Gujr': {'ભાભી': 2},
  'ben_Beng': {'others': 3}}}

# %% [markdown]
# # imports

# %%
import importlib
import os
import pandas as pd
import possible_indic_relations as poss_indic_rel
# Reload the module to reflect changes
importlib.reload(poss_indic_rel)
import matplotlib.pyplot as plt

pir= poss_indic_rel.possible_relations
pir
# Out:
# {'grandmother': {'ory_Orya': {'ଜେଜେମା': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'ଆଈ': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'ben_Beng': {'ঠাকুরমা': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'দিদি মা': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'guj_Gujr': {'દાદી': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
#    'નાની': {'description': 'mother of mother',
#     'relation': 'maternal',
#     'relation_code': 'F',
#     'gender': 'F'}},
#   'hin_Deva': {'दादी': {'description': 'mother of father',
#     'relation': 'paternal',
#     'relation_code': 'M',
#     'gender': 'F'},
# ...

# %%
plot_data = { # train new set all
    'uncle': {'tam_Taml': {'மாமா': 1079,
   'others': 595,
   'சித்தப்பா': 28,
   'பெரியப்பா': 11},
  'mar_Deva': {'others': 655, 'मामा': 160, 'काका': 265},
  'ory_Orya': {'others': 105, 'ମାମୁଁ': 95, 'ଦାଦା': 23},
  'hin_Deva': {'चाचा': 1854,
   'others': 2448,
   'मामा': 612,
   'ताऊ': 21,
   'फूफा': 19,
   'मौसा': 7},
  'kan_Knda': {'others': 351,
   'ಚಿಕ್ಕಪ್ಪ': 810,
  'ben_Beng': {'ঠাকুরমা': 2, 'others': 11}},
 'aunt': {'tam_Taml': {'அத்தை': 2},
  'mar_Deva': {'मावशी': 3, 'आत्या': 3, 'others': 1},
  'ory_Orya': {'ମାଉସୀ': 2, 'ପିଉସୀ': 1},
  'hin_Deva': {'चाची': 6},
  'kan_Knda': {'ಚಿಕ್ಕಮ್ಮ': 3},
  'pan_Guru': {},
  'tel_Telu': {'others': 3},
  'mal_Mlym': {'others': 5},
  'guj_Gujr': {'કાકી': 1, 'others': 1},
  'ben_Beng': {'others': 6}},
 'cousin': {'tam_Taml': {'others': 12},
  'mar_Deva': {'चुलत भाऊ': 12, 'others': 13, 'चुलत बहीण': 2},
  'ory_Orya': {'ଭାଇ': 13, 'others': 9},
  'hin_Deva': {'भाई': 19, 'बहन': 3, 'others': 2},
  'kan_Knda': {'others': 20},
  'pan_Guru': {'others': 3},
  'tel_Telu': {'others': 21},
  'mal_Mlym': {'ബന്ധു': 12, 'others': 12},
  'guj_Gujr': {'others': 18, 'દીકરી': 1},
  'ben_Beng': {'ভাই': 20, 'others': 6}},
 'brother-in-law': {'tam_Taml': {},
  'mar_Deva': {'मेहुणा': 4, 'दीर': 1, 'others': 1, 'मेव्हणा': 2},
  'ory_Orya': {'others': 3},
  'hin_Deva': {'others': 4, 'जीजा': 1},
  'kan_Knda': {'others': 1, 'ಭಾವ': 2},
  'pan_Guru': {},
  'tel_Telu': {'బావమరిది': 3},
  'mal_Mlym': {'അളിയൻ': 1, 'others': 4},
  'guj_Gujr': {'others': 3},
  'ben_Beng': {'others': 7}},
 'niece': {'tam_Taml': {'others': 3},
  'mar_Deva': {'भाची': 5, 'पुतणी': 1},
  'ory_Orya': {'others': 2, 'ଝିଆରୀ': 1},
  'hin_Deva': {'भतीजी': 3, 'भांजी': 1},
  'kan_Knda': {'others': 3},
  'pan_Guru': {'ਭਤੀਜੀ': 2},
  'tel_Telu': {'others': 1, 'మేనకోడలు': 1},
  'mal_Mlym': {'others': 4, 'മരുമകൾ': 1},
  'guj_Gujr': {'ભત્રીજી': 3},
  'ben_Beng': {'others': 6}}}

# %% [markdown]
# ## details to be plotted

# %%
# make a new dictionary of structure: level 1- relation, level 2- language, level 3- relation_code, level 4- count

data_FM_related = {}
data_gender_related = {}
df = data_gender_related
# df = data_FM_related
for word in plot_data:
    df[word] = {}
    for lang in plot_data[word]:
        df[word][lang] = {}
        # print(data[relation][lang].keys())
        for key in plot_data[word][lang].keys():
            # display the relation_code for that key from pir
            # print(key)
            # print(pir[relation][lang])
            temp_key =None
            if key in pir[word][lang]:
                # print(key, pir[relation][lang][key]['relation_code'])
                # temp_key = pir[relation][lang][key]['relation_code']
                temp_key = pir[word][lang][key]['gender']
                
            else :
                # print(key, "not found: others: X")
                temp_key = 'others'

            if temp_key in df[word][lang]:
                df[word][lang][temp_key] += plot_data[word][lang][key]
            else:
                df[word][lang][temp_key] = plot_data[word][lang][key]
            # print(key, pir[relation][lang][key]['relation_code'])
            # data_new[relation][lang][pir[relation][lang][key]] = data[relation][lang][key]

# data_FM_related
# data_gender_related
df
# Out:
# {'uncle': {'tam_Taml': {'M': 1118, 'others': 595},
#   'mar_Deva': {'others': 655, 'M': 425},
#   'ory_Orya': {'others': 105, 'M': 118},
#   'hin_Deva': {'M': 2513, 'others': 2448},
#   'kan_Knda': {'others': 351, 'M': 900},
#   'pan_Guru': {'M': 146, 'others': 499},
#   'tel_Telu': {'M': 281, 'others': 864},
#   'mal_Mlym': {'others': 1696, 'M': 532},
#   'guj_Gujr': {'M': 902, 'others': 433},
#   'ben_Beng': {'others': 1709, 'M': 168}},
#  'aunt': {'tam_Taml': {'others': 283, 'F': 231},
#   'mar_Deva': {'others': 263, 'F': 122},
#   'ory_Orya': {'F': 13, 'others': 59},
#   'hin_Deva': {'others': 656, 'F': 621},
#   'kan_Knda': {'others': 211, 'F': 367},
#   'pan_Guru': {'F': 74, 'others': 139},
#   'tel_Telu': {'others': 160, 'F': 312},
#   'mal_Mlym': {'others': 889, 'F': 9},
#   'guj_Gujr': {'others': 243, 'F': 275},
#   'ben_Beng': {'others': 488}},
#  'grandfather': {'tam_Taml': {'M': 1234, 'others': 468},
#   'mar_Deva': {'M': 966, 'others': 699},
# ...

# %%
colours_map={
    'F': '#ff9999',
    'M': '#66b3ff',
    'B':     '#99ff99',
    'others': '#ffcc99',
    'N': '#c2c2f0'
    ,
    'Matriarch': '#ff9999',
    'Patriarch': '#66b3ff',

}

# %% [markdown]
# # plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
languages = ['tam_Taml', 'mar_Deva', 'ory_Orya', 'hin_Deva', 'kan_Knda', 'pan_Guru', 'tel_Telu', 'mal_Mlym', 'guj_Gujr', 'ben_Beng']

# %%
# def create_stacked_bar_graph(data, title):
#     languages = list(data.keys())
#     categories = set()
    
#     # Collect all categories
#     for lang in languages:
#         categories.update(data[lang].keys())
    
#     categories = list(categories)
#     print(categories)
    
#     # Prepare data for plotting
#     values = {category: [] for category in categories}
    
#     for lang in languages:
#         for category in categories:
#             values[category].append(data[lang].get(category, 0))

   
#     # Plotting
#     fig, ax = plt.subplots()
    
#     bottom = [0] * len(languages)
#     # Define custom colors
#     # colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6','#c4e17f','#76d7c4','#ff6f61','#6b5b95',
#     #           '#feb236','#d64161','#ff7b25','#f4d35e','#ee8572','#8d99ae','#f9c22e','#405d27','#d9bf77','#f4f1de',
#     #             '#a8dadc','#457b9d','#1d3557','#e63946','#f1faee','#a8dadc','#457b9d','#1d3557','#e63946','#f1faee',
#     #           ]
#     for i, category in enumerate(categories):
#         bars = ax.bar(languages, values[category], label=category, bottom=bottom, color=colours_map[category])
#         bottom = [i + j for i, j in zip(bottom, values[category])]
        
#         # add percentages as labels on the bars
#         for bar in bars:
#             yval = bar.get_height()
#             ax.text(bar.get_x() + bar.get_width()/2.0, yval, round(yval, 2), va='bottom')
            
    
#     ax.set_title(title)
#     ax.set_ylabel('Count')
#     ax.legend()
#     # show legend on the right side outside of the plot
#     ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#     # set height and width of the plot
#     fig.set_figheight(8)
#     fig.set_figwidth(12)
#   # set x -ticks and y ticks
#     ax.set_xticks(languages)
#     ax.set_yticks(range(0, max(bottom) * 2, 100))
#     ax.set_xticklabels(languages)
#     ax.set_yticklabels(range(0, max(bottom) * 2, 100))
    
#     # Adding gap at the top of the y-axis
#     ax.set_ylim(0, max(bottom) * 1.1)
    
#     plt.xticks(rotation=90)

     
#     # Use the Noto Sans font
#     # prop = fm.FontProperties(fname=noto_sans)
#     # for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#     #     label.set_fontproperties(prop)

        
#     # Adjust layout to make room for the labels
#     plt.tight_layout()
    
#     # Save figure
#     plt.savefig('results/new train set/FM_train_'+title+'.png')
    
#     plt.show()
    
#     # # Use a font that supports the required characters
#     # plt.rcParams['font.family'] = 'Noto Sans'
    
#     # plt.show()



# # for word in data_FM_related:
#     # create_stacked_bar_graph(data_FM_related[word], word)

# for word in df:
#     create_stacked_bar_graph(df[word], word)

# %%
# ha_val = ['left', 'center', 'right']

# def create_stack_bars(plot_data, word):
#     # Extract languages and categories
#     languages = list(plot_data.keys())
#     categories = set(cat for values in plot_data.values() for cat in values.keys())

#     # Initialize the bottom position for each bar
#     bottom = [0] * len(languages)

#     # draw the bars with % stacked
#     # fig, ax = plt.subplots()
#     for i, category in enumerate(categories):
#         # values will represent 100 percent of each language
#         # values = [plot_data[lang].get(category, 0) for lang in languages] 
#         # make values as respective percentage
#         # values = [value*100 / sum(values) for value in values]
#         # make bar as 100% stacked, preserving the ratio of each category
#         values = [plot_data[lang].get(category, 0) for lang in languages]
#         plt.bar(languages, values, label=category, bottom=bottom, color=colours_map[category])
#         bottom = [i + j for i, j in zip(bottom, values)]

#     # # Plot each category
#     # for category in categories:
#     #     values = [plot_data[lang].get(category, 0) for lang in languages]
#     #     plt.bar(languages, values, bottom=bottom, label=category, color=colours_map[category])
#     #     bottom = [i + j for i, j in zip(bottom, values)]

#     # Add percentages on top of each bar segment
#     # for i, lang in enumerate(languages):
#     #     total = sum(plot_data[lang].values())
#     #     cumulative = 0
#     #     for g, category in enumerate(categories):
#     #         value = plot_data[lang].get(category, 0)
#     #         if value > 0:
#     #             plt.text(i, cumulative + value / 2, f'{value / total:.1%}', ha= 'center', va='center', fontsize=8)
#     #         cumulative += value

#     # Add labels and title
    
#     plt.xticks(rotation=90)
#     plt.xlabel('Languages')
#     plt.ylabel('Percentage')
#     plt.title(word)
#     plt.legend(title='Categories')

#     # add gap at the top of the y-axis
#     plt.ylim(0, max(bottom) * 1.1)

#     #legend at the right side outside of the plot
#     plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#     plt.tight_layout()
    
#     # Save figure
#     plt.savefig('results/wiki train/FM_train_'+word+'.png')
    
#     # Show the plot
#     plt.show()

# for word in df:
#     create_stack_bars(df[word], word)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# make the y axis as the percentage instead of the count

def create_100_bars(data, title):
    df = pd.DataFrame(data).T.fillna(0)  # Transpose and replace NaN with zeros

    # Calculate percentage for each category within each language
    df_percentage = df.div(df.sum(axis=1), axis=0) * 100

    # Plotting
    ax = df_percentage.plot(kind='bar', stacked=True, color=[colours_map[cat] for cat in df_percentage.columns])

    # Adding value labels on bars
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        if height <=34  and height >0:  # Avoid cluttering with zero-height patches (no data)
            ax.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center')
 # Adding total items at the top of each bar
    totals = df.sum(axis=1)
    for i, total in enumerate(totals):
        ax.text(i, 102, f'{int(total)}', ha='center', va='bottom', fontsize=9)
 # add gap at the top of the y-axis
    plt.ylim(0, 100 * 1.1)

   # put legend outside of plot on the right side
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    # add custom y tick label  at height 102
    plt.text(-1, 102, "Total", ha='center', va='bottom', fontsize=9)

    
   
   

    # Setting labels and title
    plt.xlabel('Languages')
    plt.ylabel('Percentage')
    plt.title(title)
    # plt.legend(title='Categories')
    
    plt.tight_layout()
    
    # Save figure
    plt.savefig('results/new train set 100/gender_train_'+word+'.png')
    
    plt.show()

for word in df:
    create_100_bars(df[word], word)

# %% [markdown]
# # language wise

# %%
lang_map = {
    'hin_Deva': 'Hindi',
    'mar_Deva': 'Marathi',
    'kan_Knda': 'Kannada',
    'tam_Taml': 'Tamil',
    'tel_Telu': 'Telugu',
    'mal_Mlym': 'Malayalam',
    'guj_Gujr': 'Gujarati',
    'ben_Beng': 'Bengali',
    'ory_Orya': 'Oriya',
    'pan_Guru': 'Punjabi'
    
}

# %%
    # make a new dictionary of structure: level 1- relation, level 2- language, level 3- relation_code, level 4- count
data_FM_related = {}
def get_code(lang_df, lang):
        df = data_FM_related
        for word in lang_df:
                df[word] = {}
                # print(data[relation][lang].keys())
                for key in lang_df[word].keys():
                    # display the relation_code for that key from pir
                    # print(key)
                    # print(pir[relation][lang])
                    temp_key =None
                    if key in pir[word][lang]:
                        # print(key, pir[word][lang][key]['relation_code'])
                        temp_key = pir[word][lang][key]['relation_code']
                        # temp_key = pir[relation][lang][key]['gender']
                        
                    # else :
                    #     # print(key, "not found: others: X")
                    #     temp_key = 'others'

                        if temp_key in df[word]:
                            df[word][temp_key] += lang_df[word][key]
                        else:
                            df[word][temp_key] = lang_df[word][key]


        # remove from df the empty keys
        df = {word: data for word, data in df.items() if data}
        df

        #rename the key from F to Matriarch and M to Patriarch

        for word in df:
            if 'F' in df[word]:
                df[word]['Matriarch'] = df[word].pop('F')
            if 'M' in df[word]:
                df[word]['Patriarch'] = df[word].pop('M')

        return df

# %%
# make the y axis as the percentage instead of the count

def word_wise_plot(data, title):
    df = pd.DataFrame(data).T.fillna(0)  # Transpose and replace NaN with zeros

    # Calculate percentage for each category within each language
    df_percentage = df.div(df.sum(axis=1), axis=0) * 100
    print(df_percentage)

    # Plotting
    ax = df_percentage.plot(kind='bar', stacked=True, color=[colours_map[cat] for cat in df_percentage.columns])

    # Adding value labels on bars
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
        if height <=34  and height >0:  # Avoid cluttering with zero-height patches (no data)
            ax.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center')
 # Adding total items at the top of each bar
    totals = df.sum(axis=1)
    for i, total in enumerate(totals):
        ax.text(i, 102, f'{int(total)}', ha='center', va='bottom', fontsize=9)
 # add gap at the top of the y-axis
    plt.ylim(0, 100 * 1.1)

   # put legend outside of plot on the right side
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    # add custom y tick label  at height 102
    plt.text(-1, 102, "Total", ha='center', va='bottom', fontsize=9)

    
   
   

    # Setting labels and title
    plt.xlabel("Words")
    plt.ylabel('Percentage')
    plt.title('Comparison of Patriarchal vs Matriarchal Relations in '+lang_map[title])
    # plt.legend(title='Categories')
    
    plt.tight_layout()
    
    # Save figure
    plt.savefig('results/final/word_wise/FM_train_'+title+'.png')
    
    plt.show()


# word_wise_plot(df, lang)

# %%
# extract only hin_Deva for all root words from plot data and plot it
# lang = 'ory_Orya'
for lang in languages:
        lang_df = {word: plot_data[word][lang] for word in plot_data}
        # lang_df
        # remove 'child' component form lang_df
        lang_df.pop('child')
        df = get_code( lang_df, lang)
        print(df)
        word_wise_plot(df, lang)
# Out:
# {'uncle': {'Matriarch': 1107, 'Patriarch': 11}, 'aunt': {'B': 207, 'Matriarch': 24}, 'grandfather': {'B': 1234}, 'grandmother': {'B': 294}, 'brother-in-law': {'Matriarch': 34}, 'nephew': {'Matriarch': 1, 'Patriarch': 4}, 'niece': {'Matriarch': 2, 'Patriarch': 8}, 'sister-in-law': {'Matriarch': 10, 'Patriarch': 13}, 'cousin': {'Matriarch': 8, 'Patriarch': 43}}
#                  Matriarch  Patriarch          B
# uncle            99.016100   0.983900    0.00000
# aunt             10.389610   0.000000   89.61039
# grandfather       0.000000   0.000000  100.00000
# grandmother       0.000000   0.000000  100.00000
# brother-in-law  100.000000   0.000000    0.00000
# nephew           20.000000  80.000000    0.00000
# niece            20.000000  80.000000    0.00000
# sister-in-law    43.478261  56.521739    0.00000
# cousin           15.686275  84.313725    0.00000
# ...

# %% [markdown]
# # Test data:

# %%
# # load from pickel files testset_len_dict_resultant
# import pickle
# with open('testset_len_dict_resultant.pkl', 'rb') as f:
#     testset_len_dict_resultant = pickle.load(f)

# testset_len_dict_resultant
# Out:
# {'child': {'tam_Taml': {'others': 232},
#   'mar_Deva': {'others': 232},
#   'ory_Orya': {'ପିଲା': 204, 'others': 28},
#   'hin_Deva': {'others': 232},
#   'kan_Knda': {'others': 216, 'ಮಗ': 16},
#   'pan_Guru': {'others': 232},
#   'tel_Telu': {'others': 232},
#   'mal_Mlym': {'കുട്ടി': 210, 'others': 22},
#   'guj_Gujr': {'બાળક': 209, 'others': 23},
#   'ben_Beng': {'others': 232}},
#  'aunt': {'tam_Taml': {'others': 12},
#   'mar_Deva': {'others': 12},
#   'ory_Orya': {'others': 12},
#   'hin_Deva': {'others': 12},
#   'kan_Knda': {'others': 12},
#   'pan_Guru': {'others': 12},
#   'tel_Telu': {'others': 12},
#   'mal_Mlym': {'others': 12},
#   'guj_Gujr': {'others': 12},
#   'ben_Beng': {'others': 12}},
#  'cousin': {'tam_Taml': {'others': 8},
#   'mar_Deva': {'चुलत बहीण': 6, 'चुलत भाऊ': 2},
#   'ory_Orya': {'others': 4, 'ଭାଇ': 4},
#   'hin_Deva': {'बहन': 6, 'भाई': 2},
#   'kan_Knda': {'others': 8},
#   'pan_Guru': {'others': 4, 'ਭੈਣ': 4},
#   'tel_Telu': {'others': 8},
# ...

# %%
# plot_data = testset_len_dict_resultant

# %%
test_indict2 = 

test_sarvam = 

test_phi = 

test_googlet =

# %% [markdown]
# # conclusion
